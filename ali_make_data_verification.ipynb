# %% [markdown]
# [View in Colaboratory](https://colab.research.google.com/github/tcglarry/alibaba_manufacturing_competition/blob/master/ali_make_data_verification.ipynb)

# %%
# Install a Drive FUSE wrapper.
# https://github.com/astrada/google-drive-ocamlfuse
# !apt-get install -y -qq software-properties-common python-software-properties module-init-tools
# !add-apt-repository -y ppa:alessandro-strada/ppa 2>&1 > /dev/null
# !apt-get update -qq 2>&1 > /dev/null
# !apt-get -y install -qq google-drive-ocamlfuse fuse
# Out:
# Preconfiguring packages ...
# Selecting previously unselected package cron.
# (Reading database ... 18408 files and directories currently installed.)
# Preparing to unpack .../00-cron_3.0pl1-128ubuntu5_amd64.deb ...
# Unpacking cron (3.0pl1-128ubuntu5) ...
# Selecting previously unselected package libapparmor1:amd64.
# Preparing to unpack .../01-libapparmor1_2.11.0-2ubuntu17.1_amd64.deb ...
# Unpacking libapparmor1:amd64 (2.11.0-2ubuntu17.1) ...
# Selecting previously unselected package libdbus-1-3:amd64.
# Preparing to unpack .../02-libdbus-1-3_1.10.22-1ubuntu1_amd64.deb ...
# Unpacking libdbus-1-3:amd64 (1.10.22-1ubuntu1) ...
# Selecting previously unselected package dbus.
# Preparing to unpack .../03-dbus_1.10.22-1ubuntu1_amd64.deb ...
# Unpacking dbus (1.10.22-1ubuntu1) ...
# Selecting previously unselected package dirmngr.
# Preparing to unpack .../04-dirmngr_2.1.15-1ubuntu8.1_amd64.deb ...
# Unpacking dirmngr (2.1.15-1ubuntu8.1) ...
# Selecting previously unselected package distro-info-data.
# Preparing to unpack .../05-distro-info-data_0.36ubuntu0.2_all.deb ...
# Unpacking distro-info-data (0.36ubuntu0.2) ...
# Selecting previously unselected package libkmod2:amd64.
# Preparing to unpack .../06-libkmod2_24-1ubuntu2_amd64.deb ...
# Unpacking libkmod2:amd64 (24-1ubuntu2) ...
# Selecting previously unselected package kmod.
# Preparing to unpack .../07-kmod_24-1ubuntu2_amd64.deb ...
# Unpacking kmod (24-1ubuntu2) ...
# Selecting previously unselected package lsb-release.
# Preparing to unpack .../08-lsb-release_9.20160110ubuntu5_all.deb ...
# Unpacking lsb-release (9.20160110ubuntu5) ...
# Selecting previously unselected package libgirepository-1.0-1:amd64.
# Preparing to unpack .../09-libgirepository-1.0-1_1.54.1-1_amd64.deb ...
# Unpacking libgirepository-1.0-1:amd64 (1.54.1-1) ...
# Selecting previously unselected package gir1.2-glib-2.0:amd64.
# Preparing to unpack .../10-gir1.2-glib-2.0_1.54.1-1_amd64.deb ...
# Unpacking gir1.2-glib-2.0:amd64 (1.54.1-1) ...
# Selecting previously unselected package iso-codes.
# Preparing to unpack .../11-iso-codes_3.75-1_all.deb ...
# Unpacking iso-codes (3.75-1) ...
# Selecting previously unselected package libdbus-glib-1-2:amd64.
# Preparing to unpack .../12-libdbus-glib-1-2_0.108-2_amd64.deb ...
# Unpacking libdbus-glib-1-2:amd64 (0.108-2) ...
# Selecting previously unselected package python-apt-common.
# Preparing to unpack .../13-python-apt-common_1.4.0~beta3build2_all.deb ...
# Unpacking python-apt-common (1.4.0~beta3build2) ...
# Selecting previously unselected package python3-apt.
# Preparing to unpack .../14-python3-apt_1.4.0~beta3build2_amd64.deb ...
# Unpacking python3-apt (1.4.0~beta3build2) ...
# Selecting previously unselected package python3-dbus.
# Preparing to unpack .../15-python3-dbus_1.2.4-1build3_amd64.deb ...
# Unpacking python3-dbus (1.2.4-1build3) ...
# Selecting previously unselected package python3-gi.
# Preparing to unpack .../16-python3-gi_3.24.1-2build1_amd64.deb ...
# Unpacking python3-gi (3.24.1-2build1) ...
# Selecting previously unselected package module-init-tools.
# Preparing to unpack .../17-module-init-tools_24-1ubuntu2_all.deb ...
# Unpacking module-init-tools (24-1ubuntu2) ...
# Selecting previously unselected package python-apt.
# Preparing to unpack .../18-python-apt_1.4.0~beta3build2_amd64.deb ...
# Unpacking python-apt (1.4.0~beta3build2) ...
# Selecting previously unselected package python-pycurl.
# Preparing to unpack .../19-python-pycurl_7.43.0-2build2_amd64.deb ...
# Unpacking python-pycurl (7.43.0-2build2) ...
# Selecting previously unselected package python-software-properties.
# Preparing to unpack .../20-python-software-properties_0.96.24.17_all.deb ...
# Unpacking python-software-properties (0.96.24.17) ...
# Selecting previously unselected package python3-software-properties.
# Preparing to unpack .../21-python3-software-properties_0.96.24.17_all.deb ...
# Unpacking python3-software-properties (0.96.24.17) ...
# Selecting previously unselected package software-properties-common.
# Preparing to unpack .../22-software-properties-common_0.96.24.17_all.deb ...
# Unpacking software-properties-common (0.96.24.17) ...
# Selecting previously unselected package unattended-upgrades.
# Preparing to unpack .../23-unattended-upgrades_0.98ubuntu1.1_all.deb ...
# Unpacking unattended-upgrades (0.98ubuntu1.1) ...
# Setting up python-apt-common (1.4.0~beta3build2) ...
# Setting up python3-apt (1.4.0~beta3build2) ...
# Setting up iso-codes (3.75-1) ...
# Setting up distro-info-data (0.36ubuntu0.2) ...
# Setting up python-pycurl (7.43.0-2build2) ...
# Setting up lsb-release (9.20160110ubuntu5) ...
# Setting up libgirepository-1.0-1:amd64 (1.54.1-1) ...
# Setting up libkmod2:amd64 (24-1ubuntu2) ...
# Setting up gir1.2-glib-2.0:amd64 (1.54.1-1) ...
# Processing triggers for libc-bin (2.26-0ubuntu2.1) ...
# Setting up libapparmor1:amd64 (2.11.0-2ubuntu17.1) ...
# Setting up unattended-upgrades (0.98ubuntu1.1) ...
#
# Creating config file /etc/apt/apt.conf.d/20auto-upgrades with new version
#
# Creating config file /etc/apt/apt.conf.d/50unattended-upgrades with new version
# invoke-rc.d: could not determine current runlevel
# invoke-rc.d: policy-rc.d denied execution of start.
# Setting up dirmngr (2.1.15-1ubuntu8.1) ...
# Setting up cron (3.0pl1-128ubuntu5) ...
# Adding group `crontab' (GID 102) ...
# Done.
# update-rc.d: warning: start and stop actions are no longer supported; falling back to defaults
# update-rc.d: warning: stop runlevel arguments (1) do not match cron Default-Stop values (none)
# invoke-rc.d: could not determine current runlevel
# invoke-rc.d: policy-rc.d denied execution of start.
# Setting up libdbus-1-3:amd64 (1.10.22-1ubuntu1) ...
# Setting up kmod (24-1ubuntu2) ...
# Setting up libdbus-glib-1-2:amd64 (0.108-2) ...
# Setting up python3-gi (3.24.1-2build1) ...
# Setting up module-init-tools (24-1ubuntu2) ...
# Setting up python3-software-properties (0.96.24.17) ...
# Setting up dbus (1.10.22-1ubuntu1) ...
# Setting up python-apt (1.4.0~beta3build2) ...
# Setting up python3-dbus (1.2.4-1build3) ...
# Setting up python-software-properties (0.96.24.17) ...
# Setting up software-properties-common (0.96.24.17) ...
# Processing triggers for libc-bin (2.26-0ubuntu2.1) ...
# Processing triggers for dbus (1.10.22-1ubuntu1) ...
# gpg: keybox '/tmp/tmpsba25dy7/pubring.gpg' created
# gpg: /tmp/tmpsba25dy7/trustdb.gpg: trustdb created
# gpg: key AD5F235DF639B041: public key "Launchpad PPA for Alessandro Strada" imported
# gpg: Total number processed: 1
# gpg:               imported: 1
# Warning: apt-key output should not be parsed (stdout is not a terminal)
# E: Unable to locate package google-drive-ocamlfuse

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
# !cp 'drive/My Drive/kaggle/ali/manu_big_data/train_sample_total.zip' .

# %%
# !unzip train_sample_total.zip
# Out:
# Archive:  train_sample_total.zip
#    creating: train_sample_total/
#   inflating: train_sample_total/正常20180914144614对照样本_02.jpg
#    creating: __MACOSX/
#    creating: __MACOSX/train_sample_total/
#   inflating: __MACOSX/train_sample_total/._正常20180914144614对照样本_02.jpg
#   inflating: train_sample_total/横条压凹20180903105700对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._横条压凹20180903105700对照样本_02.jpg
#   inflating: train_sample_total/漏底20180912160315对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._漏底20180912160315对照样本_02.jpg
#   inflating: train_sample_total/碰伤20180905092240对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._碰伤20180905092240对照样本_02.jpg
#   inflating: train_sample_total/正常20180915150646对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._正常20180915150646对照样本_02.jpg
#   inflating: train_sample_total/碰伤20180907111235对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._碰伤20180907111235对照样本_02.jpg
#   inflating: train_sample_total/正常20180915154327对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._正常20180915154327对照样本_02.jpg
#   inflating: train_sample_total/漏底20180901093350对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._漏底20180901093350对照样本_02.jpg
#   inflating: train_sample_total/桔皮20180912162642对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._桔皮20180912162642对照样本_02.jpg
#   inflating: train_sample_total/漏底20180912163834对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._漏底20180912163834对照样本_02.jpg
#   inflating: train_sample_total/漏底20180901092306对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._漏底20180901092306对照样本_02.jpg
#   inflating: train_sample_total/正常20180914140317对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._正常20180914140317对照样本_02.jpg
#   inflating: train_sample_total/正常20180913150519对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._正常20180913150519对照样本_02.jpg
#   inflating: train_sample_total/正常20180913155019对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._正常20180913155019对照样本_02.jpg
#   inflating: train_sample_total/正常20180915150730对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._正常20180915150730对照样本_02.jpg
#   inflating: train_sample_total/脏点20180910093340对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._脏点20180910093340对照样本_02.jpg
#   inflating: train_sample_total/漏底20180901091750对照样本_01.jpg
#   inflating: __MACOSX/train_sample_total/._漏底20180901091750对照样本_01.jpg
#   inflating: train_sample_total/凸粉20180901135426对照样本_01.jpg
#   inflating: __MACOSX/train_sample_total/._凸粉20180901135426对照样本_01.jpg
#   inflating: train_sample_total/其他_气泡20180906141956对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._其他_气泡20180906141956对照样本_02.jpg
#   inflating: train_sample_total/正常20180914141500对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._正常20180914141500对照样本_02.jpg
#   inflating: train_sample_total/擦花20180915105011对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._擦花20180915105011对照样本_02.jpg
#   inflating: train_sample_total/碰伤20180907154406对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._碰伤20180907154406对照样本_02.jpg
#   inflating: train_sample_total/正常20180915150613对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._正常20180915150613对照样本_02.jpg
#   inflating: train_sample_total/脏点20180910095849对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._脏点20180910095849对照样本_02.jpg
#   inflating: train_sample_total/脏点20180907110344对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._脏点20180907110344对照样本_02.jpg
#   inflating: train_sample_total/凸粉20180901101521对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._凸粉20180901101521对照样本_02.jpg
#   inflating: train_sample_total/漏底20180830162443对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._漏底20180830162443对照样本_02.jpg
#   inflating: train_sample_total/正常20180913153003对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._正常20180913153003对照样本_02.jpg
#   inflating: train_sample_total/漏底20180901094020对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._漏底20180901094020对照样本_02.jpg
#   inflating: train_sample_total/起坑20180905105859对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._起坑20180905105859对照样本_02.jpg
#   inflating: train_sample_total/正常20180914103721对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._正常20180914103721对照样本_02.jpg
#   inflating: train_sample_total/正常20180915155800对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._正常20180915155800对照样本_02.jpg
#   inflating: train_sample_total/正常20180915143920对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._正常20180915143920对照样本_02.jpg
#   inflating: train_sample_total/正常20180915145140对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._正常20180915145140对照样本_02.jpg
#   inflating: train_sample_total/正常20180914093909对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._正常20180914093909对照样本_02.jpg
#   inflating: train_sample_total/脏点20180910095110对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._脏点20180910095110对照样本_02.jpg
#   inflating: train_sample_total/正常20180914094342对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._正常20180914094342对照样本_02.jpg
#   inflating: train_sample_total/起坑20180905110106对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._起坑20180905110106对照样本_02.jpg
#   inflating: train_sample_total/漏底20180912153922对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._漏底20180912153922对照样本_02.jpg
#   inflating: train_sample_total/碰伤20180905091545对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._碰伤20180905091545对照样本_02.jpg
#   inflating: train_sample_total/擦花20180915110017对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._擦花20180915110017对照样本_02.jpg
#   inflating: train_sample_total/正常20180914154019对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._正常20180914154019对照样本_02.jpg
#   inflating: train_sample_total/正常20180915143834对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._正常20180915143834对照样本_02.jpg
#   inflating: train_sample_total/脏点20180910095033对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._脏点20180910095033对照样本_02.jpg
#   inflating: train_sample_total/涂层开裂20180905160816对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._涂层开裂20180905160816对照样本_02.jpg
#   inflating: train_sample_total/碰伤20180905095107对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._碰伤20180905095107对照样本_02.jpg
#   inflating: train_sample_total/正常20180914091003对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._正常20180914091003对照样本_02.jpg
#   inflating: train_sample_total/正常20180915144002对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._正常20180915144002对照样本_02.jpg
#   inflating: train_sample_total/脏点20180910092805对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._脏点20180910092805对照样本_02.jpg
#   inflating: train_sample_total/正常20180914143231对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._正常20180914143231对照样本_02.jpg
#   inflating: train_sample_total/正常20180914154412对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._正常20180914154412对照样本_02.jpg
#   inflating: train_sample_total/不导电20180831101753对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._不导电20180831101753对照样本_02.jpg
#   inflating: train_sample_total/其他_碰凹20180915103424对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._其他_碰凹20180915103424对照样本_02.jpg
#   inflating: train_sample_total/凸粉20180901101751对照样本_01.jpg
#   inflating: __MACOSX/train_sample_total/._凸粉20180901101751对照样本_01.jpg
#   inflating: train_sample_total/擦花20180831110630对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._擦花20180831110630对照样本_02.jpg
#   inflating: train_sample_total/正常20180914101949对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._正常20180914101949对照样本_02.jpg
#   inflating: train_sample_total/横条压凹20180903111439对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._横条压凹20180903111439对照样本_02.jpg
#   inflating: train_sample_total/正常20180913144120对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._正常20180913144120对照样本_02.jpg
#   inflating: train_sample_total/漏底20180830162421对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._漏底20180830162421对照样本_02.jpg
#   inflating: train_sample_total/正常20180914102722对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._正常20180914102722对照样本_02.jpg
#   inflating: train_sample_total/正常20180913141342对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._正常20180913141342对照样本_02.jpg
#   inflating: train_sample_total/正常20180915152054对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._正常20180915152054对照样本_02.jpg
#   inflating: train_sample_total/漏底20180908105012对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._漏底20180908105012对照样本_02.jpg
#   inflating: train_sample_total/正常20180913164552对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._正常20180913164552对照样本_02.jpg
#   inflating: train_sample_total/正常20180914143347对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._正常20180914143347对照样本_02.jpg
#   inflating: train_sample_total/脏点20180912144056对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._脏点20180912144056对照样本_02.jpg
#   inflating: train_sample_total/正常20180914104820对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._正常20180914104820对照样本_02.jpg
#   inflating: train_sample_total/凸粉20180901140848对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._凸粉20180901140848对照样本_02.jpg
#   inflating: train_sample_total/脏点20180910094030对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._脏点20180910094030对照样本_02.jpg
#   inflating: train_sample_total/正常20180915161358对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._正常20180915161358对照样本_02.jpg
#   inflating: train_sample_total/脏点20180910094752对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._脏点20180910094752对照样本_02.jpg
#   inflating: train_sample_total/桔皮20180830165314对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._桔皮20180830165314对照样本_02.jpg
#   inflating: train_sample_total/漏底20180830134026对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._漏底20180830134026对照样本_02.jpg
#   inflating: train_sample_total/碰伤20180905093905对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._碰伤20180905093905对照样本_02.jpg
#   inflating: train_sample_total/脏点20180911104657对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._脏点20180911104657对照样本_02.jpg
#   inflating: train_sample_total/凸粉20180901101040对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._凸粉20180901101040对照样本_02.jpg
#   inflating: train_sample_total/漏底20180901095111对照样本_01.jpg
#   inflating: __MACOSX/train_sample_total/._漏底20180901095111对照样本_01.jpg
#   inflating: train_sample_total/其他_碰凹20180901103136对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._其他_碰凹20180901103136对照样本_02.jpg
#   inflating: train_sample_total/正常20180914135929对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._正常20180914135929对照样本_02.jpg
#   inflating: train_sample_total/脏点20180831153018对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._脏点20180831153018对照样本_02.jpg
#   inflating: train_sample_total/其他_火山口20180905163109对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._其他_火山口20180905163109对照样本_02.jpg
#   inflating: train_sample_total/碰伤20180907152907对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._碰伤20180907152907对照样本_02.jpg
#   inflating: train_sample_total/正常20180915152911对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._正常20180915152911对照样本_02.jpg
#   inflating: train_sample_total/脏点20180831144313对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._脏点20180831144313对照样本_02.jpg
#   inflating: train_sample_total/脏点20180910092754对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._脏点20180910092754对照样本_02.jpg
#   inflating: train_sample_total/正常20180914144203对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._正常20180914144203对照样本_02.jpg
#   inflating: train_sample_total/凸粉20180901140859对照样本_01.jpg
#   inflating: __MACOSX/train_sample_total/._凸粉20180901140859对照样本_01.jpg
#   inflating: train_sample_total/正常20180913154753对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._正常20180913154753对照样本_02.jpg
#   inflating: train_sample_total/桔皮20180830152800对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._桔皮20180830152800对照样本_02.jpg
#   inflating: train_sample_total/正常20180915145944对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._正常20180915145944对照样本_02.jpg
#   inflating: train_sample_total/脏点20180911110333对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._脏点20180911110333对照样本_02.jpg
#   inflating: train_sample_total/漏底20180830140503对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._漏底20180830140503对照样本_02.jpg
#   inflating: train_sample_total/正常20180914105538对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._正常20180914105538对照样本_02.jpg
#   inflating: train_sample_total/正常20180913162422对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._正常20180913162422对照样本_02.jpg
#   inflating: train_sample_total/起坑20180906141122对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._起坑20180906141122对照样本_02.jpg
#   inflating: train_sample_total/漏底20180830140608对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._漏底20180830140608对照样本_02.jpg
#   inflating: train_sample_total/正常20180913163316对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._正常20180913163316对照样本_02.jpg
#   inflating: train_sample_total/漏底20180901091425对照样本_01.jpg
#   inflating: __MACOSX/train_sample_total/._漏底20180901091425对照样本_01.jpg
#   inflating: train_sample_total/正常20180915144853对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._正常20180915144853对照样本_02.jpg
#   inflating: train_sample_total/正常20180915155338对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._正常20180915155338对照样本_02.jpg
#   inflating: train_sample_total/漏底20180901094125对照样本_01.jpg
#   inflating: __MACOSX/train_sample_total/._漏底20180901094125对照样本_01.jpg
#   inflating: train_sample_total/正常20180914141642对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._正常20180914141642对照样本_02.jpg
#   inflating: train_sample_total/正常20180914155829对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._正常20180914155829对照样本_02.jpg
#   inflating: train_sample_total/涂层开裂20180905154937对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._涂层开裂20180905154937对照样本_02.jpg
#   inflating: train_sample_total/擦花20180915104332对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._擦花20180915104332对照样本_02.jpg
#   inflating: train_sample_total/正常20180913171116对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._正常20180913171116对照样本_02.jpg
#   inflating: train_sample_total/其他_碰凹20180901103722对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._其他_碰凹20180901103722对照样本_02.jpg
#   inflating: train_sample_total/正常20180914140614对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._正常20180914140614对照样本_02.jpg
#   inflating: train_sample_total/擦花20180901141248对照样本_01.jpg
#   inflating: __MACOSX/train_sample_total/._擦花20180901141248对照样本_01.jpg
#   inflating: train_sample_total/正常20180914101759对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._正常20180914101759对照样本_02.jpg
#   inflating: train_sample_total/正常20180913164849对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._正常20180913164849对照样本_02.jpg
#   inflating: train_sample_total/漏底20180912162908对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._漏底20180912162908对照样本_02.jpg
#   inflating: train_sample_total/横条压凹20180903103125对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._横条压凹20180903103125对照样本_02.jpg
#   inflating: train_sample_total/正常20180913152320对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._正常20180913152320对照样本_02.jpg
#   inflating: train_sample_total/正常20180915151941对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._正常20180915151941对照样本_02.jpg
#   inflating: train_sample_total/涂层开裂20180905155510对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._涂层开裂20180905155510对照样本_02.jpg
#   inflating: train_sample_total/正常20180913153423对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._正常20180913153423对照样本_02.jpg
#   inflating: train_sample_total/正常20180915160412对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._正常20180915160412对照样本_02.jpg
#   inflating: train_sample_total/其他_划伤20180912143322对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._其他_划伤20180912143322对照样本_02.jpg
#   inflating: train_sample_total/正常20180915145202对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._正常20180915145202对照样本_02.jpg
#   inflating: train_sample_total/桔皮20180910102046对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._桔皮20180910102046对照样本_02.jpg
#   inflating: train_sample_total/漏底20180829163924对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._漏底20180829163924对照样本_02.jpg
#   inflating: train_sample_total/横条压凹20180903103031对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._横条压凹20180903103031对照样本_02.jpg
#   inflating: train_sample_total/正常20180913172113对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._正常20180913172113对照样本_02.jpg
#   inflating: train_sample_total/漏底20180901091854对照样本_01.jpg
#   inflating: __MACOSX/train_sample_total/._漏底20180901091854对照样本_01.jpg
#   inflating: train_sample_total/擦花20180911140127对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._擦花20180911140127对照样本_02.jpg
#   inflating: train_sample_total/正常20180913144323对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._正常20180913144323对照样本_02.jpg
#   inflating: train_sample_total/漏底20180901092256对照样本_01.jpg
#   inflating: __MACOSX/train_sample_total/._漏底20180901092256对照样本_01.jpg
#   inflating: train_sample_total/正常20180914093922对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._正常20180914093922对照样本_02.jpg
#   inflating: train_sample_total/漏底20180908104512对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._漏底20180908104512对照样本_02.jpg
#   inflating: train_sample_total/碰伤20180907160333对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._碰伤20180907160333对照样本_02.jpg
#   inflating: train_sample_total/正常20180915150942对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._正常20180915150942对照样本_02.jpg
#   inflating: train_sample_total/正常20180914143032对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._正常20180914143032对照样本_02.jpg
#   inflating: train_sample_total/正常20180913165646对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._正常20180913165646对照样本_02.jpg
#   inflating: train_sample_total/正常20180913152342对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._正常20180913152342对照样本_02.jpg
#   inflating: train_sample_total/擦花20180901105534对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._擦花20180901105534对照样本_02.jpg
#   inflating: train_sample_total/横条压凹20180903110550对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._横条压凹20180903110550对照样本_02.jpg
#   inflating: train_sample_total/正常20180915161426对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._正常20180915161426对照样本_02.jpg
#   inflating: train_sample_total/脏点20180910091751对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._脏点20180910091751对照样本_02.jpg
#   inflating: train_sample_total/漏底20180901093423对照样本_01.jpg
#   inflating: __MACOSX/train_sample_total/._漏底20180901093423对照样本_01.jpg
#   inflating: train_sample_total/其他_碰凹20180901104059对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._其他_碰凹20180901104059对照样本_02.jpg
#   inflating: train_sample_total/碰伤20180911105119对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._碰伤20180911105119对照样本_02.jpg
#   inflating: train_sample_total/桔皮20180912165731对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._桔皮20180912165731对照样本_02.jpg
#   inflating: train_sample_total/正常20180915145343对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._正常20180915145343对照样本_02.jpg
#   inflating: train_sample_total/擦花20180901141210对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._擦花20180901141210对照样本_02.jpg
#   inflating: train_sample_total/桔皮20180830153533对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._桔皮20180830153533对照样本_02.jpg
#   inflating: train_sample_total/正常20180915145416对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._正常20180915145416对照样本_02.jpg
#   inflating: train_sample_total/正常20180915144315对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._正常20180915144315对照样本_02.jpg
#   inflating: train_sample_total/涂层开裂20180905140826对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._涂层开裂20180905140826对照样本_02.jpg
#   inflating: train_sample_total/脏点20180831150421对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._脏点20180831150421对照样本_02.jpg
#   inflating: train_sample_total/不导电20180831103945对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._不导电20180831103945对照样本_02.jpg
#   inflating: train_sample_total/脏点20180910095148对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._脏点20180910095148对照样本_02.jpg
#   inflating: train_sample_total/正常20180914094605对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._正常20180914094605对照样本_02.jpg
#   inflating: train_sample_total/擦花20180831110501对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._擦花20180831110501对照样本_02.jpg
#   inflating: train_sample_total/凸粉20180901141824对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._凸粉20180901141824对照样本_02.jpg
#   inflating: train_sample_total/横条压凹20180903111403对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._横条压凹20180903111403对照样本_02.jpg
#   inflating: train_sample_total/正常20180915145430对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._正常20180915145430对照样本_02.jpg
#   inflating: train_sample_total/漏底20180901093350对照样本_01.jpg
#   inflating: __MACOSX/train_sample_total/._漏底20180901093350对照样本_01.jpg
#   inflating: train_sample_total/擦花20180912104556对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._擦花20180912104556对照样本_02.jpg
#   inflating: train_sample_total/正常20180914143023对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._正常20180914143023对照样本_02.jpg
#   inflating: train_sample_total/漏底20180901092306对照样本_01.jpg
#   inflating: __MACOSX/train_sample_total/._漏底20180901092306对照样本_01.jpg
#   inflating: train_sample_total/正常20180914102313对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._正常20180914102313对照样本_02.jpg
#   inflating: train_sample_total/正常20180914144815对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._正常20180914144815对照样本_02.jpg
#   inflating: train_sample_total/正常20180914092813对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._正常20180914092813对照样本_02.jpg
#   inflating: train_sample_total/正常20180914091405对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._正常20180914091405对照样本_02.jpg
#   inflating: train_sample_total/正常20180913153511对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._正常20180913153511对照样本_02.jpg
#   inflating: train_sample_total/漏底20180901091750对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._漏底20180901091750对照样本_02.jpg
#   inflating: train_sample_total/正常20180913145353对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._正常20180913145353对照样本_02.jpg
#   inflating: train_sample_total/凸粉20180901135426对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._凸粉20180901135426对照样本_02.jpg
#   inflating: train_sample_total/不导电20180830131628对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._不导电20180830131628对照样本_02.jpg
#   inflating: train_sample_total/正常20180914111438对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._正常20180914111438对照样本_02.jpg
#   inflating: train_sample_total/漏底20180915095845对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._漏底20180915095845对照样本_02.jpg
#   inflating: train_sample_total/桔皮20180912151950对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._桔皮20180912151950对照样本_02.jpg
#   inflating: train_sample_total/脏点20180913110612对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._脏点20180913110612对照样本_02.jpg
#   inflating: train_sample_total/漏底20180910102922对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._漏底20180910102922对照样本_02.jpg
#   inflating: train_sample_total/不导电20180831102843对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._不导电20180831102843对照样本_02.jpg
#   inflating: train_sample_total/擦花20180830172305对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._擦花20180830172305对照样本_02.jpg
#   inflating: train_sample_total/正常20180914142017对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._正常20180914142017对照样本_02.jpg
#   inflating: train_sample_total/正常20180915164328对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._正常20180915164328对照样本_02.jpg
#   inflating: train_sample_total/横条压凹20180903111220对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._横条压凹20180903111220对照样本_02.jpg
#   inflating: train_sample_total/凸粉20180901101521对照样本_01.jpg
#   inflating: __MACOSX/train_sample_total/._凸粉20180901101521对照样本_01.jpg
#   inflating: train_sample_total/正常20180913140012对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._正常20180913140012对照样本_02.jpg
#   inflating: train_sample_total/桔皮20180912160434对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._桔皮20180912160434对照样本_02.jpg
#   inflating: train_sample_total/漏底20180901094020对照样本_01.jpg
#   inflating: __MACOSX/train_sample_total/._漏底20180901094020对照样本_01.jpg
#   inflating: train_sample_total/桔皮20180908090827对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._桔皮20180908090827对照样本_02.jpg
#   inflating: train_sample_total/正常20180914101257对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._正常20180914101257对照样本_02.jpg
#   inflating: train_sample_total/擦花20180911135707对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._擦花20180911135707对照样本_02.jpg
#   inflating: train_sample_total/脏点20180913112000对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._脏点20180913112000对照样本_02.jpg
#   inflating: train_sample_total/正常20180914152244对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._正常20180914152244对照样本_02.jpg
#   inflating: train_sample_total/碰伤20180905092218对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._碰伤20180905092218对照样本_02.jpg
#   inflating: train_sample_total/漏底20180912152349对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._漏底20180912152349对照样本_02.jpg
#   inflating: train_sample_total/脏点20180831150937对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._脏点20180831150937对照样本_02.jpg
#   inflating: train_sample_total/横条压凹20180903105525对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._横条压凹20180903105525对照样本_02.jpg
#   inflating: train_sample_total/正常20180913152936对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._正常20180913152936对照样本_02.jpg
#   inflating: train_sample_total/正常20180914090822对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._正常20180914090822对照样本_02.jpg
#   inflating: train_sample_total/正常20180915150454对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._正常20180915150454对照样本_02.jpg
#   inflating: train_sample_total/其他_纹粗20180830141638对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._其他_纹粗20180830141638对照样本_02.jpg
#   inflating: train_sample_total/正常20180914110828对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._正常20180914110828对照样本_02.jpg
#   inflating: train_sample_total/漏底20180910103411对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._漏底20180910103411对照样本_02.jpg
#   inflating: train_sample_total/正常20180913150400对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._正常20180913150400对照样本_02.jpg
#   inflating: train_sample_total/凸粉20180901101751对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._凸粉20180901101751对照样本_02.jpg
#   inflating: train_sample_total/正常20180915170744对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._正常20180915170744对照样本_02.jpg
#   inflating: train_sample_total/其他_划伤20180912142823对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._其他_划伤20180912142823对照样本_02.jpg
#   inflating: train_sample_total/横条压凹20180903104511对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._横条压凹20180903104511对照样本_02.jpg
#   inflating: train_sample_total/凸粉20180901140848对照样本_01.jpg
#   inflating: __MACOSX/train_sample_total/._凸粉20180901140848对照样本_01.jpg
#   inflating: train_sample_total/正常20180913154742对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._正常20180913154742对照样本_02.jpg
#   inflating: train_sample_total/擦花20180911135752对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._擦花20180911135752对照样本_02.jpg
#   inflating: train_sample_total/脏点20180915104643对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._脏点20180915104643对照样本_02.jpg
#   inflating: train_sample_total/正常20180913162738对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._正常20180913162738对照样本_02.jpg
#   inflating: train_sample_total/起坑20180906140746对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._起坑20180906140746对照样本_02.jpg
#   inflating: train_sample_total/正常20180914145432对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._正常20180914145432对照样本_02.jpg
#   inflating: train_sample_total/正常20180915152900对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._正常20180915152900对照样本_02.jpg
#   inflating: train_sample_total/脏点20180911143225对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._脏点20180911143225对照样本_02.jpg
#   inflating: train_sample_total/正常20180913171046对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._正常20180913171046对照样本_02.jpg
#   inflating: train_sample_total/横条压凹20180903105306对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._横条压凹20180903105306对照样本_02.jpg
#   inflating: train_sample_total/正常20180913171724对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._正常20180913171724对照样本_02.jpg
#   inflating: train_sample_total/起坑20180905105447对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._起坑20180905105447对照样本_02.jpg
#   inflating: train_sample_total/擦花20180831160713对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._擦花20180831160713对照样本_02.jpg
#   inflating: train_sample_total/脏点20180910095826对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._脏点20180910095826对照样本_02.jpg
#   inflating: train_sample_total/正常20180913154349对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._正常20180913154349对照样本_02.jpg
#   inflating: train_sample_total/正常20180913150455对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._正常20180913150455对照样本_02.jpg
#   inflating: train_sample_total/正常20180915145027对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._正常20180915145027对照样本_02.jpg
#   inflating: train_sample_total/其他_碰凹20180901103136对照样本_01.jpg
#   inflating: __MACOSX/train_sample_total/._其他_碰凹20180901103136对照样本_01.jpg
#   inflating: train_sample_total/桔皮20180912164434对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._桔皮20180912164434对照样本_02.jpg
#   inflating: train_sample_total/正常20180914142541对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._正常20180914142541对照样本_02.jpg
#   inflating: train_sample_total/凸粉20180901101040对照样本_01.jpg
#   inflating: __MACOSX/train_sample_total/._凸粉20180901101040对照样本_01.jpg
#   inflating: train_sample_total/碰伤20180905091422对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._碰伤20180905091422对照样本_02.jpg
#   inflating: train_sample_total/漏底20180908105408对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._漏底20180908105408对照样本_02.jpg
#   inflating: train_sample_total/脏点20180907153736对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._脏点20180907153736对照样本_02.jpg
#   inflating: train_sample_total/正常20180914111207对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._正常20180914111207对照样本_02.jpg
#   inflating: train_sample_total/正常20180915153130对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._正常20180915153130对照样本_02.jpg
#   inflating: train_sample_total/正常20180914142455对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._正常20180914142455对照样本_02.jpg
#   inflating: train_sample_total/正常20180915161017对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._正常20180915161017对照样本_02.jpg
#   inflating: train_sample_total/凸粉20180901140859对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._凸粉20180901140859对照样本_02.jpg
#   inflating: train_sample_total/脏点20180831150651对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._脏点20180831150651对照样本_02.jpg
#   inflating: train_sample_total/正常20180914102051对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._正常20180914102051对照样本_02.jpg
#   inflating: train_sample_total/脏点20180903100813对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._脏点20180903100813对照样本_02.jpg
#   inflating: train_sample_total/正常20180913151859对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._正常20180913151859对照样本_02.jpg
#   inflating: train_sample_total/其他_气泡20180912142436对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._其他_气泡20180912142436对照样本_02.jpg
#   inflating: train_sample_total/脏点20180911104624对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._脏点20180911104624对照样本_02.jpg
#   inflating: train_sample_total/正常20180915144259对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._正常20180915144259对照样本_02.jpg
#   inflating: train_sample_total/脏点20180907111904对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._脏点20180907111904对照样本_02.jpg
#   inflating: train_sample_total/正常20180915143812对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._正常20180915143812对照样本_02.jpg
#   inflating: train_sample_total/桔皮20180912165437对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._桔皮20180912165437对照样本_02.jpg
#   inflating: train_sample_total/漏底20180910102909对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._漏底20180910102909对照样本_02.jpg
#   inflating: train_sample_total/不导电20180831104008对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._不导电20180831104008对照样本_02.jpg
#   inflating: train_sample_total/正常20180914102127对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._正常20180914102127对照样本_02.jpg
#   inflating: train_sample_total/漏底20180901094125对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._漏底20180901094125对照样本_02.jpg
#   inflating: train_sample_total/其他_纹粗20180830142143对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._其他_纹粗20180830142143对照样本_02.jpg
#   inflating: train_sample_total/正常20180914142514对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._正常20180914142514对照样本_02.jpg
#   inflating: train_sample_total/正常20180915145710对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._正常20180915145710对照样本_02.jpg
#   inflating: train_sample_total/其他_碰凹20180901103722对照样本_01.jpg
#   inflating: __MACOSX/train_sample_total/._其他_碰凹20180901103722对照样本_01.jpg
#   inflating: train_sample_total/擦花20180831110057对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._擦花20180831110057对照样本_02.jpg
#   inflating: train_sample_total/漏底20180908105549对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._漏底20180908105549对照样本_02.jpg
#   inflating: train_sample_total/其他_纹粗20180907162304对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._其他_纹粗20180907162304对照样本_02.jpg
#   inflating: train_sample_total/漏底20180829172517对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._漏底20180829172517对照样本_02.jpg
#   inflating: train_sample_total/正常20180914142400对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._正常20180914142400对照样本_02.jpg
#   inflating: train_sample_total/漏底20180830162452对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._漏底20180830162452对照样本_02.jpg
#   inflating: train_sample_total/正常20180914094119对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._正常20180914094119对照样本_02.jpg
#   inflating: train_sample_total/正常20180915142950对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._正常20180915142950对照样本_02.jpg
#   inflating: train_sample_total/脏点20180911140428对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._脏点20180911140428对照样本_02.jpg
#   inflating: train_sample_total/起坑20180905110120对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._起坑20180905110120对照样本_02.jpg
#   inflating: train_sample_total/正常20180914144026对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._正常20180914144026对照样本_02.jpg
#   inflating: train_sample_total/正常20180913142217对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._正常20180913142217对照样本_02.jpg
#   inflating: train_sample_total/正常20180914144539对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._正常20180914144539对照样本_02.jpg
#   inflating: train_sample_total/漏底20180912162826对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._漏底20180912162826对照样本_02.jpg
#   inflating: train_sample_total/脏点20180912161839对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._脏点20180912161839对照样本_02.jpg
#   inflating: train_sample_total/脏点20180910093038对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._脏点20180910093038对照样本_02.jpg
#   inflating: train_sample_total/正常20180914152653对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._正常20180914152653对照样本_02.jpg
#   inflating: train_sample_total/其他_打白点20180907145432对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._其他_打白点20180907145432对照样本_02.jpg
#   inflating: train_sample_total/漏底20180901091854对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._漏底20180901091854对照样本_02.jpg
#   inflating: train_sample_total/正常20180913163045对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._正常20180913163045对照样本_02.jpg
#   inflating: train_sample_total/正常20180914145631对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._正常20180914145631对照样本_02.jpg
#   inflating: train_sample_total/正常20180913172953对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._正常20180913172953对照样本_02.jpg
#   inflating: train_sample_total/正常20180915154515对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._正常20180915154515对照样本_02.jpg
#   inflating: train_sample_total/脏点20180910100019对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._脏点20180910100019对照样本_02.jpg
#   inflating: train_sample_total/正常20180913171433对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._正常20180913171433对照样本_02.jpg
#   inflating: train_sample_total/其他_油渣20180910104442对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._其他_油渣20180910104442对照样本_02.jpg
#   inflating: train_sample_total/漏底20180901095542对照样本_01.jpg
#   inflating: __MACOSX/train_sample_total/._漏底20180901095542对照样本_01.jpg
#   inflating: train_sample_total/正常20180914101036对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._正常20180914101036对照样本_02.jpg
#   inflating: train_sample_total/擦花20180901105534对照样本_01.jpg
#   inflating: __MACOSX/train_sample_total/._擦花20180901105534对照样本_01.jpg
#   inflating: train_sample_total/擦花20180914162738对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._擦花20180914162738对照样本_02.jpg
#   inflating: train_sample_total/正常20180915143240对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._正常20180915143240对照样本_02.jpg
#   inflating: train_sample_total/脏点20180831143955对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._脏点20180831143955对照样本_02.jpg
#   inflating: train_sample_total/脏点20180913105749对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._脏点20180913105749对照样本_02.jpg
#   inflating: train_sample_total/正常20180914135913对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._正常20180914135913对照样本_02.jpg
#   inflating: train_sample_total/正常20180913142520对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._正常20180913142520对照样本_02.jpg
#   inflating: train_sample_total/正常20180914141450对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._正常20180914141450对照样本_02.jpg
#   inflating: train_sample_total/擦花20180901141210对照样本_01.jpg
#   inflating: __MACOSX/train_sample_total/._擦花20180901141210对照样本_01.jpg
#   inflating: train_sample_total/脏点20180913105417对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._脏点20180913105417对照样本_02.jpg
#   inflating: train_sample_total/其他_碰凹20180901104059对照样本_01.jpg
#   inflating: __MACOSX/train_sample_total/._其他_碰凹20180901104059对照样本_01.jpg
#   inflating: train_sample_total/其他_油渣20180906141644对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._其他_油渣20180906141644对照样本_02.jpg
#   inflating: train_sample_total/正常20180914104236对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._正常20180914104236对照样本_02.jpg
#   inflating: train_sample_total/正常20180914104729对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._正常20180914104729对照样本_02.jpg
#   inflating: train_sample_total/凸粉20180901110602对照样本_01.jpg
#   inflating: __MACOSX/train_sample_total/._凸粉20180901110602对照样本_01.jpg
#   inflating: train_sample_total/正常20180913163335对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._正常20180913163335对照样本_02.jpg
#   inflating: train_sample_total/擦花20180912095148对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._擦花20180912095148对照样本_02.jpg
#   inflating: train_sample_total/正常20180914104113对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._正常20180914104113对照样本_02.jpg
#   inflating: train_sample_total/擦花20180901140636对照样本_01.jpg
#   inflating: __MACOSX/train_sample_total/._擦花20180901140636对照样本_01.jpg
#   inflating: train_sample_total/起坑20180906141101对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._起坑20180906141101对照样本_02.jpg
#   inflating: train_sample_total/正常20180913164949对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._正常20180913164949对照样本_02.jpg
#   inflating: train_sample_total/正常20180915155633对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._正常20180915155633对照样本_02.jpg
#   inflating: train_sample_total/漏底20180915095431对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._漏底20180915095431对照样本_02.jpg
#   inflating: train_sample_total/脏点20180910100037对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._脏点20180910100037对照样本_02.jpg
#   inflating: train_sample_total/正常20180913142632对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._正常20180913142632对照样本_02.jpg
#   inflating: train_sample_total/正常20180915144953对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._正常20180915144953对照样本_02.jpg
#   inflating: train_sample_total/碰伤20180906144422对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._碰伤20180906144422对照样本_02.jpg
#   inflating: train_sample_total/正常20180913142150对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._正常20180913142150对照样本_02.jpg
#   inflating: train_sample_total/正常20180914144220对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._正常20180914144220对照样本_02.jpg
#   inflating: train_sample_total/漏底20180901094319对照样本_01.jpg
#   inflating: __MACOSX/train_sample_total/._漏底20180901094319对照样本_01.jpg
#   inflating: train_sample_total/正常20180913154131对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._正常20180913154131对照样本_02.jpg
#   inflating: train_sample_total/正常20180914140023对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._正常20180914140023对照样本_02.jpg
#   inflating: train_sample_total/正常20180915160936对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._正常20180915160936对照样本_02.jpg
#   inflating: train_sample_total/擦花20180911110731对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._擦花20180911110731对照样本_02.jpg
#   inflating: train_sample_total/正常20180914100427对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._正常20180914100427对照样本_02.jpg
#   inflating: train_sample_total/正常20180914102911对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._正常20180914102911对照样本_02.jpg
#   inflating: train_sample_total/其他_气泡20180829172950对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._其他_气泡20180829172950对照样本_02.jpg
#   inflating: train_sample_total/正常20180914144149对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._正常20180914144149对照样本_02.jpg
#   inflating: train_sample_total/脏点20180907111539对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._脏点20180907111539对照样本_02.jpg
#   inflating: train_sample_total/正常20180914140428对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._正常20180914140428对照样本_02.jpg
#   inflating: train_sample_total/漏底20180908095435对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._漏底20180908095435对照样本_02.jpg
#   inflating: train_sample_total/正常20180915143107对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._正常20180915143107对照样本_02.jpg
#   inflating: train_sample_total/漏底20180901092050对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._漏底20180901092050对照样本_02.jpg
#   inflating: train_sample_total/脏点20180910093448对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._脏点20180910093448对照样本_02.jpg
#   inflating: train_sample_total/漏底20180912160157对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._漏底20180912160157对照样本_02.jpg
#   inflating: train_sample_total/擦花20180901141803对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._擦花20180901141803对照样本_02.jpg
#   inflating: train_sample_total/正常20180913142650对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._正常20180913142650对照样本_02.jpg
#   inflating: train_sample_total/碰伤20180910104837对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._碰伤20180910104837对照样本_02.jpg
#   inflating: train_sample_total/不导电20180831102813对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._不导电20180831102813对照样本_02.jpg
#   inflating: train_sample_total/正常20180914142725对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._正常20180914142725对照样本_02.jpg
#   inflating: train_sample_total/碰伤20180905091646对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._碰伤20180905091646对照样本_02.jpg
#   inflating: train_sample_total/桔皮20180912163904对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._桔皮20180912163904对照样本_02.jpg
#   inflating: train_sample_total/漏底20180830135205对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._漏底20180830135205对照样本_02.jpg
#   inflating: train_sample_total/正常20180913153455对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._正常20180913153455对照样本_02.jpg
#   inflating: train_sample_total/桔皮20180912165319对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._桔皮20180912165319对照样本_02.jpg
#   inflating: train_sample_total/脏点20180910095059对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._脏点20180910095059对照样本_02.jpg
#   inflating: train_sample_total/正常20180915160331对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._正常20180915160331对照样本_02.jpg
#   inflating: train_sample_total/漏底20180901095342对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._漏底20180901095342对照样本_02.jpg
#   inflating: train_sample_total/起坑20180905103731对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._起坑20180905103731对照样本_02.jpg
#   inflating: train_sample_total/擦花20180831110533对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._擦花20180831110533对照样本_02.jpg
#   inflating: train_sample_total/凸粉20180901101452对照样本_01.jpg
#   inflating: __MACOSX/train_sample_total/._凸粉20180901101452对照样本_01.jpg
#   inflating: train_sample_total/起坑20180905103053对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._起坑20180905103053对照样本_02.jpg
#   inflating: train_sample_total/横条压凹20180903111119对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._横条压凹20180903111119对照样本_02.jpg
#   inflating: train_sample_total/正常20180914101837对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._正常20180914101837对照样本_02.jpg
#   inflating: train_sample_total/擦花20180907103928对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._擦花20180907103928对照样本_02.jpg
#   inflating: train_sample_total/正常20180913172318对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._正常20180913172318对照样本_02.jpg
#   inflating: train_sample_total/其他_碰凹20180915105825对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._其他_碰凹20180915105825对照样本_02.jpg
#   inflating: train_sample_total/其他_纹粗20180830142251对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._其他_纹粗20180830142251对照样本_02.jpg
#   inflating: train_sample_total/正常20180915163951对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._正常20180915163951对照样本_02.jpg
#   inflating: train_sample_total/正常20180915165106对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._正常20180915165106对照样本_02.jpg
#   inflating: train_sample_total/脏点20180907104717对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._脏点20180907104717对照样本_02.jpg
#   inflating: train_sample_total/正常20180915145543对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._正常20180915145543对照样本_02.jpg
#   inflating: train_sample_total/凸粉20180901141408对照样本_01.jpg
#   inflating: __MACOSX/train_sample_total/._凸粉20180901141408对照样本_01.jpg
# ...
#   inflating: train_sample_total/其他_划伤20180912104706对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._其他_划伤20180912104706对照样本_02.jpg
#   inflating: train_sample_total/正常20180915154302对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._正常20180915154302对照样本_02.jpg
#   inflating: train_sample_total/正常20180913150155对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._正常20180913150155对照样本_02.jpg
#   inflating: train_sample_total/不导电20180831102726对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._不导电20180831102726对照样本_02.jpg
#   inflating: train_sample_total/漏底20180901091802对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._漏底20180901091802对照样本_02.jpg
#   inflating: train_sample_total/漏底20180912164133对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._漏底20180912164133对照样本_02.jpg
#   inflating: train_sample_total/其他_纹粗20180830141751对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._其他_纹粗20180830141751对照样本_02.jpg
#   inflating: train_sample_total/碰伤20180905091850对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._碰伤20180905091850对照样本_02.jpg
#   inflating: train_sample_total/起坑20180906140524对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._起坑20180906140524对照样本_02.jpg
#   inflating: train_sample_total/正常20180914105501对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._正常20180914105501对照样本_02.jpg
#   inflating: train_sample_total/正常20180914103127对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._正常20180914103127对照样本_02.jpg
#   inflating: train_sample_total/正常20180913135946对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._正常20180913135946对照样本_02.jpg
#   inflating: train_sample_total/正常20180913145725对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._正常20180913145725对照样本_02.jpg
#   inflating: train_sample_total/漏底20180901095358对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._漏底20180901095358对照样本_02.jpg
#   inflating: train_sample_total/横条压凹20180903104948对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._横条压凹20180903104948对照样本_02.jpg
#   inflating: train_sample_total/正常20180914154628对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._正常20180914154628对照样本_02.jpg
#   inflating: train_sample_total/正常20180914104926对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._正常20180914104926对照样本_02.jpg
#   inflating: train_sample_total/正常20180914094226对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._正常20180914094226对照样本_02.jpg
#   inflating: train_sample_total/漏底20180901094611对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._漏底20180901094611对照样本_02.jpg
#   inflating: train_sample_total/漏底20180830163213对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._漏底20180830163213对照样本_02.jpg
#   inflating: train_sample_total/不导电20180831104223对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._不导电20180831104223对照样本_02.jpg
#   inflating: train_sample_total/擦花20180901141814对照样本_01.jpg
#   inflating: __MACOSX/train_sample_total/._擦花20180901141814对照样本_01.jpg
#   inflating: train_sample_total/正常20180913140331对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._正常20180913140331对照样本_02.jpg
#   inflating: train_sample_total/横条压凹20180903111134对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._横条压凹20180903111134对照样本_02.jpg
#   inflating: train_sample_total/碰伤20180905091502对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._碰伤20180905091502对照样本_02.jpg
#   inflating: train_sample_total/正常20180913152258对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._正常20180913152258对照样本_02.jpg
#   inflating: train_sample_total/漏底20180901095006对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._漏底20180901095006对照样本_02.jpg
#   inflating: train_sample_total/其他_驳口20180906140308对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._其他_驳口20180906140308对照样本_02.jpg
#   inflating: train_sample_total/正常20180914102707对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._正常20180914102707对照样本_02.jpg
#   inflating: train_sample_total/正常20180913173401对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._正常20180913173401对照样本_02.jpg
#   inflating: train_sample_total/正常20180915152713对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._正常20180915152713对照样本_02.jpg
#   inflating: train_sample_total/正常20180914110718对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._正常20180914110718对照样本_02.jpg
#   inflating: train_sample_total/起坑20180905103108对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._起坑20180905103108对照样本_02.jpg
#   inflating: train_sample_total/漏底20180901095625对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._漏底20180901095625对照样本_02.jpg
#   inflating: train_sample_total/漏底20180901094439对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._漏底20180901094439对照样本_02.jpg
#   inflating: train_sample_total/正常20180915143826对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._正常20180915143826对照样本_02.jpg
#   inflating: train_sample_total/正常20180914102646对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._正常20180914102646对照样本_02.jpg
#   inflating: train_sample_total/漏底20180901091344对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._漏底20180901091344对照样本_02.jpg
#   inflating: train_sample_total/正常20180914103145对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._正常20180914103145对照样本_02.jpg
#   inflating: train_sample_total/正常20180914105925对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._正常20180914105925对照样本_02.jpg
#   inflating: train_sample_total/正常20180913153132对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._正常20180913153132对照样本_02.jpg
#   inflating: train_sample_total/正常20180914111251对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._正常20180914111251对照样本_02.jpg
#   inflating: train_sample_total/漏底20180908104120对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._漏底20180908104120对照样本_02.jpg
#   inflating: train_sample_total/桔皮20180912161637对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._桔皮20180912161637对照样本_02.jpg
#   inflating: train_sample_total/正常20180915162809对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._正常20180915162809对照样本_02.jpg
#   inflating: train_sample_total/漏底20180901095706对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._漏底20180901095706对照样本_02.jpg
#   inflating: train_sample_total/凸粉20180901141019对照样本_01.jpg
#   inflating: __MACOSX/train_sample_total/._凸粉20180901141019对照样本_01.jpg
#   inflating: train_sample_total/桔皮20180912165242对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._桔皮20180912165242对照样本_02.jpg
#   inflating: train_sample_total/涂层开裂20180905150415对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._涂层开裂20180905150415对照样本_02.jpg
#   inflating: train_sample_total/漏底20180901091514对照样本_01.jpg
#   inflating: __MACOSX/train_sample_total/._漏底20180901091514对照样本_01.jpg
#   inflating: train_sample_total/横条压凹20180903104225对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._横条压凹20180903104225对照样本_02.jpg
#   inflating: train_sample_total/漏底20180901095717对照样本_01.jpg
#   inflating: __MACOSX/train_sample_total/._漏底20180901095717对照样本_01.jpg
#   inflating: train_sample_total/擦花20180831110832对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._擦花20180831110832对照样本_02.jpg
#   inflating: train_sample_total/脏点20180912100912对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._脏点20180912100912对照样本_02.jpg
#   inflating: train_sample_total/正常20180915145934对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._正常20180915145934对照样本_02.jpg
#   inflating: train_sample_total/正常20180913144901对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._正常20180913144901对照样本_02.jpg
#   inflating: train_sample_total/漏底20180901091241对照样本_01.jpg
#   inflating: __MACOSX/train_sample_total/._漏底20180901091241对照样本_01.jpg
#   inflating: train_sample_total/正常20180914144526对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._正常20180914144526对照样本_02.jpg
#   inflating: train_sample_total/不导电20180831103739对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._不导电20180831103739对照样本_02.jpg
#   inflating: train_sample_total/正常20180914135959对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._正常20180914135959对照样本_02.jpg
#   inflating: train_sample_total/正常20180913162352对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._正常20180913162352对照样本_02.jpg
#   inflating: train_sample_total/正常20180915162453对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._正常20180915162453对照样本_02.jpg
#   inflating: train_sample_total/正常20180915163350对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._正常20180915163350对照样本_02.jpg
#   inflating: train_sample_total/不导电20180830131827对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._不导电20180830131827对照样本_02.jpg
#   inflating: train_sample_total/正常20180915144841对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._正常20180915144841对照样本_02.jpg
#   inflating: train_sample_total/漏底20180901091437对照样本_01.jpg
#   inflating: __MACOSX/train_sample_total/._漏底20180901091437对照样本_01.jpg
#   inflating: train_sample_total/正常20180915150335对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._正常20180915150335对照样本_02.jpg
#   inflating: train_sample_total/漏底20180901094428对照样本_01.jpg
#   inflating: __MACOSX/train_sample_total/._漏底20180901094428对照样本_01.jpg
#   inflating: train_sample_total/漏底20180901093000对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._漏底20180901093000对照样本_02.jpg
#   inflating: train_sample_total/正常20180914101201对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._正常20180914101201对照样本_02.jpg
#   inflating: train_sample_total/凸粉20180901101146对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._凸粉20180901101146对照样本_02.jpg
#   inflating: train_sample_total/漏底20180901095017对照样本_01.jpg
#   inflating: __MACOSX/train_sample_total/._漏底20180901095017对照样本_01.jpg
#   inflating: train_sample_total/正常20180914141632对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._正常20180914141632对照样本_02.jpg
#   inflating: train_sample_total/其他_碰凹20180901104559对照样本_01.jpg
#   inflating: __MACOSX/train_sample_total/._其他_碰凹20180901104559对照样本_01.jpg
#   inflating: train_sample_total/涂层开裂20180905154947对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._涂层开裂20180905154947对照样本_02.jpg
#   inflating: train_sample_total/漏底20180901095508对照样本_01.jpg
#   inflating: __MACOSX/train_sample_total/._漏底20180901095508对照样本_01.jpg
#   inflating: train_sample_total/正常20180914104054对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._正常20180914104054对照样本_02.jpg
#   inflating: train_sample_total/漏底20180901091541对照样本_01.jpg
#   inflating: __MACOSX/train_sample_total/._漏底20180901091541对照样本_01.jpg
#   inflating: train_sample_total/正常20180914100535对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._正常20180914100535对照样本_02.jpg
#   inflating: train_sample_total/漏底20180901094600对照样本_01.jpg
#   inflating: __MACOSX/train_sample_total/._漏底20180901094600对照样本_01.jpg
#   inflating: train_sample_total/正常20180914104615对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._正常20180914104615对照样本_02.jpg
#   inflating: train_sample_total/其他_铝屑20180906143741对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._其他_铝屑20180906143741对照样本_02.jpg
#   inflating: train_sample_total/正常20180914151933对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._正常20180914151933对照样本_02.jpg
#   inflating: train_sample_total/正常20180915143015对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._正常20180915143015对照样本_02.jpg
#   inflating: train_sample_total/擦花20180911143724对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._擦花20180911143724对照样本_02.jpg
#   inflating: train_sample_total/脏点20180911110926对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._脏点20180911110926对照样本_02.jpg
#   inflating: train_sample_total/桔皮20180830163813对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._桔皮20180830163813对照样本_02.jpg
#   inflating: train_sample_total/正常20180915161008对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._正常20180915161008对照样本_02.jpg
#   inflating: train_sample_total/正常20180915144307对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._正常20180915144307对照样本_02.jpg
#   inflating: train_sample_total/漏底20180829164328对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._漏底20180829164328对照样本_02.jpg
#   inflating: train_sample_total/正常20180915145404对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._正常20180915145404对照样本_02.jpg
#   inflating: train_sample_total/脏点20180907112012对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._脏点20180907112012对照样本_02.jpg
#   inflating: train_sample_total/正常20180913173348对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._正常20180913173348对照样本_02.jpg
#   inflating: train_sample_total/脏点20180910094435对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._脏点20180910094435对照样本_02.jpg
#   inflating: train_sample_total/正常20180914154042对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._正常20180914154042对照样本_02.jpg
#   inflating: train_sample_total/擦花20180911105706对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._擦花20180911105706对照样本_02.jpg
#   inflating: train_sample_total/正常20180915144224对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._正常20180915144224对照样本_02.jpg
#   inflating: train_sample_total/凸粉20180901101222对照样本_01.jpg
#   inflating: __MACOSX/train_sample_total/._凸粉20180901101222对照样本_01.jpg
#   inflating: train_sample_total/脏点20180831143130对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._脏点20180831143130对照样本_02.jpg
#   inflating: train_sample_total/漏底20180901095426对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._漏底20180901095426对照样本_02.jpg
#   inflating: train_sample_total/脏点20180831163220对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._脏点20180831163220对照样本_02.jpg
#   inflating: train_sample_total/正常20180914154449对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._正常20180914154449对照样本_02.jpg
#   inflating: train_sample_total/不导电20180831104208对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._不导电20180831104208对照样本_02.jpg
#   inflating: train_sample_total/正常20180915144213对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._正常20180915144213对照样本_02.jpg
#   inflating: train_sample_total/正常20180915143858对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._正常20180915143858对照样本_02.jpg
#   inflating: train_sample_total/碰伤20180905094554对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._碰伤20180905094554对照样本_02.jpg
#   inflating: train_sample_total/擦花20180911141636对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._擦花20180911141636对照样本_02.jpg
#   inflating: train_sample_total/漏底20180901092039对照样本_01.jpg
#   inflating: __MACOSX/train_sample_total/._漏底20180901092039对照样本_01.jpg
#   inflating: train_sample_total/正常20180915140727对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._正常20180915140727对照样本_02.jpg
#   inflating: train_sample_total/正常20180914100926对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._正常20180914100926对照样本_02.jpg
#   inflating: train_sample_total/正常20180914154103对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._正常20180914154103对照样本_02.jpg
#   inflating: train_sample_total/正常20180914110733对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._正常20180914110733对照样本_02.jpg
#   inflating: train_sample_total/正常20180914111030对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._正常20180914111030对照样本_02.jpg
#   inflating: train_sample_total/正常20180914143042对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._正常20180914143042对照样本_02.jpg
#   inflating: train_sample_total/漏底20180901095639对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._漏底20180901095639对照样本_02.jpg
#   inflating: train_sample_total/漏底20180901095326对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._漏底20180901095326对照样本_02.jpg
#   inflating: train_sample_total/正常20180914095711对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._正常20180914095711对照样本_02.jpg
#   inflating: train_sample_total/正常20180913162955对照样本_02.jpg
#   inflating: __MACOSX/train_sample_total/._正常20180913162955对照样本_02.jpg

# %%
# !rm --rf train_sample_total.zip
# Out:
# rm: unrecognized option '--rf'
# Try 'rm --help' for more information.

# %%
# !rm -rf __MACOSX

# %%
# !cp 'drive/My Drive/kaggle/ali/manu_big_data/guangdong_round1_test_a_20180916.zip' .

# %%
# !unzip guangdong_round1_test_a_20180916.zip
# Out:
# Archive:  guangdong_round1_test_a_20180916.zip
#    creating: guangdong_round1_test_a_20180916/
#   inflating: guangdong_round1_test_a_20180916/0.jpg
#  extracting: guangdong_round1_test_a_20180916/1.jpg
#   inflating: guangdong_round1_test_a_20180916/10.jpg
#  extracting: guangdong_round1_test_a_20180916/100.jpg
#   inflating: guangdong_round1_test_a_20180916/101.jpg
#   inflating: guangdong_round1_test_a_20180916/102.jpg
#   inflating: guangdong_round1_test_a_20180916/103.jpg
#   inflating: guangdong_round1_test_a_20180916/104.jpg
#   inflating: guangdong_round1_test_a_20180916/105.jpg
#   inflating: guangdong_round1_test_a_20180916/106.jpg
#   inflating: guangdong_round1_test_a_20180916/107.jpg
#   inflating: guangdong_round1_test_a_20180916/108.jpg
#   inflating: guangdong_round1_test_a_20180916/109.jpg
#   inflating: guangdong_round1_test_a_20180916/11.jpg
#  extracting: guangdong_round1_test_a_20180916/110.jpg
#  extracting: guangdong_round1_test_a_20180916/111.jpg
#  extracting: guangdong_round1_test_a_20180916/112.jpg
#   inflating: guangdong_round1_test_a_20180916/113.jpg
#   inflating: guangdong_round1_test_a_20180916/114.jpg
#   inflating: guangdong_round1_test_a_20180916/115.jpg
#  extracting: guangdong_round1_test_a_20180916/116.jpg
#   inflating: guangdong_round1_test_a_20180916/117.jpg
#   inflating: guangdong_round1_test_a_20180916/118.jpg
#   inflating: guangdong_round1_test_a_20180916/119.jpg
#   inflating: guangdong_round1_test_a_20180916/12.jpg
#  extracting: guangdong_round1_test_a_20180916/120.jpg
#  extracting: guangdong_round1_test_a_20180916/121.jpg
#   inflating: guangdong_round1_test_a_20180916/122.jpg
#   inflating: guangdong_round1_test_a_20180916/123.jpg
#   inflating: guangdong_round1_test_a_20180916/124.jpg
#  extracting: guangdong_round1_test_a_20180916/125.jpg
#  extracting: guangdong_round1_test_a_20180916/126.jpg
#  extracting: guangdong_round1_test_a_20180916/127.jpg
#  extracting: guangdong_round1_test_a_20180916/128.jpg
#   inflating: guangdong_round1_test_a_20180916/129.jpg
#   inflating: guangdong_round1_test_a_20180916/13.jpg
#  extracting: guangdong_round1_test_a_20180916/130.jpg
#   inflating: guangdong_round1_test_a_20180916/131.jpg
#  extracting: guangdong_round1_test_a_20180916/132.jpg
#   inflating: guangdong_round1_test_a_20180916/133.jpg
#   inflating: guangdong_round1_test_a_20180916/134.jpg
#   inflating: guangdong_round1_test_a_20180916/135.jpg
#  extracting: guangdong_round1_test_a_20180916/136.jpg
#   inflating: guangdong_round1_test_a_20180916/137.jpg
#   inflating: guangdong_round1_test_a_20180916/138.jpg
#   inflating: guangdong_round1_test_a_20180916/139.jpg
#   inflating: guangdong_round1_test_a_20180916/14.jpg
#  extracting: guangdong_round1_test_a_20180916/140.jpg
#   inflating: guangdong_round1_test_a_20180916/141.jpg
#   inflating: guangdong_round1_test_a_20180916/142.jpg
#   inflating: guangdong_round1_test_a_20180916/143.jpg
#   inflating: guangdong_round1_test_a_20180916/144.jpg
#   inflating: guangdong_round1_test_a_20180916/145.jpg
#  extracting: guangdong_round1_test_a_20180916/146.jpg
#   inflating: guangdong_round1_test_a_20180916/147.jpg
#   inflating: guangdong_round1_test_a_20180916/148.jpg
#  extracting: guangdong_round1_test_a_20180916/149.jpg
#  extracting: guangdong_round1_test_a_20180916/15.jpg
#   inflating: guangdong_round1_test_a_20180916/150.jpg
#   inflating: guangdong_round1_test_a_20180916/151.jpg
#   inflating: guangdong_round1_test_a_20180916/152.jpg
#   inflating: guangdong_round1_test_a_20180916/153.jpg
#   inflating: guangdong_round1_test_a_20180916/154.jpg
#   inflating: guangdong_round1_test_a_20180916/155.jpg
#   inflating: guangdong_round1_test_a_20180916/156.jpg
#   inflating: guangdong_round1_test_a_20180916/157.jpg
#   inflating: guangdong_round1_test_a_20180916/158.jpg
#   inflating: guangdong_round1_test_a_20180916/159.jpg
#   inflating: guangdong_round1_test_a_20180916/16.jpg
#   inflating: guangdong_round1_test_a_20180916/160.jpg
#   inflating: guangdong_round1_test_a_20180916/161.jpg
#   inflating: guangdong_round1_test_a_20180916/162.jpg
#   inflating: guangdong_round1_test_a_20180916/163.jpg
#   inflating: guangdong_round1_test_a_20180916/164.jpg
#   inflating: guangdong_round1_test_a_20180916/165.jpg
#   inflating: guangdong_round1_test_a_20180916/166.jpg
#   inflating: guangdong_round1_test_a_20180916/167.jpg
#   inflating: guangdong_round1_test_a_20180916/168.jpg
#  extracting: guangdong_round1_test_a_20180916/169.jpg
#  extracting: guangdong_round1_test_a_20180916/17.jpg
#   inflating: guangdong_round1_test_a_20180916/170.jpg
#   inflating: guangdong_round1_test_a_20180916/171.jpg
#   inflating: guangdong_round1_test_a_20180916/172.jpg
#   inflating: guangdong_round1_test_a_20180916/173.jpg
#  extracting: guangdong_round1_test_a_20180916/174.jpg
#   inflating: guangdong_round1_test_a_20180916/175.jpg
#   inflating: guangdong_round1_test_a_20180916/176.jpg
#   inflating: guangdong_round1_test_a_20180916/177.jpg
#   inflating: guangdong_round1_test_a_20180916/178.jpg
#   inflating: guangdong_round1_test_a_20180916/179.jpg
#   inflating: guangdong_round1_test_a_20180916/18.jpg
#   inflating: guangdong_round1_test_a_20180916/180.jpg
#  extracting: guangdong_round1_test_a_20180916/181.jpg
#   inflating: guangdong_round1_test_a_20180916/182.jpg
#   inflating: guangdong_round1_test_a_20180916/183.jpg
#  extracting: guangdong_round1_test_a_20180916/184.jpg
#  extracting: guangdong_round1_test_a_20180916/185.jpg
#   inflating: guangdong_round1_test_a_20180916/186.jpg
#  extracting: guangdong_round1_test_a_20180916/187.jpg
#   inflating: guangdong_round1_test_a_20180916/188.jpg
#   inflating: guangdong_round1_test_a_20180916/189.jpg
#   inflating: guangdong_round1_test_a_20180916/19.jpg
#   inflating: guangdong_round1_test_a_20180916/190.jpg
#  extracting: guangdong_round1_test_a_20180916/191.jpg
#   inflating: guangdong_round1_test_a_20180916/192.jpg
#   inflating: guangdong_round1_test_a_20180916/193.jpg
#   inflating: guangdong_round1_test_a_20180916/194.jpg
#   inflating: guangdong_round1_test_a_20180916/195.jpg
#  extracting: guangdong_round1_test_a_20180916/196.jpg
#   inflating: guangdong_round1_test_a_20180916/197.jpg
#   inflating: guangdong_round1_test_a_20180916/198.jpg
#   inflating: guangdong_round1_test_a_20180916/199.jpg
#   inflating: guangdong_round1_test_a_20180916/2.jpg
#  extracting: guangdong_round1_test_a_20180916/20.jpg
#   inflating: guangdong_round1_test_a_20180916/200.jpg
#   inflating: guangdong_round1_test_a_20180916/201.jpg
#   inflating: guangdong_round1_test_a_20180916/202.jpg
#   inflating: guangdong_round1_test_a_20180916/203.jpg
#  extracting: guangdong_round1_test_a_20180916/204.jpg
#  extracting: guangdong_round1_test_a_20180916/205.jpg
#   inflating: guangdong_round1_test_a_20180916/206.jpg
#   inflating: guangdong_round1_test_a_20180916/207.jpg
#  extracting: guangdong_round1_test_a_20180916/208.jpg
#   inflating: guangdong_round1_test_a_20180916/209.jpg
#   inflating: guangdong_round1_test_a_20180916/21.jpg
#   inflating: guangdong_round1_test_a_20180916/210.jpg
#  extracting: guangdong_round1_test_a_20180916/211.jpg
#  extracting: guangdong_round1_test_a_20180916/212.jpg
#   inflating: guangdong_round1_test_a_20180916/213.jpg
#   inflating: guangdong_round1_test_a_20180916/214.jpg
#  extracting: guangdong_round1_test_a_20180916/215.jpg
#   inflating: guangdong_round1_test_a_20180916/216.jpg
#   inflating: guangdong_round1_test_a_20180916/217.jpg
#   inflating: guangdong_round1_test_a_20180916/218.jpg
#  extracting: guangdong_round1_test_a_20180916/219.jpg
#  extracting: guangdong_round1_test_a_20180916/22.jpg
#  extracting: guangdong_round1_test_a_20180916/220.jpg
#   inflating: guangdong_round1_test_a_20180916/221.jpg
#  extracting: guangdong_round1_test_a_20180916/222.jpg
#   inflating: guangdong_round1_test_a_20180916/223.jpg
#  extracting: guangdong_round1_test_a_20180916/224.jpg
#  extracting: guangdong_round1_test_a_20180916/225.jpg
#   inflating: guangdong_round1_test_a_20180916/226.jpg
#  extracting: guangdong_round1_test_a_20180916/227.jpg
#   inflating: guangdong_round1_test_a_20180916/228.jpg
#   inflating: guangdong_round1_test_a_20180916/229.jpg
#   inflating: guangdong_round1_test_a_20180916/23.jpg
#  extracting: guangdong_round1_test_a_20180916/230.jpg
#   inflating: guangdong_round1_test_a_20180916/231.jpg
#   inflating: guangdong_round1_test_a_20180916/232.jpg
#   inflating: guangdong_round1_test_a_20180916/233.jpg
#   inflating: guangdong_round1_test_a_20180916/234.jpg
#  extracting: guangdong_round1_test_a_20180916/235.jpg
#   inflating: guangdong_round1_test_a_20180916/236.jpg
#   inflating: guangdong_round1_test_a_20180916/237.jpg
#   inflating: guangdong_round1_test_a_20180916/238.jpg
#   inflating: guangdong_round1_test_a_20180916/239.jpg
#  extracting: guangdong_round1_test_a_20180916/24.jpg
#   inflating: guangdong_round1_test_a_20180916/240.jpg
#   inflating: guangdong_round1_test_a_20180916/241.jpg
#   inflating: guangdong_round1_test_a_20180916/242.jpg
#   inflating: guangdong_round1_test_a_20180916/243.jpg
#   inflating: guangdong_round1_test_a_20180916/244.jpg
#   inflating: guangdong_round1_test_a_20180916/245.jpg
#   inflating: guangdong_round1_test_a_20180916/246.jpg
#   inflating: guangdong_round1_test_a_20180916/247.jpg
#  extracting: guangdong_round1_test_a_20180916/248.jpg
#  extracting: guangdong_round1_test_a_20180916/249.jpg
#  extracting: guangdong_round1_test_a_20180916/25.jpg
#   inflating: guangdong_round1_test_a_20180916/250.jpg
#   inflating: guangdong_round1_test_a_20180916/251.jpg
#  extracting: guangdong_round1_test_a_20180916/252.jpg
#   inflating: guangdong_round1_test_a_20180916/253.jpg
#   inflating: guangdong_round1_test_a_20180916/254.jpg
#   inflating: guangdong_round1_test_a_20180916/255.jpg
#  extracting: guangdong_round1_test_a_20180916/256.jpg
#   inflating: guangdong_round1_test_a_20180916/257.jpg
#  extracting: guangdong_round1_test_a_20180916/258.jpg
#   inflating: guangdong_round1_test_a_20180916/259.jpg
#   inflating: guangdong_round1_test_a_20180916/26.jpg
#   inflating: guangdong_round1_test_a_20180916/260.jpg
#   inflating: guangdong_round1_test_a_20180916/261.jpg
#  extracting: guangdong_round1_test_a_20180916/262.jpg
#   inflating: guangdong_round1_test_a_20180916/263.jpg
#   inflating: guangdong_round1_test_a_20180916/264.jpg
#   inflating: guangdong_round1_test_a_20180916/265.jpg
#   inflating: guangdong_round1_test_a_20180916/266.jpg
#  extracting: guangdong_round1_test_a_20180916/267.jpg
#  extracting: guangdong_round1_test_a_20180916/268.jpg
#  extracting: guangdong_round1_test_a_20180916/269.jpg
#  extracting: guangdong_round1_test_a_20180916/27.jpg
#   inflating: guangdong_round1_test_a_20180916/270.jpg
#  extracting: guangdong_round1_test_a_20180916/271.jpg
#   inflating: guangdong_round1_test_a_20180916/272.jpg
#   inflating: guangdong_round1_test_a_20180916/273.jpg
#   inflating: guangdong_round1_test_a_20180916/274.jpg
#  extracting: guangdong_round1_test_a_20180916/275.jpg
#   inflating: guangdong_round1_test_a_20180916/276.jpg
#   inflating: guangdong_round1_test_a_20180916/277.jpg
#  extracting: guangdong_round1_test_a_20180916/278.jpg
#  extracting: guangdong_round1_test_a_20180916/279.jpg
#   inflating: guangdong_round1_test_a_20180916/28.jpg
#   inflating: guangdong_round1_test_a_20180916/280.jpg
#   inflating: guangdong_round1_test_a_20180916/281.jpg
#  extracting: guangdong_round1_test_a_20180916/282.jpg
#   inflating: guangdong_round1_test_a_20180916/283.jpg
#   inflating: guangdong_round1_test_a_20180916/284.jpg
#   inflating: guangdong_round1_test_a_20180916/285.jpg
#   inflating: guangdong_round1_test_a_20180916/286.jpg
#  extracting: guangdong_round1_test_a_20180916/287.jpg
#   inflating: guangdong_round1_test_a_20180916/288.jpg
#  extracting: guangdong_round1_test_a_20180916/289.jpg
#   inflating: guangdong_round1_test_a_20180916/29.jpg
#   inflating: guangdong_round1_test_a_20180916/290.jpg
#  extracting: guangdong_round1_test_a_20180916/291.jpg
#   inflating: guangdong_round1_test_a_20180916/292.jpg
#   inflating: guangdong_round1_test_a_20180916/293.jpg
#   inflating: guangdong_round1_test_a_20180916/294.jpg
#   inflating: guangdong_round1_test_a_20180916/295.jpg
#   inflating: guangdong_round1_test_a_20180916/296.jpg
#   inflating: guangdong_round1_test_a_20180916/297.jpg
#   inflating: guangdong_round1_test_a_20180916/298.jpg
#   inflating: guangdong_round1_test_a_20180916/299.jpg
#   inflating: guangdong_round1_test_a_20180916/3.jpg
#  extracting: guangdong_round1_test_a_20180916/30.jpg
#   inflating: guangdong_round1_test_a_20180916/300.jpg
#   inflating: guangdong_round1_test_a_20180916/301.jpg
#   inflating: guangdong_round1_test_a_20180916/302.jpg
#   inflating: guangdong_round1_test_a_20180916/303.jpg
#   inflating: guangdong_round1_test_a_20180916/304.jpg
#   inflating: guangdong_round1_test_a_20180916/305.jpg
#  extracting: guangdong_round1_test_a_20180916/306.jpg
#  extracting: guangdong_round1_test_a_20180916/307.jpg
#   inflating: guangdong_round1_test_a_20180916/308.jpg
#   inflating: guangdong_round1_test_a_20180916/309.jpg
#   inflating: guangdong_round1_test_a_20180916/31.jpg
#   inflating: guangdong_round1_test_a_20180916/310.jpg
#   inflating: guangdong_round1_test_a_20180916/311.jpg
#   inflating: guangdong_round1_test_a_20180916/312.jpg
#   inflating: guangdong_round1_test_a_20180916/313.jpg
#   inflating: guangdong_round1_test_a_20180916/314.jpg
#  extracting: guangdong_round1_test_a_20180916/315.jpg
#   inflating: guangdong_round1_test_a_20180916/316.jpg
#   inflating: guangdong_round1_test_a_20180916/317.jpg
#  extracting: guangdong_round1_test_a_20180916/318.jpg
#   inflating: guangdong_round1_test_a_20180916/319.jpg
#   inflating: guangdong_round1_test_a_20180916/32.jpg
#  extracting: guangdong_round1_test_a_20180916/320.jpg
#   inflating: guangdong_round1_test_a_20180916/321.jpg
#   inflating: guangdong_round1_test_a_20180916/322.jpg
#  extracting: guangdong_round1_test_a_20180916/323.jpg
#   inflating: guangdong_round1_test_a_20180916/324.jpg
#   inflating: guangdong_round1_test_a_20180916/325.jpg
#   inflating: guangdong_round1_test_a_20180916/326.jpg
#   inflating: guangdong_round1_test_a_20180916/327.jpg
#   inflating: guangdong_round1_test_a_20180916/328.jpg
#   inflating: guangdong_round1_test_a_20180916/329.jpg
#   inflating: guangdong_round1_test_a_20180916/33.jpg
#  extracting: guangdong_round1_test_a_20180916/330.jpg
#   inflating: guangdong_round1_test_a_20180916/331.jpg
#   inflating: guangdong_round1_test_a_20180916/332.jpg
#   inflating: guangdong_round1_test_a_20180916/333.jpg
#  extracting: guangdong_round1_test_a_20180916/334.jpg
#   inflating: guangdong_round1_test_a_20180916/335.jpg
#   inflating: guangdong_round1_test_a_20180916/336.jpg
#   inflating: guangdong_round1_test_a_20180916/337.jpg
#  extracting: guangdong_round1_test_a_20180916/338.jpg
#   inflating: guangdong_round1_test_a_20180916/339.jpg
#   inflating: guangdong_round1_test_a_20180916/34.jpg
#   inflating: guangdong_round1_test_a_20180916/340.jpg
#   inflating: guangdong_round1_test_a_20180916/341.jpg
#  extracting: guangdong_round1_test_a_20180916/342.jpg
#   inflating: guangdong_round1_test_a_20180916/343.jpg
#  extracting: guangdong_round1_test_a_20180916/344.jpg
#   inflating: guangdong_round1_test_a_20180916/345.jpg
#   inflating: guangdong_round1_test_a_20180916/346.jpg
#   inflating: guangdong_round1_test_a_20180916/347.jpg
#   inflating: guangdong_round1_test_a_20180916/348.jpg
#   inflating: guangdong_round1_test_a_20180916/349.jpg
#   inflating: guangdong_round1_test_a_20180916/35.jpg
#   inflating: guangdong_round1_test_a_20180916/350.jpg
#   inflating: guangdong_round1_test_a_20180916/351.jpg
#   inflating: guangdong_round1_test_a_20180916/352.jpg
#   inflating: guangdong_round1_test_a_20180916/353.jpg
#   inflating: guangdong_round1_test_a_20180916/354.jpg
#   inflating: guangdong_round1_test_a_20180916/355.jpg
#   inflating: guangdong_round1_test_a_20180916/356.jpg
#   inflating: guangdong_round1_test_a_20180916/357.jpg
#  extracting: guangdong_round1_test_a_20180916/358.jpg
#   inflating: guangdong_round1_test_a_20180916/359.jpg
#  extracting: guangdong_round1_test_a_20180916/36.jpg
#   inflating: guangdong_round1_test_a_20180916/360.jpg
#  extracting: guangdong_round1_test_a_20180916/361.jpg
#   inflating: guangdong_round1_test_a_20180916/362.jpg
#  extracting: guangdong_round1_test_a_20180916/363.jpg
#   inflating: guangdong_round1_test_a_20180916/364.jpg
#   inflating: guangdong_round1_test_a_20180916/365.jpg
#   inflating: guangdong_round1_test_a_20180916/366.jpg
#   inflating: guangdong_round1_test_a_20180916/367.jpg
#  extracting: guangdong_round1_test_a_20180916/368.jpg
#   inflating: guangdong_round1_test_a_20180916/369.jpg
#   inflating: guangdong_round1_test_a_20180916/37.jpg
#   inflating: guangdong_round1_test_a_20180916/370.jpg
#   inflating: guangdong_round1_test_a_20180916/371.jpg
#  extracting: guangdong_round1_test_a_20180916/372.jpg
#   inflating: guangdong_round1_test_a_20180916/373.jpg
#   inflating: guangdong_round1_test_a_20180916/374.jpg
#   inflating: guangdong_round1_test_a_20180916/375.jpg
#   inflating: guangdong_round1_test_a_20180916/376.jpg
#   inflating: guangdong_round1_test_a_20180916/377.jpg
#   inflating: guangdong_round1_test_a_20180916/378.jpg
#   inflating: guangdong_round1_test_a_20180916/379.jpg
#   inflating: guangdong_round1_test_a_20180916/38.jpg
#   inflating: guangdong_round1_test_a_20180916/380.jpg
#   inflating: guangdong_round1_test_a_20180916/381.jpg
#   inflating: guangdong_round1_test_a_20180916/382.jpg
#   inflating: guangdong_round1_test_a_20180916/383.jpg
#   inflating: guangdong_round1_test_a_20180916/384.jpg
#   inflating: guangdong_round1_test_a_20180916/385.jpg
#   inflating: guangdong_round1_test_a_20180916/386.jpg
#   inflating: guangdong_round1_test_a_20180916/387.jpg
#   inflating: guangdong_round1_test_a_20180916/388.jpg
#   inflating: guangdong_round1_test_a_20180916/389.jpg
#   inflating: guangdong_round1_test_a_20180916/39.jpg
#   inflating: guangdong_round1_test_a_20180916/390.jpg
#  extracting: guangdong_round1_test_a_20180916/391.jpg
#   inflating: guangdong_round1_test_a_20180916/392.jpg
#   inflating: guangdong_round1_test_a_20180916/393.jpg
#   inflating: guangdong_round1_test_a_20180916/394.jpg
#   inflating: guangdong_round1_test_a_20180916/395.jpg
#   inflating: guangdong_round1_test_a_20180916/396.jpg
#   inflating: guangdong_round1_test_a_20180916/397.jpg
#  extracting: guangdong_round1_test_a_20180916/398.jpg
#  extracting: guangdong_round1_test_a_20180916/399.jpg
#   inflating: guangdong_round1_test_a_20180916/4.jpg
#  extracting: guangdong_round1_test_a_20180916/40.jpg
#   inflating: guangdong_round1_test_a_20180916/400.jpg
#  extracting: guangdong_round1_test_a_20180916/401.jpg
#   inflating: guangdong_round1_test_a_20180916/402.jpg
#   inflating: guangdong_round1_test_a_20180916/403.jpg
#  extracting: guangdong_round1_test_a_20180916/404.jpg
#   inflating: guangdong_round1_test_a_20180916/405.jpg
#   inflating: guangdong_round1_test_a_20180916/406.jpg
#  extracting: guangdong_round1_test_a_20180916/407.jpg
#   inflating: guangdong_round1_test_a_20180916/408.jpg
#   inflating: guangdong_round1_test_a_20180916/409.jpg
#   inflating: guangdong_round1_test_a_20180916/41.jpg
#   inflating: guangdong_round1_test_a_20180916/410.jpg
#   inflating: guangdong_round1_test_a_20180916/411.jpg
#  extracting: guangdong_round1_test_a_20180916/412.jpg
#   inflating: guangdong_round1_test_a_20180916/413.jpg
#  extracting: guangdong_round1_test_a_20180916/414.jpg
#   inflating: guangdong_round1_test_a_20180916/415.jpg
#   inflating: guangdong_round1_test_a_20180916/416.jpg
#   inflating: guangdong_round1_test_a_20180916/417.jpg
#   inflating: guangdong_round1_test_a_20180916/418.jpg
#  extracting: guangdong_round1_test_a_20180916/419.jpg
#  extracting: guangdong_round1_test_a_20180916/42.jpg
#   inflating: guangdong_round1_test_a_20180916/420.jpg
#  extracting: guangdong_round1_test_a_20180916/421.jpg
#  extracting: guangdong_round1_test_a_20180916/422.jpg
#   inflating: guangdong_round1_test_a_20180916/423.jpg
#   inflating: guangdong_round1_test_a_20180916/424.jpg
#  extracting: guangdong_round1_test_a_20180916/425.jpg
#  extracting: guangdong_round1_test_a_20180916/426.jpg
#   inflating: guangdong_round1_test_a_20180916/427.jpg
#   inflating: guangdong_round1_test_a_20180916/428.jpg
#   inflating: guangdong_round1_test_a_20180916/429.jpg
#   inflating: guangdong_round1_test_a_20180916/43.jpg
#   inflating: guangdong_round1_test_a_20180916/430.jpg
#   inflating: guangdong_round1_test_a_20180916/431.jpg
#   inflating: guangdong_round1_test_a_20180916/432.jpg
#   inflating: guangdong_round1_test_a_20180916/433.jpg
#   inflating: guangdong_round1_test_a_20180916/434.jpg
#  extracting: guangdong_round1_test_a_20180916/435.jpg
#   inflating: guangdong_round1_test_a_20180916/436.jpg
#  extracting: guangdong_round1_test_a_20180916/437.jpg
#   inflating: guangdong_round1_test_a_20180916/438.jpg
#   inflating: guangdong_round1_test_a_20180916/439.jpg
#  extracting: guangdong_round1_test_a_20180916/44.jpg
#   inflating: guangdong_round1_test_a_20180916/45.jpg
#   inflating: guangdong_round1_test_a_20180916/46.jpg
#   inflating: guangdong_round1_test_a_20180916/47.jpg
#   inflating: guangdong_round1_test_a_20180916/48.jpg
#   inflating: guangdong_round1_test_a_20180916/49.jpg
#   inflating: guangdong_round1_test_a_20180916/5.jpg
#  extracting: guangdong_round1_test_a_20180916/50.jpg
#   inflating: guangdong_round1_test_a_20180916/51.jpg
#  extracting: guangdong_round1_test_a_20180916/52.jpg
#   inflating: guangdong_round1_test_a_20180916/53.jpg
#  extracting: guangdong_round1_test_a_20180916/54.jpg
#  extracting: guangdong_round1_test_a_20180916/55.jpg
#   inflating: guangdong_round1_test_a_20180916/56.jpg
#  extracting: guangdong_round1_test_a_20180916/57.jpg
#   inflating: guangdong_round1_test_a_20180916/58.jpg
#   inflating: guangdong_round1_test_a_20180916/59.jpg
#   inflating: guangdong_round1_test_a_20180916/6.jpg
#  extracting: guangdong_round1_test_a_20180916/60.jpg
#   inflating: guangdong_round1_test_a_20180916/61.jpg
#   inflating: guangdong_round1_test_a_20180916/62.jpg
#  extracting: guangdong_round1_test_a_20180916/63.jpg
#   inflating: guangdong_round1_test_a_20180916/64.jpg
#   inflating: guangdong_round1_test_a_20180916/65.jpg
#  extracting: guangdong_round1_test_a_20180916/66.jpg
#   inflating: guangdong_round1_test_a_20180916/67.jpg
#   inflating: guangdong_round1_test_a_20180916/68.jpg
#   inflating: guangdong_round1_test_a_20180916/69.jpg
#   inflating: guangdong_round1_test_a_20180916/7.jpg
#   inflating: guangdong_round1_test_a_20180916/70.jpg
#  extracting: guangdong_round1_test_a_20180916/71.jpg
#   inflating: guangdong_round1_test_a_20180916/72.jpg
#   inflating: guangdong_round1_test_a_20180916/73.jpg
#   inflating: guangdong_round1_test_a_20180916/74.jpg
#  extracting: guangdong_round1_test_a_20180916/75.jpg
#  extracting: guangdong_round1_test_a_20180916/76.jpg
#   inflating: guangdong_round1_test_a_20180916/77.jpg
#   inflating: guangdong_round1_test_a_20180916/78.jpg
#   inflating: guangdong_round1_test_a_20180916/79.jpg
#   inflating: guangdong_round1_test_a_20180916/8.jpg
#   inflating: guangdong_round1_test_a_20180916/80.jpg
#   inflating: guangdong_round1_test_a_20180916/81.jpg
#   inflating: guangdong_round1_test_a_20180916/82.jpg
#  extracting: guangdong_round1_test_a_20180916/83.jpg
#  extracting: guangdong_round1_test_a_20180916/84.jpg
#   inflating: guangdong_round1_test_a_20180916/85.jpg
#  extracting: guangdong_round1_test_a_20180916/86.jpg
#   inflating: guangdong_round1_test_a_20180916/87.jpg
#  extracting: guangdong_round1_test_a_20180916/88.jpg
#   inflating: guangdong_round1_test_a_20180916/89.jpg
#   inflating: guangdong_round1_test_a_20180916/9.jpg
#   inflating: guangdong_round1_test_a_20180916/90.jpg
#   inflating: guangdong_round1_test_a_20180916/91.jpg
#  extracting: guangdong_round1_test_a_20180916/92.jpg
#   inflating: guangdong_round1_test_a_20180916/93.jpg
#   inflating: guangdong_round1_test_a_20180916/94.jpg
#  extracting: guangdong_round1_test_a_20180916/95.jpg
#   inflating: guangdong_round1_test_a_20180916/96.jpg
#  extracting: guangdong_round1_test_a_20180916/97.jpg
#   inflating: guangdong_round1_test_a_20180916/98.jpg
#  extracting: guangdong_round1_test_a_20180916/99.jpg

# %%
#!pip install -q keras

# %%
'''

need to upgrade keras first (version 2.2.2) it will include MobileNetV2
'''


import keras
print (keras.__version__)
import numpy as np
import matplotlib.pyplot as plt

import tensorflow as tf
import subprocess
import os
import pickle
import sklearn

from sklearn.model_selection import train_test_split

from xgboost.sklearn import XGBClassifier




import keras.backend as K

from keras.applications.inception_v3 import InceptionV3
from keras.applications.densenet import DenseNet121
#from keras.applications.mobilenet import MobileNet
#from keras.applications.mobilenetv2 import MobileNetV2,preprocess_input
#from keras.applications.nasnet import NASNetMobile,NASNetLarge
from keras.applications.vgg16 import VGG16
from keras.applications.resnet50 import ResNet50
from keras.preprocessing import image
from keras.applications.inception_resnet_v2 import InceptionResNetV2, preprocess_input
from keras.preprocessing.image import ImageDataGenerator,  img_to_array, load_img



#from keras.applications.xception import Xception, preprocess_input

from keras.layers import Dense, GlobalAveragePooling2D
from keras.layers import Input, Conv2D, MaxPooling2D, merge, Lambda,UpSampling2D, concatenate, Reshape, Dropout,Cropping2D,Activation
from keras.models import Model, load_model
import pandas as pd

from keras.callbacks import ModelCheckpoint,EarlyStopping
from keras.callbacks import Callback


from keras import regularizers
#from dummyPy import OneHotEncoder
from keras.utils import to_categorical

from sklearn.metrics import confusion_matrix

import itertools
import time


# In[ ]:


'''
First, copy train_sample_total.zip
unzip the file

need to change following dircetories according to your own settign
'''

#src_1= 'manu_big_data/'
#src_2= 'manu_big_data/train_sample_total/' #'train data directory'
#src_3 = 'manu_big_data/guangdong_round1_test_a_20180916/guangdong_round1_test_a_20180916/'  # test data directory
#src_save = 'manu_big_data/verification'



src_1= 'drive/My Drive/kaggle/ali/'
src_2= 'train_sample_total/' #'train data directory'
src_3 = 'guangdong_round1_test_a_20180916/'  # test data directory
src_save = 'drive/My Drive/kaggle/ali/manu_big_data/'


# In[ ]:

train_file_list = os.listdir(src_2)


print (len(train_file_list))# length should be 2386


# save file list
if not os.path.isfile(src_save+'train_file_list.pkl'):

    with open (src_save+'train_file_list.pkl','wb') as handle:
        pickle.dump(train_file_list, handle)
    print ('file_list saved')
else:
    print ('file list exists')

if '.DS_Store' in train_file_list:
    train_file_list.remove('.DS_Store')



def make_label_data(file_list):

    '''
    # get first 2 simplex character in all train_file_name (will be converted to file label)
    '''


    label_list = []
    for f in train_file_list:
        label_list.append(f[:2])
    print (len(label_list))



    # check how many failure categories
    uniq_label_list = list(set(label_list))
    print ('unique label list', len(uniq_label_list), uniq_label_list)


    '''
    convert failure category to label according to the instruction dict
    every category (2 charcter ) map to a label
    '''
    with open(src_1+'failure_to_label.pkl', 'rb') as handle:
        label_dict = pickle.load(handle)

        print (label_dict.keys())


    # label the image according to the defect type
    label_data = []
    for f in file_list:
        label_data.append(label_dict[f[:2]])
    label_data = np.array(label_data)
    label_df = pd.DataFrame (label_data)

    label_df.columns = ['label']



    # In[ ]:


    # Label Counts
    print (label_df['label'].value_counts())




    # In[ ]:

    '''
    label_data_0 : if label is 0 or not, if yes, means normal, if not means defect
    later will convert normal --True-- to '1',  defect --Fasle -- to '0'
    '''
    label_data_0 = (label_data ==0)
    label_data_0 = label_data_0*1
    print ('how many normal', sum(label_data_0))
    label_data_0[:10]

    return label_data, label_data_0


    # In[ ]:


train_label_data, train_label_data_0 = make_label_data(train_file_list)



with open (src_save+'train_label_data_verification.pkl','wb') as handle:
    pickle.dump(train_label_data, handle)
print ('label_data saved')
# Out:
# 2.1.6
# 2386
# file_list saved
# 2386
# unique label list 12 ['擦花', '凸粉', '正常', '起坑', '横条', '桔皮', '涂层', '其他', '碰伤', '脏点', '漏底', '不导']
# dict_keys(['正常', '不导', '擦花', '横条', '桔皮', '漏底', '碰伤', '起坑', '凸粉', '涂层', '脏点', '其他'])
# 0     1018
# 5      388
# 10     209
# 2      165
# 11     160
# 8      104
# 4       90
# 6       77
# 7       54
# 3       47
# 1       39
# 9       35
# Name: label, dtype: int64
# how many normal 1018
# label_data saved

# %%
'''
start to make train data
will us MobileNetV2,
two stage making
stage 1: will use logic layer (the layer before dense(1000))
stage 2: will use
'''



def build_model_1():
    inputs = Input(shape=(1920,2560,3))
    #inputs = Input(shape=(224,224,3))

    # create the base pre-trained model
    base_model = DenseNet121(weights='imagenet',input_tensor=inputs,  include_top=True)
    #base_model = MobileNetV2(weights='imagenet',input_tensor=inputs,  include_top=True)
    #base_model =load_model('drive/My Drive/'+'MobileNetV2.h5')

    '''
    #(get the desired layer)
    '''

    model_1_out = base_model.layers[-2].output



    model_1 = Model(inputs=base_model.input, outputs=model_1_out)
    model_1.summary()



    return model_1





# In[ ]:


model_1= build_model_1()



'''
following wil start to make train data
as the memory limited (in colab), need to seperate the bacth making to 5 or 7 (or will encounter OOM issue)

Theoreticlly, it is no need to seperate two steps for making train dataself.
However, again, due to memeory limitation issue.  make train data step by step
'''

'''
making stage 1, use model_1
'''

model_1.compile(optimizer='adam', loss='categorical_crossentropy',metrics=['accuracy'])


# In[ ]:






'''
following will make bacth list
will return a final_list, each element in the final_list will be a list of file names with bacth size as pre-defined
feed to model_1 one batch at a time
the total length of batch should be equal to file list

'''
def make_batch (file_list,batch_size):
  final_list =[]


  floor = int(np.floor(len(file_list)/batch_size))
  print ('floor=', floor)
  for i in range(floor+1):
      if i < floor:
          final_list.append(file_list[i*batch_size:(i+1)*batch_size])
      else:
          final_list.append(file_list[i*batch_size:])


  # check whther the bach making final_llist len equal to file_list
  a =0
  for l in final_list:
    #print (len(l))
    #print (l[-10:])
    a += len(l)
  if (a - len(final_list) == 0):
    print ('total size', a, 'final_list length equal to file_list')
  else:
    print ('total size', a, 'file_list', len(file_list),'final_list length NOT equal to file_list')
    print (a - len(file_list))
    print ('warning, something wrong')

  return final_list


# In[ ]:





def make_data(file_list,model,src):

    '''
    first make bacth, then make data
    '''
    batch_size = 7
    final_list = make_batch(file_list,batch_size)
    print (len(final_list))




    '''
    make data
    '''

    s= time.time()  # count timing
    final_array = []  # the target array of trainging data
    for j,l in enumerate(final_list):
          img_list=[]
          for i,img in enumerate(l):



            img = load_img(src+img)

            if i == 0:
                print (img.size)
            '''
            in stage 1, no need to resize a smaller one.
            img = img.resize((2560//4,1920//4))

            '''

            x = img_to_array(img)

            '''
            stage 1 no need to apply background deletion pre_process on image

            my_filter = (x.max(axis=2) - x.min(axis=2)) < 50  # get mask

            for k in range(3):
                x[:,:,k] *= my_filter  # mask out the unnecessary part
            '''

            x = preprocess_input(x)


            img_list.append(x)
          #print ('img_list=', len(img_list))
          testing_data = np.array(img_list)


          '''
          make prediction, result will be (batch_szie, 1280)
          '''
          pred_temp = model.predict(testing_data)

          print('batch = ', j, 'stage 1 completed', 'shape=', pred_temp.shape)
          #np.save(src_save+'temp_'+str(j)+'.npy',pred_temp)

          #print ('bacth npy saved', j)
          e = time.time()
          print ('batch',j,'time=', round(e -s ,4))

          final_array.append(pred_temp) # append first batch result
          print ('afterbatch',j,'length=', len(final_array))

    '''
    convert the final_array list into numpy array and save
    Stage 1 train data done
    '''
    final_array = np.concatenate(final_array)

    return final_array
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_8 (InputLayer)            (None, 1920, 2560, 3 0
# __________________________________________________________________________________________________
# zero_padding2d_9 (ZeroPadding2D (None, 1926, 2566, 3 0           input_8[0][0]
# __________________________________________________________________________________________________
# conv1/conv (Conv2D)             (None, 960, 1280, 64 9408        zero_padding2d_9[0][0]
# __________________________________________________________________________________________________
# conv1/bn (BatchNormalization)   (None, 960, 1280, 64 256         conv1/conv[0][0]
# __________________________________________________________________________________________________
# conv1/relu (Activation)         (None, 960, 1280, 64 0           conv1/bn[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_10 (ZeroPadding2 (None, 962, 1282, 64 0           conv1/relu[0][0]
# __________________________________________________________________________________________________
# pool1 (MaxPooling2D)            (None, 480, 640, 64) 0           zero_padding2d_10[0][0]
# __________________________________________________________________________________________________
# conv2_block1_0_bn (BatchNormali (None, 480, 640, 64) 256         pool1[0][0]
# __________________________________________________________________________________________________
# conv2_block1_0_relu (Activation (None, 480, 640, 64) 0           conv2_block1_0_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block1_1_conv (Conv2D)    (None, 480, 640, 128 8192        conv2_block1_0_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block1_1_bn (BatchNormali (None, 480, 640, 128 512         conv2_block1_1_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block1_1_relu (Activation (None, 480, 640, 128 0           conv2_block1_1_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block1_2_conv (Conv2D)    (None, 480, 640, 32) 36864       conv2_block1_1_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block1_concat (Concatenat (None, 480, 640, 96) 0           pool1[0][0]
#                                                                  conv2_block1_2_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block2_0_bn (BatchNormali (None, 480, 640, 96) 384         conv2_block1_concat[0][0]
# __________________________________________________________________________________________________
# conv2_block2_0_relu (Activation (None, 480, 640, 96) 0           conv2_block2_0_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block2_1_conv (Conv2D)    (None, 480, 640, 128 12288       conv2_block2_0_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block2_1_bn (BatchNormali (None, 480, 640, 128 512         conv2_block2_1_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block2_1_relu (Activation (None, 480, 640, 128 0           conv2_block2_1_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block2_2_conv (Conv2D)    (None, 480, 640, 32) 36864       conv2_block2_1_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block2_concat (Concatenat (None, 480, 640, 128 0           conv2_block1_concat[0][0]
#                                                                  conv2_block2_2_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block3_0_bn (BatchNormali (None, 480, 640, 128 512         conv2_block2_concat[0][0]
# __________________________________________________________________________________________________
# conv2_block3_0_relu (Activation (None, 480, 640, 128 0           conv2_block3_0_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block3_1_conv (Conv2D)    (None, 480, 640, 128 16384       conv2_block3_0_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block3_1_bn (BatchNormali (None, 480, 640, 128 512         conv2_block3_1_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block3_1_relu (Activation (None, 480, 640, 128 0           conv2_block3_1_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block3_2_conv (Conv2D)    (None, 480, 640, 32) 36864       conv2_block3_1_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block3_concat (Concatenat (None, 480, 640, 160 0           conv2_block2_concat[0][0]
#                                                                  conv2_block3_2_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block4_0_bn (BatchNormali (None, 480, 640, 160 640         conv2_block3_concat[0][0]
# __________________________________________________________________________________________________
# conv2_block4_0_relu (Activation (None, 480, 640, 160 0           conv2_block4_0_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block4_1_conv (Conv2D)    (None, 480, 640, 128 20480       conv2_block4_0_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block4_1_bn (BatchNormali (None, 480, 640, 128 512         conv2_block4_1_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block4_1_relu (Activation (None, 480, 640, 128 0           conv2_block4_1_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block4_2_conv (Conv2D)    (None, 480, 640, 32) 36864       conv2_block4_1_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block4_concat (Concatenat (None, 480, 640, 192 0           conv2_block3_concat[0][0]
#                                                                  conv2_block4_2_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block5_0_bn (BatchNormali (None, 480, 640, 192 768         conv2_block4_concat[0][0]
# __________________________________________________________________________________________________
# conv2_block5_0_relu (Activation (None, 480, 640, 192 0           conv2_block5_0_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block5_1_conv (Conv2D)    (None, 480, 640, 128 24576       conv2_block5_0_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block5_1_bn (BatchNormali (None, 480, 640, 128 512         conv2_block5_1_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block5_1_relu (Activation (None, 480, 640, 128 0           conv2_block5_1_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block5_2_conv (Conv2D)    (None, 480, 640, 32) 36864       conv2_block5_1_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block5_concat (Concatenat (None, 480, 640, 224 0           conv2_block4_concat[0][0]
#                                                                  conv2_block5_2_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block6_0_bn (BatchNormali (None, 480, 640, 224 896         conv2_block5_concat[0][0]
# __________________________________________________________________________________________________
# conv2_block6_0_relu (Activation (None, 480, 640, 224 0           conv2_block6_0_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block6_1_conv (Conv2D)    (None, 480, 640, 128 28672       conv2_block6_0_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block6_1_bn (BatchNormali (None, 480, 640, 128 512         conv2_block6_1_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block6_1_relu (Activation (None, 480, 640, 128 0           conv2_block6_1_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block6_2_conv (Conv2D)    (None, 480, 640, 32) 36864       conv2_block6_1_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block6_concat (Concatenat (None, 480, 640, 256 0           conv2_block5_concat[0][0]
#                                                                  conv2_block6_2_conv[0][0]
# __________________________________________________________________________________________________
# pool2_bn (BatchNormalization)   (None, 480, 640, 256 1024        conv2_block6_concat[0][0]
# __________________________________________________________________________________________________
# pool2_relu (Activation)         (None, 480, 640, 256 0           pool2_bn[0][0]
# __________________________________________________________________________________________________
# pool2_conv (Conv2D)             (None, 480, 640, 128 32768       pool2_relu[0][0]
# __________________________________________________________________________________________________
# pool2_pool (AveragePooling2D)   (None, 240, 320, 128 0           pool2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block1_0_bn (BatchNormali (None, 240, 320, 128 512         pool2_pool[0][0]
# __________________________________________________________________________________________________
# conv3_block1_0_relu (Activation (None, 240, 320, 128 0           conv3_block1_0_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block1_1_conv (Conv2D)    (None, 240, 320, 128 16384       conv3_block1_0_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block1_1_bn (BatchNormali (None, 240, 320, 128 512         conv3_block1_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block1_1_relu (Activation (None, 240, 320, 128 0           conv3_block1_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block1_2_conv (Conv2D)    (None, 240, 320, 32) 36864       conv3_block1_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block1_concat (Concatenat (None, 240, 320, 160 0           pool2_pool[0][0]
#                                                                  conv3_block1_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block2_0_bn (BatchNormali (None, 240, 320, 160 640         conv3_block1_concat[0][0]
# __________________________________________________________________________________________________
# conv3_block2_0_relu (Activation (None, 240, 320, 160 0           conv3_block2_0_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block2_1_conv (Conv2D)    (None, 240, 320, 128 20480       conv3_block2_0_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block2_1_bn (BatchNormali (None, 240, 320, 128 512         conv3_block2_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block2_1_relu (Activation (None, 240, 320, 128 0           conv3_block2_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block2_2_conv (Conv2D)    (None, 240, 320, 32) 36864       conv3_block2_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block2_concat (Concatenat (None, 240, 320, 192 0           conv3_block1_concat[0][0]
#                                                                  conv3_block2_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block3_0_bn (BatchNormali (None, 240, 320, 192 768         conv3_block2_concat[0][0]
# __________________________________________________________________________________________________
# conv3_block3_0_relu (Activation (None, 240, 320, 192 0           conv3_block3_0_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block3_1_conv (Conv2D)    (None, 240, 320, 128 24576       conv3_block3_0_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block3_1_bn (BatchNormali (None, 240, 320, 128 512         conv3_block3_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block3_1_relu (Activation (None, 240, 320, 128 0           conv3_block3_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block3_2_conv (Conv2D)    (None, 240, 320, 32) 36864       conv3_block3_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block3_concat (Concatenat (None, 240, 320, 224 0           conv3_block2_concat[0][0]
#                                                                  conv3_block3_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block4_0_bn (BatchNormali (None, 240, 320, 224 896         conv3_block3_concat[0][0]
# __________________________________________________________________________________________________
# conv3_block4_0_relu (Activation (None, 240, 320, 224 0           conv3_block4_0_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block4_1_conv (Conv2D)    (None, 240, 320, 128 28672       conv3_block4_0_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block4_1_bn (BatchNormali (None, 240, 320, 128 512         conv3_block4_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block4_1_relu (Activation (None, 240, 320, 128 0           conv3_block4_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block4_2_conv (Conv2D)    (None, 240, 320, 32) 36864       conv3_block4_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block4_concat (Concatenat (None, 240, 320, 256 0           conv3_block3_concat[0][0]
#                                                                  conv3_block4_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block5_0_bn (BatchNormali (None, 240, 320, 256 1024        conv3_block4_concat[0][0]
# __________________________________________________________________________________________________
# conv3_block5_0_relu (Activation (None, 240, 320, 256 0           conv3_block5_0_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block5_1_conv (Conv2D)    (None, 240, 320, 128 32768       conv3_block5_0_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block5_1_bn (BatchNormali (None, 240, 320, 128 512         conv3_block5_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block5_1_relu (Activation (None, 240, 320, 128 0           conv3_block5_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block5_2_conv (Conv2D)    (None, 240, 320, 32) 36864       conv3_block5_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block5_concat (Concatenat (None, 240, 320, 288 0           conv3_block4_concat[0][0]
#                                                                  conv3_block5_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block6_0_bn (BatchNormali (None, 240, 320, 288 1152        conv3_block5_concat[0][0]
# __________________________________________________________________________________________________
# conv3_block6_0_relu (Activation (None, 240, 320, 288 0           conv3_block6_0_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block6_1_conv (Conv2D)    (None, 240, 320, 128 36864       conv3_block6_0_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block6_1_bn (BatchNormali (None, 240, 320, 128 512         conv3_block6_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block6_1_relu (Activation (None, 240, 320, 128 0           conv3_block6_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block6_2_conv (Conv2D)    (None, 240, 320, 32) 36864       conv3_block6_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block6_concat (Concatenat (None, 240, 320, 320 0           conv3_block5_concat[0][0]
#                                                                  conv3_block6_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block7_0_bn (BatchNormali (None, 240, 320, 320 1280        conv3_block6_concat[0][0]
# __________________________________________________________________________________________________
# conv3_block7_0_relu (Activation (None, 240, 320, 320 0           conv3_block7_0_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block7_1_conv (Conv2D)    (None, 240, 320, 128 40960       conv3_block7_0_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block7_1_bn (BatchNormali (None, 240, 320, 128 512         conv3_block7_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block7_1_relu (Activation (None, 240, 320, 128 0           conv3_block7_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block7_2_conv (Conv2D)    (None, 240, 320, 32) 36864       conv3_block7_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block7_concat (Concatenat (None, 240, 320, 352 0           conv3_block6_concat[0][0]
#                                                                  conv3_block7_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block8_0_bn (BatchNormali (None, 240, 320, 352 1408        conv3_block7_concat[0][0]
# __________________________________________________________________________________________________
# conv3_block8_0_relu (Activation (None, 240, 320, 352 0           conv3_block8_0_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block8_1_conv (Conv2D)    (None, 240, 320, 128 45056       conv3_block8_0_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block8_1_bn (BatchNormali (None, 240, 320, 128 512         conv3_block8_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block8_1_relu (Activation (None, 240, 320, 128 0           conv3_block8_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block8_2_conv (Conv2D)    (None, 240, 320, 32) 36864       conv3_block8_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block8_concat (Concatenat (None, 240, 320, 384 0           conv3_block7_concat[0][0]
#                                                                  conv3_block8_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block9_0_bn (BatchNormali (None, 240, 320, 384 1536        conv3_block8_concat[0][0]
# __________________________________________________________________________________________________
# conv3_block9_0_relu (Activation (None, 240, 320, 384 0           conv3_block9_0_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block9_1_conv (Conv2D)    (None, 240, 320, 128 49152       conv3_block9_0_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block9_1_bn (BatchNormali (None, 240, 320, 128 512         conv3_block9_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block9_1_relu (Activation (None, 240, 320, 128 0           conv3_block9_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block9_2_conv (Conv2D)    (None, 240, 320, 32) 36864       conv3_block9_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block9_concat (Concatenat (None, 240, 320, 416 0           conv3_block8_concat[0][0]
#                                                                  conv3_block9_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block10_0_bn (BatchNormal (None, 240, 320, 416 1664        conv3_block9_concat[0][0]
# __________________________________________________________________________________________________
# conv3_block10_0_relu (Activatio (None, 240, 320, 416 0           conv3_block10_0_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block10_1_conv (Conv2D)   (None, 240, 320, 128 53248       conv3_block10_0_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block10_1_bn (BatchNormal (None, 240, 320, 128 512         conv3_block10_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block10_1_relu (Activatio (None, 240, 320, 128 0           conv3_block10_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block10_2_conv (Conv2D)   (None, 240, 320, 32) 36864       conv3_block10_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block10_concat (Concatena (None, 240, 320, 448 0           conv3_block9_concat[0][0]
#                                                                  conv3_block10_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block11_0_bn (BatchNormal (None, 240, 320, 448 1792        conv3_block10_concat[0][0]
# __________________________________________________________________________________________________
# conv3_block11_0_relu (Activatio (None, 240, 320, 448 0           conv3_block11_0_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block11_1_conv (Conv2D)   (None, 240, 320, 128 57344       conv3_block11_0_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block11_1_bn (BatchNormal (None, 240, 320, 128 512         conv3_block11_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block11_1_relu (Activatio (None, 240, 320, 128 0           conv3_block11_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block11_2_conv (Conv2D)   (None, 240, 320, 32) 36864       conv3_block11_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block11_concat (Concatena (None, 240, 320, 480 0           conv3_block10_concat[0][0]
#                                                                  conv3_block11_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block12_0_bn (BatchNormal (None, 240, 320, 480 1920        conv3_block11_concat[0][0]
# __________________________________________________________________________________________________
# conv3_block12_0_relu (Activatio (None, 240, 320, 480 0           conv3_block12_0_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block12_1_conv (Conv2D)   (None, 240, 320, 128 61440       conv3_block12_0_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block12_1_bn (BatchNormal (None, 240, 320, 128 512         conv3_block12_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block12_1_relu (Activatio (None, 240, 320, 128 0           conv3_block12_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block12_2_conv (Conv2D)   (None, 240, 320, 32) 36864       conv3_block12_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block12_concat (Concatena (None, 240, 320, 512 0           conv3_block11_concat[0][0]
#                                                                  conv3_block12_2_conv[0][0]
# __________________________________________________________________________________________________
# pool3_bn (BatchNormalization)   (None, 240, 320, 512 2048        conv3_block12_concat[0][0]
# __________________________________________________________________________________________________
# pool3_relu (Activation)         (None, 240, 320, 512 0           pool3_bn[0][0]
# __________________________________________________________________________________________________
# pool3_conv (Conv2D)             (None, 240, 320, 256 131072      pool3_relu[0][0]
# __________________________________________________________________________________________________
# pool3_pool (AveragePooling2D)   (None, 120, 160, 256 0           pool3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block1_0_bn (BatchNormali (None, 120, 160, 256 1024        pool3_pool[0][0]
# __________________________________________________________________________________________________
# conv4_block1_0_relu (Activation (None, 120, 160, 256 0           conv4_block1_0_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block1_1_conv (Conv2D)    (None, 120, 160, 128 32768       conv4_block1_0_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block1_1_bn (BatchNormali (None, 120, 160, 128 512         conv4_block1_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block1_1_relu (Activation (None, 120, 160, 128 0           conv4_block1_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block1_2_conv (Conv2D)    (None, 120, 160, 32) 36864       conv4_block1_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block1_concat (Concatenat (None, 120, 160, 288 0           pool3_pool[0][0]
#                                                                  conv4_block1_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block2_0_bn (BatchNormali (None, 120, 160, 288 1152        conv4_block1_concat[0][0]
# __________________________________________________________________________________________________
# conv4_block2_0_relu (Activation (None, 120, 160, 288 0           conv4_block2_0_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block2_1_conv (Conv2D)    (None, 120, 160, 128 36864       conv4_block2_0_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block2_1_bn (BatchNormali (None, 120, 160, 128 512         conv4_block2_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block2_1_relu (Activation (None, 120, 160, 128 0           conv4_block2_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block2_2_conv (Conv2D)    (None, 120, 160, 32) 36864       conv4_block2_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block2_concat (Concatenat (None, 120, 160, 320 0           conv4_block1_concat[0][0]
#                                                                  conv4_block2_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block3_0_bn (BatchNormali (None, 120, 160, 320 1280        conv4_block2_concat[0][0]
# __________________________________________________________________________________________________
# conv4_block3_0_relu (Activation (None, 120, 160, 320 0           conv4_block3_0_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block3_1_conv (Conv2D)    (None, 120, 160, 128 40960       conv4_block3_0_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block3_1_bn (BatchNormali (None, 120, 160, 128 512         conv4_block3_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block3_1_relu (Activation (None, 120, 160, 128 0           conv4_block3_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block3_2_conv (Conv2D)    (None, 120, 160, 32) 36864       conv4_block3_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block3_concat (Concatenat (None, 120, 160, 352 0           conv4_block2_concat[0][0]
#                                                                  conv4_block3_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block4_0_bn (BatchNormali (None, 120, 160, 352 1408        conv4_block3_concat[0][0]
# __________________________________________________________________________________________________
# conv4_block4_0_relu (Activation (None, 120, 160, 352 0           conv4_block4_0_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block4_1_conv (Conv2D)    (None, 120, 160, 128 45056       conv4_block4_0_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block4_1_bn (BatchNormali (None, 120, 160, 128 512         conv4_block4_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block4_1_relu (Activation (None, 120, 160, 128 0           conv4_block4_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block4_2_conv (Conv2D)    (None, 120, 160, 32) 36864       conv4_block4_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block4_concat (Concatenat (None, 120, 160, 384 0           conv4_block3_concat[0][0]
#                                                                  conv4_block4_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block5_0_bn (BatchNormali (None, 120, 160, 384 1536        conv4_block4_concat[0][0]
# __________________________________________________________________________________________________
# conv4_block5_0_relu (Activation (None, 120, 160, 384 0           conv4_block5_0_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block5_1_conv (Conv2D)    (None, 120, 160, 128 49152       conv4_block5_0_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block5_1_bn (BatchNormali (None, 120, 160, 128 512         conv4_block5_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block5_1_relu (Activation (None, 120, 160, 128 0           conv4_block5_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block5_2_conv (Conv2D)    (None, 120, 160, 32) 36864       conv4_block5_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block5_concat (Concatenat (None, 120, 160, 416 0           conv4_block4_concat[0][0]
#                                                                  conv4_block5_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block6_0_bn (BatchNormali (None, 120, 160, 416 1664        conv4_block5_concat[0][0]
# __________________________________________________________________________________________________
# conv4_block6_0_relu (Activation (None, 120, 160, 416 0           conv4_block6_0_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block6_1_conv (Conv2D)    (None, 120, 160, 128 53248       conv4_block6_0_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block6_1_bn (BatchNormali (None, 120, 160, 128 512         conv4_block6_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block6_1_relu (Activation (None, 120, 160, 128 0           conv4_block6_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block6_2_conv (Conv2D)    (None, 120, 160, 32) 36864       conv4_block6_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block6_concat (Concatenat (None, 120, 160, 448 0           conv4_block5_concat[0][0]
#                                                                  conv4_block6_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block7_0_bn (BatchNormali (None, 120, 160, 448 1792        conv4_block6_concat[0][0]
# __________________________________________________________________________________________________
# conv4_block7_0_relu (Activation (None, 120, 160, 448 0           conv4_block7_0_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block7_1_conv (Conv2D)    (None, 120, 160, 128 57344       conv4_block7_0_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block7_1_bn (BatchNormali (None, 120, 160, 128 512         conv4_block7_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block7_1_relu (Activation (None, 120, 160, 128 0           conv4_block7_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block7_2_conv (Conv2D)    (None, 120, 160, 32) 36864       conv4_block7_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block7_concat (Concatenat (None, 120, 160, 480 0           conv4_block6_concat[0][0]
#                                                                  conv4_block7_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block8_0_bn (BatchNormali (None, 120, 160, 480 1920        conv4_block7_concat[0][0]
# __________________________________________________________________________________________________
# conv4_block8_0_relu (Activation (None, 120, 160, 480 0           conv4_block8_0_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block8_1_conv (Conv2D)    (None, 120, 160, 128 61440       conv4_block8_0_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block8_1_bn (BatchNormali (None, 120, 160, 128 512         conv4_block8_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block8_1_relu (Activation (None, 120, 160, 128 0           conv4_block8_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block8_2_conv (Conv2D)    (None, 120, 160, 32) 36864       conv4_block8_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block8_concat (Concatenat (None, 120, 160, 512 0           conv4_block7_concat[0][0]
#                                                                  conv4_block8_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block9_0_bn (BatchNormali (None, 120, 160, 512 2048        conv4_block8_concat[0][0]
# __________________________________________________________________________________________________
# conv4_block9_0_relu (Activation (None, 120, 160, 512 0           conv4_block9_0_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block9_1_conv (Conv2D)    (None, 120, 160, 128 65536       conv4_block9_0_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block9_1_bn (BatchNormali (None, 120, 160, 128 512         conv4_block9_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block9_1_relu (Activation (None, 120, 160, 128 0           conv4_block9_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block9_2_conv (Conv2D)    (None, 120, 160, 32) 36864       conv4_block9_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block9_concat (Concatenat (None, 120, 160, 544 0           conv4_block8_concat[0][0]
#                                                                  conv4_block9_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block10_0_bn (BatchNormal (None, 120, 160, 544 2176        conv4_block9_concat[0][0]
# __________________________________________________________________________________________________
# conv4_block10_0_relu (Activatio (None, 120, 160, 544 0           conv4_block10_0_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block10_1_conv (Conv2D)   (None, 120, 160, 128 69632       conv4_block10_0_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block10_1_bn (BatchNormal (None, 120, 160, 128 512         conv4_block10_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block10_1_relu (Activatio (None, 120, 160, 128 0           conv4_block10_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block10_2_conv (Conv2D)   (None, 120, 160, 32) 36864       conv4_block10_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block10_concat (Concatena (None, 120, 160, 576 0           conv4_block9_concat[0][0]
#                                                                  conv4_block10_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block11_0_bn (BatchNormal (None, 120, 160, 576 2304        conv4_block10_concat[0][0]
# __________________________________________________________________________________________________
# conv4_block11_0_relu (Activatio (None, 120, 160, 576 0           conv4_block11_0_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block11_1_conv (Conv2D)   (None, 120, 160, 128 73728       conv4_block11_0_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block11_1_bn (BatchNormal (None, 120, 160, 128 512         conv4_block11_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block11_1_relu (Activatio (None, 120, 160, 128 0           conv4_block11_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block11_2_conv (Conv2D)   (None, 120, 160, 32) 36864       conv4_block11_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block11_concat (Concatena (None, 120, 160, 608 0           conv4_block10_concat[0][0]
#                                                                  conv4_block11_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block12_0_bn (BatchNormal (None, 120, 160, 608 2432        conv4_block11_concat[0][0]
# __________________________________________________________________________________________________
# conv4_block12_0_relu (Activatio (None, 120, 160, 608 0           conv4_block12_0_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block12_1_conv (Conv2D)   (None, 120, 160, 128 77824       conv4_block12_0_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block12_1_bn (BatchNormal (None, 120, 160, 128 512         conv4_block12_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block12_1_relu (Activatio (None, 120, 160, 128 0           conv4_block12_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block12_2_conv (Conv2D)   (None, 120, 160, 32) 36864       conv4_block12_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block12_concat (Concatena (None, 120, 160, 640 0           conv4_block11_concat[0][0]
#                                                                  conv4_block12_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block13_0_bn (BatchNormal (None, 120, 160, 640 2560        conv4_block12_concat[0][0]
# ...
# conv5_block6_2_conv (Conv2D)    (None, 60, 80, 32)   36864       conv5_block6_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block6_concat (Concatenat (None, 60, 80, 704)  0           conv5_block5_concat[0][0]
#                                                                  conv5_block6_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block7_0_bn (BatchNormali (None, 60, 80, 704)  2816        conv5_block6_concat[0][0]
# __________________________________________________________________________________________________
# conv5_block7_0_relu (Activation (None, 60, 80, 704)  0           conv5_block7_0_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block7_1_conv (Conv2D)    (None, 60, 80, 128)  90112       conv5_block7_0_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block7_1_bn (BatchNormali (None, 60, 80, 128)  512         conv5_block7_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block7_1_relu (Activation (None, 60, 80, 128)  0           conv5_block7_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block7_2_conv (Conv2D)    (None, 60, 80, 32)   36864       conv5_block7_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block7_concat (Concatenat (None, 60, 80, 736)  0           conv5_block6_concat[0][0]
#                                                                  conv5_block7_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block8_0_bn (BatchNormali (None, 60, 80, 736)  2944        conv5_block7_concat[0][0]
# __________________________________________________________________________________________________
# conv5_block8_0_relu (Activation (None, 60, 80, 736)  0           conv5_block8_0_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block8_1_conv (Conv2D)    (None, 60, 80, 128)  94208       conv5_block8_0_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block8_1_bn (BatchNormali (None, 60, 80, 128)  512         conv5_block8_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block8_1_relu (Activation (None, 60, 80, 128)  0           conv5_block8_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block8_2_conv (Conv2D)    (None, 60, 80, 32)   36864       conv5_block8_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block8_concat (Concatenat (None, 60, 80, 768)  0           conv5_block7_concat[0][0]
#                                                                  conv5_block8_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block9_0_bn (BatchNormali (None, 60, 80, 768)  3072        conv5_block8_concat[0][0]
# __________________________________________________________________________________________________
# conv5_block9_0_relu (Activation (None, 60, 80, 768)  0           conv5_block9_0_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block9_1_conv (Conv2D)    (None, 60, 80, 128)  98304       conv5_block9_0_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block9_1_bn (BatchNormali (None, 60, 80, 128)  512         conv5_block9_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block9_1_relu (Activation (None, 60, 80, 128)  0           conv5_block9_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block9_2_conv (Conv2D)    (None, 60, 80, 32)   36864       conv5_block9_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block9_concat (Concatenat (None, 60, 80, 800)  0           conv5_block8_concat[0][0]
#                                                                  conv5_block9_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block10_0_bn (BatchNormal (None, 60, 80, 800)  3200        conv5_block9_concat[0][0]
# __________________________________________________________________________________________________
# conv5_block10_0_relu (Activatio (None, 60, 80, 800)  0           conv5_block10_0_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block10_1_conv (Conv2D)   (None, 60, 80, 128)  102400      conv5_block10_0_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block10_1_bn (BatchNormal (None, 60, 80, 128)  512         conv5_block10_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block10_1_relu (Activatio (None, 60, 80, 128)  0           conv5_block10_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block10_2_conv (Conv2D)   (None, 60, 80, 32)   36864       conv5_block10_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block10_concat (Concatena (None, 60, 80, 832)  0           conv5_block9_concat[0][0]
#                                                                  conv5_block10_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block11_0_bn (BatchNormal (None, 60, 80, 832)  3328        conv5_block10_concat[0][0]
# __________________________________________________________________________________________________
# conv5_block11_0_relu (Activatio (None, 60, 80, 832)  0           conv5_block11_0_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block11_1_conv (Conv2D)   (None, 60, 80, 128)  106496      conv5_block11_0_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block11_1_bn (BatchNormal (None, 60, 80, 128)  512         conv5_block11_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block11_1_relu (Activatio (None, 60, 80, 128)  0           conv5_block11_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block11_2_conv (Conv2D)   (None, 60, 80, 32)   36864       conv5_block11_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block11_concat (Concatena (None, 60, 80, 864)  0           conv5_block10_concat[0][0]
#                                                                  conv5_block11_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block12_0_bn (BatchNormal (None, 60, 80, 864)  3456        conv5_block11_concat[0][0]
# __________________________________________________________________________________________________
# conv5_block12_0_relu (Activatio (None, 60, 80, 864)  0           conv5_block12_0_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block12_1_conv (Conv2D)   (None, 60, 80, 128)  110592      conv5_block12_0_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block12_1_bn (BatchNormal (None, 60, 80, 128)  512         conv5_block12_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block12_1_relu (Activatio (None, 60, 80, 128)  0           conv5_block12_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block12_2_conv (Conv2D)   (None, 60, 80, 32)   36864       conv5_block12_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block12_concat (Concatena (None, 60, 80, 896)  0           conv5_block11_concat[0][0]
#                                                                  conv5_block12_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block13_0_bn (BatchNormal (None, 60, 80, 896)  3584        conv5_block12_concat[0][0]
# __________________________________________________________________________________________________
# conv5_block13_0_relu (Activatio (None, 60, 80, 896)  0           conv5_block13_0_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block13_1_conv (Conv2D)   (None, 60, 80, 128)  114688      conv5_block13_0_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block13_1_bn (BatchNormal (None, 60, 80, 128)  512         conv5_block13_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block13_1_relu (Activatio (None, 60, 80, 128)  0           conv5_block13_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block13_2_conv (Conv2D)   (None, 60, 80, 32)   36864       conv5_block13_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block13_concat (Concatena (None, 60, 80, 928)  0           conv5_block12_concat[0][0]
#                                                                  conv5_block13_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block14_0_bn (BatchNormal (None, 60, 80, 928)  3712        conv5_block13_concat[0][0]
# __________________________________________________________________________________________________
# conv5_block14_0_relu (Activatio (None, 60, 80, 928)  0           conv5_block14_0_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block14_1_conv (Conv2D)   (None, 60, 80, 128)  118784      conv5_block14_0_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block14_1_bn (BatchNormal (None, 60, 80, 128)  512         conv5_block14_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block14_1_relu (Activatio (None, 60, 80, 128)  0           conv5_block14_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block14_2_conv (Conv2D)   (None, 60, 80, 32)   36864       conv5_block14_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block14_concat (Concatena (None, 60, 80, 960)  0           conv5_block13_concat[0][0]
#                                                                  conv5_block14_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block15_0_bn (BatchNormal (None, 60, 80, 960)  3840        conv5_block14_concat[0][0]
# __________________________________________________________________________________________________
# conv5_block15_0_relu (Activatio (None, 60, 80, 960)  0           conv5_block15_0_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block15_1_conv (Conv2D)   (None, 60, 80, 128)  122880      conv5_block15_0_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block15_1_bn (BatchNormal (None, 60, 80, 128)  512         conv5_block15_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block15_1_relu (Activatio (None, 60, 80, 128)  0           conv5_block15_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block15_2_conv (Conv2D)   (None, 60, 80, 32)   36864       conv5_block15_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block15_concat (Concatena (None, 60, 80, 992)  0           conv5_block14_concat[0][0]
#                                                                  conv5_block15_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block16_0_bn (BatchNormal (None, 60, 80, 992)  3968        conv5_block15_concat[0][0]
# __________________________________________________________________________________________________
# conv5_block16_0_relu (Activatio (None, 60, 80, 992)  0           conv5_block16_0_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block16_1_conv (Conv2D)   (None, 60, 80, 128)  126976      conv5_block16_0_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block16_1_bn (BatchNormal (None, 60, 80, 128)  512         conv5_block16_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block16_1_relu (Activatio (None, 60, 80, 128)  0           conv5_block16_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block16_2_conv (Conv2D)   (None, 60, 80, 32)   36864       conv5_block16_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block16_concat (Concatena (None, 60, 80, 1024) 0           conv5_block15_concat[0][0]
#                                                                  conv5_block16_2_conv[0][0]
# __________________________________________________________________________________________________
# bn (BatchNormalization)         (None, 60, 80, 1024) 4096        conv5_block16_concat[0][0]
# __________________________________________________________________________________________________
# avg_pool (GlobalAveragePooling2 (None, 1024)         0           bn[0][0]
# ==================================================================================================
# Total params: 7,037,504
# Trainable params: 6,953,856
# Non-trainable params: 83,648
# __________________________________________________________________________________________________

# %%
train_final_array_1 = make_data(train_file_list,model_1,src_2)
print ('train_final array_1', train_final_array_1.shape)
np.save(src_save+'train_data_DenseNet121_1_verification.npy',train_final_array_1)
print ('totally done, train_data_DenseNet_1_verification.npy')
# Out:
# floor= 477
# total size 2386 file_list 2386 final_list length NOT equal to file_list
# 0
# warning, something wrong
# 478
# (2560, 1920)
# batch =  0 stage 1 completed shape= (5, 1024)
# batch 0 time= 26.2273
# afterbatch 0 length= 1
# (2560, 1920)
# batch =  1 stage 1 completed shape= (5, 1024)
# batch 1 time= 33.07
# afterbatch 1 length= 2
# (2560, 1920)
# batch =  2 stage 1 completed shape= (5, 1024)
# batch 2 time= 39.896
# afterbatch 2 length= 3
# (2560, 1920)
# batch =  3 stage 1 completed shape= (5, 1024)
# batch 3 time= 46.7777
# afterbatch 3 length= 4
# (2560, 1920)
# batch =  4 stage 1 completed shape= (5, 1024)
# batch 4 time= 53.5493
# afterbatch 4 length= 5
# (2560, 1920)
# batch =  5 stage 1 completed shape= (5, 1024)
# batch 5 time= 60.3822
# afterbatch 5 length= 6
# (2560, 1920)
# batch =  6 stage 1 completed shape= (5, 1024)
# batch 6 time= 67.2014
# afterbatch 6 length= 7
# (2560, 1920)
# batch =  7 stage 1 completed shape= (5, 1024)
# batch 7 time= 74.0013
# afterbatch 7 length= 8
# (2560, 1920)
# batch =  8 stage 1 completed shape= (5, 1024)
# batch 8 time= 80.8404
# afterbatch 8 length= 9
# (2560, 1920)
# batch =  9 stage 1 completed shape= (5, 1024)
# batch 9 time= 87.5536
# afterbatch 9 length= 10
# (2560, 1920)
# batch =  10 stage 1 completed shape= (5, 1024)
# batch 10 time= 94.3814
# afterbatch 10 length= 11
# (2560, 1920)
# batch =  11 stage 1 completed shape= (5, 1024)
# batch 11 time= 101.2128
# afterbatch 11 length= 12
# (2560, 1920)
# batch =  12 stage 1 completed shape= (5, 1024)
# batch 12 time= 108.0835
# afterbatch 12 length= 13
# (2560, 1920)
# batch =  13 stage 1 completed shape= (5, 1024)
# batch 13 time= 114.9615
# afterbatch 13 length= 14
# (2560, 1920)
# batch =  14 stage 1 completed shape= (5, 1024)
# batch 14 time= 121.8779
# afterbatch 14 length= 15
# (2560, 1920)
# batch =  15 stage 1 completed shape= (5, 1024)
# batch 15 time= 128.6439
# afterbatch 15 length= 16
# (2560, 1920)
# batch =  16 stage 1 completed shape= (5, 1024)
# batch 16 time= 135.44
# afterbatch 16 length= 17
# (2560, 1920)
# batch =  17 stage 1 completed shape= (5, 1024)
# batch 17 time= 142.255
# afterbatch 17 length= 18
# (2560, 1920)
# batch =  18 stage 1 completed shape= (5, 1024)
# batch 18 time= 149.1101
# afterbatch 18 length= 19
# (2560, 1920)
# batch =  19 stage 1 completed shape= (5, 1024)
# batch 19 time= 155.9101
# afterbatch 19 length= 20
# (2560, 1920)
# batch =  20 stage 1 completed shape= (5, 1024)
# batch 20 time= 162.775
# afterbatch 20 length= 21
# (2560, 1920)
# batch =  21 stage 1 completed shape= (5, 1024)
# batch 21 time= 169.566
# afterbatch 21 length= 22
# (2560, 1920)
# batch =  22 stage 1 completed shape= (5, 1024)
# batch 22 time= 176.3885
# afterbatch 22 length= 23
# (2560, 1920)
# batch =  23 stage 1 completed shape= (5, 1024)
# batch 23 time= 183.1958
# afterbatch 23 length= 24
# (2560, 1920)
# batch =  24 stage 1 completed shape= (5, 1024)
# batch 24 time= 190.076
# afterbatch 24 length= 25
# (2560, 1920)
# batch =  25 stage 1 completed shape= (5, 1024)
# batch 25 time= 196.8862
# afterbatch 25 length= 26
# (2560, 1920)
# batch =  26 stage 1 completed shape= (5, 1024)
# batch 26 time= 203.662
# afterbatch 26 length= 27
# (2560, 1920)
# batch =  27 stage 1 completed shape= (5, 1024)
# batch 27 time= 210.4905
# afterbatch 27 length= 28
# (2560, 1920)
# batch =  28 stage 1 completed shape= (5, 1024)
# batch 28 time= 217.2999
# afterbatch 28 length= 29
# (2560, 1920)
# batch =  29 stage 1 completed shape= (5, 1024)
# batch 29 time= 224.0942
# afterbatch 29 length= 30
# (2560, 1920)
# batch =  30 stage 1 completed shape= (5, 1024)
# batch 30 time= 230.9246
# afterbatch 30 length= 31
# (2560, 1920)
# batch =  31 stage 1 completed shape= (5, 1024)
# batch 31 time= 237.7214
# afterbatch 31 length= 32
# (2560, 1920)
# batch =  32 stage 1 completed shape= (5, 1024)
# batch 32 time= 244.5507
# afterbatch 32 length= 33
# (2560, 1920)
# batch =  33 stage 1 completed shape= (5, 1024)
# batch 33 time= 251.386
# afterbatch 33 length= 34
# (2560, 1920)
# batch =  34 stage 1 completed shape= (5, 1024)
# batch 34 time= 258.2301
# afterbatch 34 length= 35
# (2560, 1920)
# batch =  35 stage 1 completed shape= (5, 1024)
# batch 35 time= 265.1038
# afterbatch 35 length= 36
# (2560, 1920)
# batch =  36 stage 1 completed shape= (5, 1024)
# batch 36 time= 271.9823
# afterbatch 36 length= 37
# (2560, 1920)
# batch =  37 stage 1 completed shape= (5, 1024)
# batch 37 time= 278.8451
# afterbatch 37 length= 38
# (2560, 1920)
# batch =  38 stage 1 completed shape= (5, 1024)
# batch 38 time= 285.5905
# afterbatch 38 length= 39
# (2560, 1920)
# batch =  39 stage 1 completed shape= (5, 1024)
# batch 39 time= 292.33
# afterbatch 39 length= 40
# (2560, 1920)
# batch =  40 stage 1 completed shape= (5, 1024)
# batch 40 time= 299.1026
# afterbatch 40 length= 41
# (2560, 1920)
# batch =  41 stage 1 completed shape= (5, 1024)
# batch 41 time= 305.9516
# afterbatch 41 length= 42
# (2560, 1920)
# batch =  42 stage 1 completed shape= (5, 1024)
# batch 42 time= 312.8045
# afterbatch 42 length= 43
# (2560, 1920)
# batch =  43 stage 1 completed shape= (5, 1024)
# batch 43 time= 319.5435
# afterbatch 43 length= 44
# (2560, 1920)
# batch =  44 stage 1 completed shape= (5, 1024)
# batch 44 time= 326.3517
# afterbatch 44 length= 45
# (2560, 1920)
# batch =  45 stage 1 completed shape= (5, 1024)
# batch 45 time= 333.119
# afterbatch 45 length= 46
# (2560, 1920)
# batch =  46 stage 1 completed shape= (5, 1024)
# batch 46 time= 339.8816
# afterbatch 46 length= 47
# (2560, 1920)
# batch =  47 stage 1 completed shape= (5, 1024)
# batch 47 time= 346.7768
# afterbatch 47 length= 48
# (2560, 1920)
# batch =  48 stage 1 completed shape= (5, 1024)
# batch 48 time= 353.5203
# afterbatch 48 length= 49
# (2560, 1920)
# batch =  49 stage 1 completed shape= (5, 1024)
# batch 49 time= 360.355
# afterbatch 49 length= 50
# (2560, 1920)
# batch =  50 stage 1 completed shape= (5, 1024)
# batch 50 time= 367.1004
# afterbatch 50 length= 51
# (2560, 1920)
# batch =  51 stage 1 completed shape= (5, 1024)
# batch 51 time= 373.8869
# afterbatch 51 length= 52
# (2560, 1920)
# batch =  52 stage 1 completed shape= (5, 1024)
# batch 52 time= 380.7653
# afterbatch 52 length= 53
# (2560, 1920)
# batch =  53 stage 1 completed shape= (5, 1024)
# batch 53 time= 387.6685
# afterbatch 53 length= 54
# (2560, 1920)
# batch =  54 stage 1 completed shape= (5, 1024)
# batch 54 time= 394.4736
# afterbatch 54 length= 55
# (2560, 1920)
# batch =  55 stage 1 completed shape= (5, 1024)
# batch 55 time= 401.2292
# afterbatch 55 length= 56
# (2560, 1920)
# batch =  56 stage 1 completed shape= (5, 1024)
# batch 56 time= 407.996
# afterbatch 56 length= 57
# (2560, 1920)
# batch =  57 stage 1 completed shape= (5, 1024)
# batch 57 time= 414.8963
# afterbatch 57 length= 58
# (2560, 1920)
# batch =  58 stage 1 completed shape= (5, 1024)
# batch 58 time= 421.6561
# afterbatch 58 length= 59
# (2560, 1920)
# batch =  59 stage 1 completed shape= (5, 1024)
# batch 59 time= 428.4915
# afterbatch 59 length= 60
# (2560, 1920)
# batch =  60 stage 1 completed shape= (5, 1024)
# batch 60 time= 435.3777
# afterbatch 60 length= 61
# (2560, 1920)
# batch =  61 stage 1 completed shape= (5, 1024)
# batch 61 time= 442.1977
# afterbatch 61 length= 62
# (2560, 1920)
# batch =  62 stage 1 completed shape= (5, 1024)
# batch 62 time= 448.9707
# afterbatch 62 length= 63
# (2560, 1920)
# batch =  63 stage 1 completed shape= (5, 1024)
# batch 63 time= 455.7866
# afterbatch 63 length= 64
# (2560, 1920)
# batch =  64 stage 1 completed shape= (5, 1024)
# batch 64 time= 462.6147
# afterbatch 64 length= 65
# (2560, 1920)
# batch =  65 stage 1 completed shape= (5, 1024)
# batch 65 time= 469.3498
# afterbatch 65 length= 66
# (2560, 1920)
# batch =  66 stage 1 completed shape= (5, 1024)
# batch 66 time= 476.1341
# afterbatch 66 length= 67
# (2560, 1920)
# batch =  67 stage 1 completed shape= (5, 1024)
# batch 67 time= 482.9028
# afterbatch 67 length= 68
# (2560, 1920)
# batch =  68 stage 1 completed shape= (5, 1024)
# batch 68 time= 489.7194
# afterbatch 68 length= 69
# (2560, 1920)
# batch =  69 stage 1 completed shape= (5, 1024)
# batch 69 time= 496.5988
# afterbatch 69 length= 70
# (2560, 1920)
# batch =  70 stage 1 completed shape= (5, 1024)
# batch 70 time= 503.4472
# afterbatch 70 length= 71
# (2560, 1920)
# batch =  71 stage 1 completed shape= (5, 1024)
# batch 71 time= 510.3404
# afterbatch 71 length= 72
# (2560, 1920)
# batch =  72 stage 1 completed shape= (5, 1024)
# batch 72 time= 517.0858
# afterbatch 72 length= 73
# (2560, 1920)
# batch =  73 stage 1 completed shape= (5, 1024)
# batch 73 time= 523.9928
# afterbatch 73 length= 74
# (2560, 1920)
# batch =  74 stage 1 completed shape= (5, 1024)
# batch 74 time= 530.7976
# afterbatch 74 length= 75
# (2560, 1920)
# batch =  75 stage 1 completed shape= (5, 1024)
# batch 75 time= 537.5812
# afterbatch 75 length= 76
# (2560, 1920)
# batch =  76 stage 1 completed shape= (5, 1024)
# batch 76 time= 544.4022
# afterbatch 76 length= 77
# (2560, 1920)
# batch =  77 stage 1 completed shape= (5, 1024)
# batch 77 time= 551.2513
# afterbatch 77 length= 78
# (2560, 1920)
# batch =  78 stage 1 completed shape= (5, 1024)
# batch 78 time= 558.0804
# afterbatch 78 length= 79
# (2560, 1920)
# batch =  79 stage 1 completed shape= (5, 1024)
# batch 79 time= 564.8757
# afterbatch 79 length= 80
# (2560, 1920)
# batch =  80 stage 1 completed shape= (5, 1024)
# batch 80 time= 571.7279
# afterbatch 80 length= 81
# (2560, 1920)
# batch =  81 stage 1 completed shape= (5, 1024)
# batch 81 time= 578.5504
# afterbatch 81 length= 82
# (2560, 1920)
# batch =  82 stage 1 completed shape= (5, 1024)
# batch 82 time= 585.3567
# afterbatch 82 length= 83
# (2560, 1920)
# batch =  83 stage 1 completed shape= (5, 1024)
# batch 83 time= 592.0794
# afterbatch 83 length= 84
# (2560, 1920)
# batch =  84 stage 1 completed shape= (5, 1024)
# batch 84 time= 598.913
# afterbatch 84 length= 85
# (2560, 1920)
# batch =  85 stage 1 completed shape= (5, 1024)
# batch 85 time= 605.7257
# afterbatch 85 length= 86
# (2560, 1920)
# batch =  86 stage 1 completed shape= (5, 1024)
# batch 86 time= 612.5459
# afterbatch 86 length= 87
# (2560, 1920)
# batch =  87 stage 1 completed shape= (5, 1024)
# batch 87 time= 619.2601
# afterbatch 87 length= 88
# (2560, 1920)
# batch =  88 stage 1 completed shape= (5, 1024)
# batch 88 time= 626.0902
# afterbatch 88 length= 89
# (2560, 1920)
# batch =  89 stage 1 completed shape= (5, 1024)
# batch 89 time= 632.8777
# afterbatch 89 length= 90
# (2560, 1920)
# batch =  90 stage 1 completed shape= (5, 1024)
# batch 90 time= 639.6451
# afterbatch 90 length= 91
# (2560, 1920)
# batch =  91 stage 1 completed shape= (5, 1024)
# batch 91 time= 646.3818
# afterbatch 91 length= 92
# (2560, 1920)
# batch =  92 stage 1 completed shape= (5, 1024)
# batch 92 time= 653.1008
# afterbatch 92 length= 93
# (2560, 1920)
# batch =  93 stage 1 completed shape= (5, 1024)
# batch 93 time= 659.8484
# afterbatch 93 length= 94
# (2560, 1920)
# batch =  94 stage 1 completed shape= (5, 1024)
# batch 94 time= 666.588
# afterbatch 94 length= 95
# (2560, 1920)
# batch =  95 stage 1 completed shape= (5, 1024)
# batch 95 time= 673.4558
# afterbatch 95 length= 96
# (2560, 1920)
# batch =  96 stage 1 completed shape= (5, 1024)
# batch 96 time= 680.3411
# afterbatch 96 length= 97
# (2560, 1920)
# batch =  97 stage 1 completed shape= (5, 1024)
# batch 97 time= 687.1031
# afterbatch 97 length= 98
# (2560, 1920)
# batch =  98 stage 1 completed shape= (5, 1024)
# batch 98 time= 693.956
# afterbatch 98 length= 99
# (2560, 1920)
# batch =  99 stage 1 completed shape= (5, 1024)
# batch 99 time= 700.7547
# afterbatch 99 length= 100
# (2560, 1920)
# batch =  100 stage 1 completed shape= (5, 1024)
# batch 100 time= 707.584
# afterbatch 100 length= 101
# (2560, 1920)
# batch =  101 stage 1 completed shape= (5, 1024)
# batch 101 time= 714.2947
# afterbatch 101 length= 102
# (2560, 1920)
# batch =  102 stage 1 completed shape= (5, 1024)
# batch 102 time= 721.2137
# afterbatch 102 length= 103
# (2560, 1920)
# batch =  103 stage 1 completed shape= (5, 1024)
# batch 103 time= 728.1207
# afterbatch 103 length= 104
# (2560, 1920)
# batch =  104 stage 1 completed shape= (5, 1024)
# batch 104 time= 734.9321
# afterbatch 104 length= 105
# (2560, 1920)
# batch =  105 stage 1 completed shape= (5, 1024)
# batch 105 time= 741.741
# afterbatch 105 length= 106
# (2560, 1920)
# batch =  106 stage 1 completed shape= (5, 1024)
# batch 106 time= 748.5394
# afterbatch 106 length= 107
# (2560, 1920)
# batch =  107 stage 1 completed shape= (5, 1024)
# batch 107 time= 755.2802
# afterbatch 107 length= 108
# (2560, 1920)
# batch =  108 stage 1 completed shape= (5, 1024)
# batch 108 time= 762.1566
# afterbatch 108 length= 109
# (2560, 1920)
# batch =  109 stage 1 completed shape= (5, 1024)
# batch 109 time= 768.9637
# afterbatch 109 length= 110
# (2560, 1920)
# batch =  110 stage 1 completed shape= (5, 1024)
# batch 110 time= 775.8216
# afterbatch 110 length= 111
# (2560, 1920)
# batch =  111 stage 1 completed shape= (5, 1024)
# batch 111 time= 782.6455
# afterbatch 111 length= 112
# (2560, 1920)
# batch =  112 stage 1 completed shape= (5, 1024)
# batch 112 time= 789.4612
# afterbatch 112 length= 113
# (2560, 1920)
# batch =  113 stage 1 completed shape= (5, 1024)
# batch 113 time= 796.2221
# afterbatch 113 length= 114
# (2560, 1920)
# batch =  114 stage 1 completed shape= (5, 1024)
# batch 114 time= 802.99
# afterbatch 114 length= 115
# (2560, 1920)
# batch =  115 stage 1 completed shape= (5, 1024)
# batch 115 time= 809.8075
# afterbatch 115 length= 116
# (2560, 1920)
# batch =  116 stage 1 completed shape= (5, 1024)
# batch 116 time= 816.549
# afterbatch 116 length= 117
# (2560, 1920)
# batch =  117 stage 1 completed shape= (5, 1024)
# batch 117 time= 823.4583
# afterbatch 117 length= 118
# (2560, 1920)
# batch =  118 stage 1 completed shape= (5, 1024)
# batch 118 time= 830.2259
# afterbatch 118 length= 119
# (2560, 1920)
# batch =  119 stage 1 completed shape= (5, 1024)
# batch 119 time= 836.9474
# afterbatch 119 length= 120
# (2560, 1920)
# batch =  120 stage 1 completed shape= (5, 1024)
# batch 120 time= 843.779
# afterbatch 120 length= 121
# (2560, 1920)
# batch =  121 stage 1 completed shape= (5, 1024)
# batch 121 time= 850.5437
# afterbatch 121 length= 122
# (2560, 1920)
# batch =  122 stage 1 completed shape= (5, 1024)
# batch 122 time= 857.3239
# afterbatch 122 length= 123
# (2560, 1920)
# batch =  123 stage 1 completed shape= (5, 1024)
# batch 123 time= 864.1025
# afterbatch 123 length= 124
# (2560, 1920)
# batch =  124 stage 1 completed shape= (5, 1024)
# batch 124 time= 870.9744
# afterbatch 124 length= 125
# (2560, 1920)
# batch =  125 stage 1 completed shape= (5, 1024)
# batch 125 time= 877.747
# afterbatch 125 length= 126
# (2560, 1920)
# batch =  126 stage 1 completed shape= (5, 1024)
# batch 126 time= 884.4667
# afterbatch 126 length= 127
# (2560, 1920)
# batch =  127 stage 1 completed shape= (5, 1024)
# batch 127 time= 891.3308
# afterbatch 127 length= 128
# (2560, 1920)
# batch =  128 stage 1 completed shape= (5, 1024)
# batch 128 time= 898.1007
# afterbatch 128 length= 129
# (2560, 1920)
# batch =  129 stage 1 completed shape= (5, 1024)
# batch 129 time= 904.9429
# afterbatch 129 length= 130
# (2560, 1920)
# batch =  130 stage 1 completed shape= (5, 1024)
# batch 130 time= 911.6993
# afterbatch 130 length= 131
# (2560, 1920)
# batch =  131 stage 1 completed shape= (5, 1024)
# batch 131 time= 918.5093
# afterbatch 131 length= 132
# (2560, 1920)
# batch =  132 stage 1 completed shape= (5, 1024)
# batch 132 time= 925.3473
# afterbatch 132 length= 133
# (2560, 1920)
# batch =  133 stage 1 completed shape= (5, 1024)
# batch 133 time= 932.1005
# afterbatch 133 length= 134
# (2560, 1920)
# batch =  134 stage 1 completed shape= (5, 1024)
# batch 134 time= 938.9456
# afterbatch 134 length= 135
# (2560, 1920)
# batch =  135 stage 1 completed shape= (5, 1024)
# batch 135 time= 945.8001
# afterbatch 135 length= 136
# (2560, 1920)
# batch =  136 stage 1 completed shape= (5, 1024)
# batch 136 time= 952.6389
# afterbatch 136 length= 137
# (2560, 1920)
# batch =  137 stage 1 completed shape= (5, 1024)
# batch 137 time= 959.5023
# afterbatch 137 length= 138
# (2560, 1920)
# batch =  138 stage 1 completed shape= (5, 1024)
# batch 138 time= 966.3691
# afterbatch 138 length= 139
# (2560, 1920)
# batch =  139 stage 1 completed shape= (5, 1024)
# batch 139 time= 973.226
# afterbatch 139 length= 140
# (2560, 1920)
# batch =  140 stage 1 completed shape= (5, 1024)
# batch 140 time= 980.0528
# afterbatch 140 length= 141
# (2560, 1920)
# batch =  141 stage 1 completed shape= (5, 1024)
# batch 141 time= 986.8089
# afterbatch 141 length= 142
# (2560, 1920)
# batch =  142 stage 1 completed shape= (5, 1024)
# batch 142 time= 993.6189
# afterbatch 142 length= 143
# (2560, 1920)
# batch =  143 stage 1 completed shape= (5, 1024)
# batch 143 time= 1000.3542
# afterbatch 143 length= 144
# (2560, 1920)
# batch =  144 stage 1 completed shape= (5, 1024)
# batch 144 time= 1007.1456
# afterbatch 144 length= 145
# (2560, 1920)
# batch =  145 stage 1 completed shape= (5, 1024)
# batch 145 time= 1013.9402
# afterbatch 145 length= 146
# (2560, 1920)
# batch =  146 stage 1 completed shape= (5, 1024)
# batch 146 time= 1020.7154
# afterbatch 146 length= 147
# (2560, 1920)
# batch =  147 stage 1 completed shape= (5, 1024)
# batch 147 time= 1027.6086
# afterbatch 147 length= 148
# (2560, 1920)
# batch =  148 stage 1 completed shape= (5, 1024)
# batch 148 time= 1034.3591
# afterbatch 148 length= 149
# (2560, 1920)
# batch =  149 stage 1 completed shape= (5, 1024)
# batch 149 time= 1041.2084
# afterbatch 149 length= 150
# (2560, 1920)
# batch =  150 stage 1 completed shape= (5, 1024)
# batch 150 time= 1048.0567
# afterbatch 150 length= 151
# (2560, 1920)
# batch =  151 stage 1 completed shape= (5, 1024)
# batch 151 time= 1054.839
# afterbatch 151 length= 152
# (2560, 1920)
# batch =  152 stage 1 completed shape= (5, 1024)
# batch 152 time= 1061.6618
# afterbatch 152 length= 153
# (2560, 1920)
# batch =  153 stage 1 completed shape= (5, 1024)
# batch 153 time= 1068.3898
# afterbatch 153 length= 154
# (2560, 1920)
# batch =  154 stage 1 completed shape= (5, 1024)
# batch 154 time= 1075.217
# afterbatch 154 length= 155
# (2560, 1920)
# batch =  155 stage 1 completed shape= (5, 1024)
# batch 155 time= 1082.0433
# afterbatch 155 length= 156
# (2560, 1920)
# batch =  156 stage 1 completed shape= (5, 1024)
# batch 156 time= 1088.8663
# afterbatch 156 length= 157
# (2560, 1920)
# batch =  157 stage 1 completed shape= (5, 1024)
# batch 157 time= 1095.6379
# afterbatch 157 length= 158
# (2560, 1920)
# batch =  158 stage 1 completed shape= (5, 1024)
# batch 158 time= 1102.4757
# afterbatch 158 length= 159
# (2560, 1920)
# batch =  159 stage 1 completed shape= (5, 1024)
# batch 159 time= 1109.2661
# afterbatch 159 length= 160
# (2560, 1920)
# batch =  160 stage 1 completed shape= (5, 1024)
# batch 160 time= 1116.0323
# afterbatch 160 length= 161
# (2560, 1920)
# batch =  161 stage 1 completed shape= (5, 1024)
# batch 161 time= 1122.8688
# afterbatch 161 length= 162
# (2560, 1920)
# batch =  162 stage 1 completed shape= (5, 1024)
# batch 162 time= 1129.6313
# afterbatch 162 length= 163
# (2560, 1920)
# batch =  163 stage 1 completed shape= (5, 1024)
# batch 163 time= 1136.4787
# afterbatch 163 length= 164
# (2560, 1920)
# batch =  164 stage 1 completed shape= (5, 1024)
# batch 164 time= 1143.3788
# afterbatch 164 length= 165
# (2560, 1920)
# batch =  165 stage 1 completed shape= (5, 1024)
# batch 165 time= 1150.1323
# afterbatch 165 length= 166
# (2560, 1920)
# batch =  166 stage 1 completed shape= (5, 1024)
# batch 166 time= 1156.9205
# afterbatch 166 length= 167
# (2560, 1920)
# batch =  167 stage 1 completed shape= (5, 1024)
# batch 167 time= 1163.6501
# afterbatch 167 length= 168
# (2560, 1920)
# batch =  168 stage 1 completed shape= (5, 1024)
# batch 168 time= 1170.4418
# afterbatch 168 length= 169
# (2560, 1920)
# batch =  169 stage 1 completed shape= (5, 1024)
# batch 169 time= 1177.1853
# afterbatch 169 length= 170
# (2560, 1920)
# batch =  170 stage 1 completed shape= (5, 1024)
# batch 170 time= 1184.0359
# afterbatch 170 length= 171
# (2560, 1920)
# batch =  171 stage 1 completed shape= (5, 1024)
# batch 171 time= 1190.7888
# afterbatch 171 length= 172
# (2560, 1920)
# batch =  172 stage 1 completed shape= (5, 1024)
# batch 172 time= 1197.5566
# afterbatch 172 length= 173
# (2560, 1920)
# batch =  173 stage 1 completed shape= (5, 1024)
# batch 173 time= 1204.3601
# afterbatch 173 length= 174
# (2560, 1920)
# batch =  174 stage 1 completed shape= (5, 1024)
# batch 174 time= 1211.197
# afterbatch 174 length= 175
# (2560, 1920)
# batch =  175 stage 1 completed shape= (5, 1024)
# batch 175 time= 1217.9773
# afterbatch 175 length= 176
# (2560, 1920)
# batch =  176 stage 1 completed shape= (5, 1024)
# batch 176 time= 1224.844
# afterbatch 176 length= 177
# (2560, 1920)
# batch =  177 stage 1 completed shape= (5, 1024)
# batch 177 time= 1231.701
# afterbatch 177 length= 178
# (2560, 1920)
# batch =  178 stage 1 completed shape= (5, 1024)
# batch 178 time= 1238.5454
# afterbatch 178 length= 179
# (2560, 1920)
# batch =  179 stage 1 completed shape= (5, 1024)
# batch 179 time= 1245.4713
# afterbatch 179 length= 180
# (2560, 1920)
# batch =  180 stage 1 completed shape= (5, 1024)
# batch 180 time= 1252.2124
# afterbatch 180 length= 181
# (2560, 1920)
# batch =  181 stage 1 completed shape= (5, 1024)
# batch 181 time= 1259.0233
# afterbatch 181 length= 182
# (2560, 1920)
# batch =  182 stage 1 completed shape= (5, 1024)
# batch 182 time= 1265.9171
# afterbatch 182 length= 183
# (2560, 1920)
# batch =  183 stage 1 completed shape= (5, 1024)
# batch 183 time= 1272.7703
# afterbatch 183 length= 184
# (2560, 1920)
# batch =  184 stage 1 completed shape= (5, 1024)
# batch 184 time= 1279.5197
# afterbatch 184 length= 185
# (2560, 1920)
# batch =  185 stage 1 completed shape= (5, 1024)
# batch 185 time= 1286.3049
# afterbatch 185 length= 186
# (2560, 1920)
# batch =  186 stage 1 completed shape= (5, 1024)
# batch 186 time= 1293.1088
# afterbatch 186 length= 187
# (2560, 1920)
# batch =  187 stage 1 completed shape= (5, 1024)
# batch 187 time= 1299.9503
# afterbatch 187 length= 188
# (2560, 1920)
# batch =  188 stage 1 completed shape= (5, 1024)
# batch 188 time= 1306.777
# afterbatch 188 length= 189
# (2560, 1920)
# batch =  189 stage 1 completed shape= (5, 1024)
# batch 189 time= 1313.6578
# afterbatch 189 length= 190
# (2560, 1920)
# batch =  190 stage 1 completed shape= (5, 1024)
# batch 190 time= 1320.5228
# afterbatch 190 length= 191
# (2560, 1920)
# batch =  191 stage 1 completed shape= (5, 1024)
# batch 191 time= 1327.3405
# afterbatch 191 length= 192
# (2560, 1920)
# batch =  192 stage 1 completed shape= (5, 1024)
# batch 192 time= 1334.2036
# afterbatch 192 length= 193
# (2560, 1920)
# batch =  193 stage 1 completed shape= (5, 1024)
# batch 193 time= 1341.0894
# afterbatch 193 length= 194
# (2560, 1920)
# batch =  194 stage 1 completed shape= (5, 1024)
# batch 194 time= 1347.8092
# afterbatch 194 length= 195
# (2560, 1920)
# batch =  195 stage 1 completed shape= (5, 1024)
# batch 195 time= 1354.6563
# afterbatch 195 length= 196
# (2560, 1920)
# batch =  196 stage 1 completed shape= (5, 1024)
# batch 196 time= 1361.4485
# afterbatch 196 length= 197
# (2560, 1920)
# batch =  197 stage 1 completed shape= (5, 1024)
# batch 197 time= 1368.2016
# afterbatch 197 length= 198
# (2560, 1920)
# batch =  198 stage 1 completed shape= (5, 1024)
# batch 198 time= 1374.9225
# afterbatch 198 length= 199
# (2560, 1920)
# batch =  199 stage 1 completed shape= (5, 1024)
# batch 199 time= 1381.6957
# afterbatch 199 length= 200
# (2560, 1920)
# batch =  200 stage 1 completed shape= (5, 1024)
# batch 200 time= 1388.5476
# afterbatch 200 length= 201
# (2560, 1920)
# batch =  201 stage 1 completed shape= (5, 1024)
# batch 201 time= 1395.3035
# afterbatch 201 length= 202
# (2560, 1920)
# batch =  202 stage 1 completed shape= (5, 1024)
# batch 202 time= 1402.0902
# afterbatch 202 length= 203
# (2560, 1920)
# batch =  203 stage 1 completed shape= (5, 1024)
# batch 203 time= 1408.9303
# afterbatch 203 length= 204
# (2560, 1920)
# batch =  204 stage 1 completed shape= (5, 1024)
# batch 204 time= 1415.649
# afterbatch 204 length= 205
# (2560, 1920)
# batch =  205 stage 1 completed shape= (5, 1024)
# batch 205 time= 1422.4665
# afterbatch 205 length= 206
# (2560, 1920)
# batch =  206 stage 1 completed shape= (5, 1024)
# batch 206 time= 1429.338
# afterbatch 206 length= 207
# (2560, 1920)
# batch =  207 stage 1 completed shape= (5, 1024)
# batch 207 time= 1436.1852
# afterbatch 207 length= 208
# (2560, 1920)
# batch =  208 stage 1 completed shape= (5, 1024)
# batch 208 time= 1443.0936
# afterbatch 208 length= 209
# (2560, 1920)
# batch =  209 stage 1 completed shape= (5, 1024)
# batch 209 time= 1449.9318
# afterbatch 209 length= 210
# (2560, 1920)
# batch =  210 stage 1 completed shape= (5, 1024)
# batch 210 time= 1456.7071
# afterbatch 210 length= 211
# (2560, 1920)
# batch =  211 stage 1 completed shape= (5, 1024)
# batch 211 time= 1463.5859
# afterbatch 211 length= 212
# (2560, 1920)
# batch =  212 stage 1 completed shape= (5, 1024)
# batch 212 time= 1470.3398
# afterbatch 212 length= 213
# (2560, 1920)
# batch =  213 stage 1 completed shape= (5, 1024)
# batch 213 time= 1477.1391
# afterbatch 213 length= 214
# (2560, 1920)
# batch =  214 stage 1 completed shape= (5, 1024)
# batch 214 time= 1484.0638
# afterbatch 214 length= 215
# (2560, 1920)
# batch =  215 stage 1 completed shape= (5, 1024)
# batch 215 time= 1490.9249
# afterbatch 215 length= 216
# (2560, 1920)
# batch =  216 stage 1 completed shape= (5, 1024)
# batch 216 time= 1497.7283
# afterbatch 216 length= 217
# (2560, 1920)
# batch =  217 stage 1 completed shape= (5, 1024)
# batch 217 time= 1504.5465
# afterbatch 217 length= 218
# (2560, 1920)
# batch =  218 stage 1 completed shape= (5, 1024)
# batch 218 time= 1511.4262
# afterbatch 218 length= 219
# (2560, 1920)
# batch =  219 stage 1 completed shape= (5, 1024)
# batch 219 time= 1518.2108
# afterbatch 219 length= 220
# (2560, 1920)
# batch =  220 stage 1 completed shape= (5, 1024)
# batch 220 time= 1524.9508
# afterbatch 220 length= 221
# (2560, 1920)
# batch =  221 stage 1 completed shape= (5, 1024)
# batch 221 time= 1531.714
# afterbatch 221 length= 222
# (2560, 1920)
# batch =  222 stage 1 completed shape= (5, 1024)
# batch 222 time= 1538.5159
# afterbatch 222 length= 223
# (2560, 1920)
# batch =  223 stage 1 completed shape= (5, 1024)
# batch 223 time= 1545.346
# afterbatch 223 length= 224
# (2560, 1920)
# batch =  224 stage 1 completed shape= (5, 1024)
# batch 224 time= 1552.1273
# afterbatch 224 length= 225
# (2560, 1920)
# batch =  225 stage 1 completed shape= (5, 1024)
# batch 225 time= 1558.9911
# afterbatch 225 length= 226
# (2560, 1920)
# batch =  226 stage 1 completed shape= (5, 1024)
# batch 226 time= 1565.8239
# afterbatch 226 length= 227
# (2560, 1920)
# batch =  227 stage 1 completed shape= (5, 1024)
# batch 227 time= 1572.5468
# afterbatch 227 length= 228
# (2560, 1920)
# batch =  228 stage 1 completed shape= (5, 1024)
# batch 228 time= 1579.3414
# afterbatch 228 length= 229
# (2560, 1920)
# batch =  229 stage 1 completed shape= (5, 1024)
# batch 229 time= 1586.1191
# afterbatch 229 length= 230
# (2560, 1920)
# batch =  230 stage 1 completed shape= (5, 1024)
# batch 230 time= 1592.9495
# afterbatch 230 length= 231
# (2560, 1920)
# batch =  231 stage 1 completed shape= (5, 1024)
# batch 231 time= 1599.775
# afterbatch 231 length= 232
# (2560, 1920)
# batch =  232 stage 1 completed shape= (5, 1024)
# batch 232 time= 1606.5389
# afterbatch 232 length= 233
# (2560, 1920)
# batch =  233 stage 1 completed shape= (5, 1024)
# batch 233 time= 1613.3774
# afterbatch 233 length= 234
# (2560, 1920)
# batch =  234 stage 1 completed shape= (5, 1024)
# batch 234 time= 1620.2083
# afterbatch 234 length= 235
# (2560, 1920)
# batch =  235 stage 1 completed shape= (5, 1024)
# batch 235 time= 1627.0223
# afterbatch 235 length= 236
# (2560, 1920)
# batch =  236 stage 1 completed shape= (5, 1024)
# batch 236 time= 1633.9032
# afterbatch 236 length= 237
# (2560, 1920)
# batch =  237 stage 1 completed shape= (5, 1024)
# batch 237 time= 1640.6629
# afterbatch 237 length= 238
# (2560, 1920)
# batch =  238 stage 1 completed shape= (5, 1024)
# batch 238 time= 1647.5232
# afterbatch 238 length= 239
# (2560, 1920)
# batch =  239 stage 1 completed shape= (5, 1024)
# batch 239 time= 1654.2592
# afterbatch 239 length= 240
# (2560, 1920)
# batch =  240 stage 1 completed shape= (5, 1024)
# batch 240 time= 1661.1189
# afterbatch 240 length= 241
# (2560, 1920)
# batch =  241 stage 1 completed shape= (5, 1024)
# batch 241 time= 1667.9232
# afterbatch 241 length= 242
# (2560, 1920)
# batch =  242 stage 1 completed shape= (5, 1024)
# batch 242 time= 1674.6752
# afterbatch 242 length= 243
# (2560, 1920)
# batch =  243 stage 1 completed shape= (5, 1024)
# batch 243 time= 1681.5057
# afterbatch 243 length= 244
# (2560, 1920)
# batch =  244 stage 1 completed shape= (5, 1024)
# batch 244 time= 1688.2582
# afterbatch 244 length= 245
# (2560, 1920)
# batch =  245 stage 1 completed shape= (5, 1024)
# batch 245 time= 1695.0895
# afterbatch 245 length= 246
# (2560, 1920)
# batch =  246 stage 1 completed shape= (5, 1024)
# batch 246 time= 1701.885
# afterbatch 246 length= 247
# (2560, 1920)
# batch =  247 stage 1 completed shape= (5, 1024)
# batch 247 time= 1708.7656
# afterbatch 247 length= 248
# (2560, 1920)
# batch =  248 stage 1 completed shape= (5, 1024)
# batch 248 time= 1715.595
# afterbatch 248 length= 249
# (2560, 1920)
# batch =  249 stage 1 completed shape= (5, 1024)
# batch 249 time= 1722.4174
# afterbatch 249 length= 250
# (2560, 1920)
# batch =  250 stage 1 completed shape= (5, 1024)
# batch 250 time= 1729.1521
# afterbatch 250 length= 251
# (2560, 1920)
# batch =  251 stage 1 completed shape= (5, 1024)
# batch 251 time= 1735.8934
# afterbatch 251 length= 252
# (2560, 1920)
# batch =  252 stage 1 completed shape= (5, 1024)
# batch 252 time= 1742.689
# afterbatch 252 length= 253
# (2560, 1920)
# batch =  253 stage 1 completed shape= (5, 1024)
# batch 253 time= 1749.4854
# afterbatch 253 length= 254
# (2560, 1920)
# batch =  254 stage 1 completed shape= (5, 1024)
# batch 254 time= 1756.2778
# afterbatch 254 length= 255
# (2560, 1920)
# batch =  255 stage 1 completed shape= (5, 1024)
# batch 255 time= 1763.047
# afterbatch 255 length= 256
# (2560, 1920)
# batch =  256 stage 1 completed shape= (5, 1024)
# batch 256 time= 1769.891
# afterbatch 256 length= 257
# (2560, 1920)
# batch =  257 stage 1 completed shape= (5, 1024)
# batch 257 time= 1776.7063
# afterbatch 257 length= 258
# (2560, 1920)
# batch =  258 stage 1 completed shape= (5, 1024)
# batch 258 time= 1783.5404
# afterbatch 258 length= 259
# (2560, 1920)
# batch =  259 stage 1 completed shape= (5, 1024)
# batch 259 time= 1790.2736
# afterbatch 259 length= 260
# (2560, 1920)
# batch =  260 stage 1 completed shape= (5, 1024)
# batch 260 time= 1797.0667
# afterbatch 260 length= 261
# (2560, 1920)
# batch =  261 stage 1 completed shape= (5, 1024)
# batch 261 time= 1803.872
# afterbatch 261 length= 262
# (2560, 1920)
# batch =  262 stage 1 completed shape= (5, 1024)
# batch 262 time= 1810.6725
# afterbatch 262 length= 263
# (2560, 1920)
# batch =  263 stage 1 completed shape= (5, 1024)
# batch 263 time= 1817.395
# afterbatch 263 length= 264
# (2560, 1920)
# batch =  264 stage 1 completed shape= (5, 1024)
# batch 264 time= 1824.2389
# afterbatch 264 length= 265
# (2560, 1920)
# batch =  265 stage 1 completed shape= (5, 1024)
# batch 265 time= 1831.0711
# afterbatch 265 length= 266
# (2560, 1920)
# batch =  266 stage 1 completed shape= (5, 1024)
# batch 266 time= 1837.8401
# afterbatch 266 length= 267
# (2560, 1920)
# batch =  267 stage 1 completed shape= (5, 1024)
# batch 267 time= 1844.6303
# afterbatch 267 length= 268
# (2560, 1920)
# batch =  268 stage 1 completed shape= (5, 1024)
# batch 268 time= 1851.4613
# afterbatch 268 length= 269
# (2560, 1920)
# batch =  269 stage 1 completed shape= (5, 1024)
# batch 269 time= 1858.3564
# afterbatch 269 length= 270
# (2560, 1920)
# batch =  270 stage 1 completed shape= (5, 1024)
# batch 270 time= 1865.1715
# afterbatch 270 length= 271
# (2560, 1920)
# batch =  271 stage 1 completed shape= (5, 1024)
# batch 271 time= 1871.9013
# afterbatch 271 length= 272
# (2560, 1920)
# batch =  272 stage 1 completed shape= (5, 1024)
# batch 272 time= 1878.726
# afterbatch 272 length= 273
# (2560, 1920)
# batch =  273 stage 1 completed shape= (5, 1024)
# batch 273 time= 1885.4707
# afterbatch 273 length= 274
# (2560, 1920)
# batch =  274 stage 1 completed shape= (5, 1024)
# batch 274 time= 1892.2941
# afterbatch 274 length= 275
# (2560, 1920)
# batch =  275 stage 1 completed shape= (5, 1024)
# batch 275 time= 1899.0315
# afterbatch 275 length= 276
# (2560, 1920)
# batch =  276 stage 1 completed shape= (5, 1024)
# batch 276 time= 1905.8464
# afterbatch 276 length= 277
# (2560, 1920)
# batch =  277 stage 1 completed shape= (5, 1024)
# batch 277 time= 1912.7228
# afterbatch 277 length= 278
# (2560, 1920)
# batch =  278 stage 1 completed shape= (5, 1024)
# batch 278 time= 1919.4708
# afterbatch 278 length= 279
# (2560, 1920)
# batch =  279 stage 1 completed shape= (5, 1024)
# batch 279 time= 1926.3471
# afterbatch 279 length= 280
# (2560, 1920)
# batch =  280 stage 1 completed shape= (5, 1024)
# batch 280 time= 1933.1377
# afterbatch 280 length= 281
# (2560, 1920)
# batch =  281 stage 1 completed shape= (5, 1024)
# batch 281 time= 1939.8904
# afterbatch 281 length= 282
# (2560, 1920)
# batch =  282 stage 1 completed shape= (5, 1024)
# batch 282 time= 1946.6999
# afterbatch 282 length= 283
# (2560, 1920)
# batch =  283 stage 1 completed shape= (5, 1024)
# batch 283 time= 1953.5187
# afterbatch 283 length= 284
# (2560, 1920)
# batch =  284 stage 1 completed shape= (5, 1024)
# batch 284 time= 1960.4166
# afterbatch 284 length= 285
# (2560, 1920)
# batch =  285 stage 1 completed shape= (5, 1024)
# batch 285 time= 1967.1982
# afterbatch 285 length= 286
# (2560, 1920)
# batch =  286 stage 1 completed shape= (5, 1024)
# batch 286 time= 1974.0038
# afterbatch 286 length= 287
# (2560, 1920)
# batch =  287 stage 1 completed shape= (5, 1024)
# batch 287 time= 1980.7508
# afterbatch 287 length= 288
# (2560, 1920)
# batch =  288 stage 1 completed shape= (5, 1024)
# batch 288 time= 1987.6191
# afterbatch 288 length= 289
# (2560, 1920)
# batch =  289 stage 1 completed shape= (5, 1024)
# batch 289 time= 1994.3648
# afterbatch 289 length= 290
# (2560, 1920)
# batch =  290 stage 1 completed shape= (5, 1024)
# batch 290 time= 2001.1906
# afterbatch 290 length= 291
# (2560, 1920)
# batch =  291 stage 1 completed shape= (5, 1024)
# batch 291 time= 2007.8928
# afterbatch 291 length= 292
# (2560, 1920)
# batch =  292 stage 1 completed shape= (5, 1024)
# batch 292 time= 2014.6742
# afterbatch 292 length= 293
# (2560, 1920)
# batch =  293 stage 1 completed shape= (5, 1024)
# batch 293 time= 2021.4864
# afterbatch 293 length= 294
# (2560, 1920)
# batch =  294 stage 1 completed shape= (5, 1024)
# batch 294 time= 2028.2911
# afterbatch 294 length= 295
# (2560, 1920)
# batch =  295 stage 1 completed shape= (5, 1024)
# batch 295 time= 2035.1582
# afterbatch 295 length= 296
# (2560, 1920)
# batch =  296 stage 1 completed shape= (5, 1024)
# batch 296 time= 2041.9638
# afterbatch 296 length= 297
# (2560, 1920)
# batch =  297 stage 1 completed shape= (5, 1024)
# batch 297 time= 2048.7923
# afterbatch 297 length= 298
# (2560, 1920)
# batch =  298 stage 1 completed shape= (5, 1024)
# batch 298 time= 2055.6292
# afterbatch 298 length= 299
# (2560, 1920)
# batch =  299 stage 1 completed shape= (5, 1024)
# batch 299 time= 2062.3587
# afterbatch 299 length= 300
# (2560, 1920)
# batch =  300 stage 1 completed shape= (5, 1024)
# batch 300 time= 2069.2154
# afterbatch 300 length= 301
# (2560, 1920)
# batch =  301 stage 1 completed shape= (5, 1024)
# batch 301 time= 2076.0061
# afterbatch 301 length= 302
# (2560, 1920)
# batch =  302 stage 1 completed shape= (5, 1024)
# batch 302 time= 2082.877
# afterbatch 302 length= 303
# (2560, 1920)
# batch =  303 stage 1 completed shape= (5, 1024)
# batch 303 time= 2089.7315
# afterbatch 303 length= 304
# (2560, 1920)
# batch =  304 stage 1 completed shape= (5, 1024)
# batch 304 time= 2096.5079
# afterbatch 304 length= 305
# (2560, 1920)
# batch =  305 stage 1 completed shape= (5, 1024)
# batch 305 time= 2103.3581
# afterbatch 305 length= 306
# (2560, 1920)
# batch =  306 stage 1 completed shape= (5, 1024)
# batch 306 time= 2110.1067
# afterbatch 306 length= 307
# (2560, 1920)
# batch =  307 stage 1 completed shape= (5, 1024)
# batch 307 time= 2116.8544
# afterbatch 307 length= 308
# (2560, 1920)
# batch =  308 stage 1 completed shape= (5, 1024)
# batch 308 time= 2123.6789
# afterbatch 308 length= 309
# (2560, 1920)
# batch =  309 stage 1 completed shape= (5, 1024)
# batch 309 time= 2130.4078
# afterbatch 309 length= 310
# (2560, 1920)
# batch =  310 stage 1 completed shape= (5, 1024)
# batch 310 time= 2137.1706
# afterbatch 310 length= 311
# (2560, 1920)
# batch =  311 stage 1 completed shape= (5, 1024)
# batch 311 time= 2143.9129
# afterbatch 311 length= 312
# (2560, 1920)
# batch =  312 stage 1 completed shape= (5, 1024)
# batch 312 time= 2150.6704
# afterbatch 312 length= 313
# (2560, 1920)
# batch =  313 stage 1 completed shape= (5, 1024)
# batch 313 time= 2157.4528
# afterbatch 313 length= 314
# (2560, 1920)
# batch =  314 stage 1 completed shape= (5, 1024)
# batch 314 time= 2164.2826
# afterbatch 314 length= 315
# (2560, 1920)
# batch =  315 stage 1 completed shape= (5, 1024)
# batch 315 time= 2171.1079
# afterbatch 315 length= 316
# (2560, 1920)
# batch =  316 stage 1 completed shape= (5, 1024)
# batch 316 time= 2177.9124
# afterbatch 316 length= 317
# (2560, 1920)
# batch =  317 stage 1 completed shape= (5, 1024)
# batch 317 time= 2184.6492
# afterbatch 317 length= 318
# (2560, 1920)
# batch =  318 stage 1 completed shape= (5, 1024)
# batch 318 time= 2191.3665
# afterbatch 318 length= 319
# (2560, 1920)
# batch =  319 stage 1 completed shape= (5, 1024)
# batch 319 time= 2198.1955
# afterbatch 319 length= 320
# (2560, 1920)
# batch =  320 stage 1 completed shape= (5, 1024)
# batch 320 time= 2205.0551
# afterbatch 320 length= 321
# (2560, 1920)
# batch =  321 stage 1 completed shape= (5, 1024)
# batch 321 time= 2211.8107
# afterbatch 321 length= 322
# (2560, 1920)
# batch =  322 stage 1 completed shape= (5, 1024)
# batch 322 time= 2218.6493
# afterbatch 322 length= 323
# (2560, 1920)
# batch =  323 stage 1 completed shape= (5, 1024)
# batch 323 time= 2225.3839
# afterbatch 323 length= 324
# (2560, 1920)
# batch =  324 stage 1 completed shape= (5, 1024)
# batch 324 time= 2232.2287
# afterbatch 324 length= 325
# (2560, 1920)
# batch =  325 stage 1 completed shape= (5, 1024)
# batch 325 time= 2239.0374
# afterbatch 325 length= 326
# (2560, 1920)
# batch =  326 stage 1 completed shape= (5, 1024)
# batch 326 time= 2245.8733
# afterbatch 326 length= 327
# (2560, 1920)
# batch =  327 stage 1 completed shape= (5, 1024)
# batch 327 time= 2252.7178
# afterbatch 327 length= 328
# (2560, 1920)
# batch =  328 stage 1 completed shape= (5, 1024)
# batch 328 time= 2259.4827
# afterbatch 328 length= 329
# (2560, 1920)
# batch =  329 stage 1 completed shape= (5, 1024)
# batch 329 time= 2266.3228
# afterbatch 329 length= 330
# (2560, 1920)
# batch =  330 stage 1 completed shape= (5, 1024)
# batch 330 time= 2273.1916
# afterbatch 330 length= 331
# (2560, 1920)
# batch =  331 stage 1 completed shape= (5, 1024)
# batch 331 time= 2279.9842
# afterbatch 331 length= 332
# (2560, 1920)
# batch =  332 stage 1 completed shape= (5, 1024)
# batch 332 time= 2286.7832
# afterbatch 332 length= 333
# (2560, 1920)
# batch =  333 stage 1 completed shape= (5, 1024)
# batch 333 time= 2293.6753
# afterbatch 333 length= 334
# (2560, 1920)
# batch =  334 stage 1 completed shape= (5, 1024)
# batch 334 time= 2300.4972
# afterbatch 334 length= 335
# (2560, 1920)
# batch =  335 stage 1 completed shape= (5, 1024)
# batch 335 time= 2307.2984
# afterbatch 335 length= 336
# (2560, 1920)
# batch =  336 stage 1 completed shape= (5, 1024)
# batch 336 time= 2314.1511
# afterbatch 336 length= 337
# (2560, 1920)
# batch =  337 stage 1 completed shape= (5, 1024)
# batch 337 time= 2320.9096
# afterbatch 337 length= 338
# (2560, 1920)
# batch =  338 stage 1 completed shape= (5, 1024)
# batch 338 time= 2327.6617
# afterbatch 338 length= 339
# (2560, 1920)
# batch =  339 stage 1 completed shape= (5, 1024)
# batch 339 time= 2334.4634
# afterbatch 339 length= 340
# (2560, 1920)
# batch =  340 stage 1 completed shape= (5, 1024)
# batch 340 time= 2341.3006
# afterbatch 340 length= 341
# (2560, 1920)
# batch =  341 stage 1 completed shape= (5, 1024)
# batch 341 time= 2348.0268
# afterbatch 341 length= 342
# (2560, 1920)
# batch =  342 stage 1 completed shape= (5, 1024)
# batch 342 time= 2354.7868
# afterbatch 342 length= 343
# (2560, 1920)
# batch =  343 stage 1 completed shape= (5, 1024)
# batch 343 time= 2361.552
# afterbatch 343 length= 344
# (2560, 1920)
# batch =  344 stage 1 completed shape= (5, 1024)
# batch 344 time= 2368.2937
# afterbatch 344 length= 345
# (2560, 1920)
# batch =  345 stage 1 completed shape= (5, 1024)
# batch 345 time= 2375.0434
# afterbatch 345 length= 346
# (2560, 1920)
# batch =  346 stage 1 completed shape= (5, 1024)
# batch 346 time= 2381.8518
# afterbatch 346 length= 347
# (2560, 1920)
# batch =  347 stage 1 completed shape= (5, 1024)
# batch 347 time= 2388.7147
# afterbatch 347 length= 348
# (2560, 1920)
# batch =  348 stage 1 completed shape= (5, 1024)
# batch 348 time= 2395.4526
# afterbatch 348 length= 349
# (2560, 1920)
# batch =  349 stage 1 completed shape= (5, 1024)
# batch 349 time= 2402.2507
# afterbatch 349 length= 350
# (2560, 1920)
# batch =  350 stage 1 completed shape= (5, 1024)
# batch 350 time= 2409.0753
# afterbatch 350 length= 351
# (2560, 1920)
# batch =  351 stage 1 completed shape= (5, 1024)
# batch 351 time= 2415.8898
# afterbatch 351 length= 352
# (2560, 1920)
# batch =  352 stage 1 completed shape= (5, 1024)
# batch 352 time= 2422.7264
# afterbatch 352 length= 353
# (2560, 1920)
# batch =  353 stage 1 completed shape= (5, 1024)
# batch 353 time= 2429.5942
# afterbatch 353 length= 354
# (2560, 1920)
# batch =  354 stage 1 completed shape= (5, 1024)
# batch 354 time= 2436.4227
# afterbatch 354 length= 355
# (2560, 1920)
# batch =  355 stage 1 completed shape= (5, 1024)
# batch 355 time= 2443.2945
# afterbatch 355 length= 356
# (2560, 1920)
# batch =  356 stage 1 completed shape= (5, 1024)
# batch 356 time= 2450.1383
# afterbatch 356 length= 357
# (2560, 1920)
# batch =  357 stage 1 completed shape= (5, 1024)
# batch 357 time= 2456.9346
# afterbatch 357 length= 358
# (2560, 1920)
# batch =  358 stage 1 completed shape= (5, 1024)
# batch 358 time= 2463.709
# afterbatch 358 length= 359
# (2560, 1920)
# batch =  359 stage 1 completed shape= (5, 1024)
# batch 359 time= 2470.5147
# afterbatch 359 length= 360
# (2560, 1920)
# batch =  360 stage 1 completed shape= (5, 1024)
# batch 360 time= 2477.3379
# afterbatch 360 length= 361
# (2560, 1920)
# batch =  361 stage 1 completed shape= (5, 1024)
# batch 361 time= 2484.1844
# afterbatch 361 length= 362
# (2560, 1920)
# batch =  362 stage 1 completed shape= (5, 1024)
# batch 362 time= 2491.0188
# afterbatch 362 length= 363
# (2560, 1920)
# batch =  363 stage 1 completed shape= (5, 1024)
# batch 363 time= 2497.7941
# afterbatch 363 length= 364
# (2560, 1920)
# batch =  364 stage 1 completed shape= (5, 1024)
# batch 364 time= 2504.5254
# afterbatch 364 length= 365
# (2560, 1920)
# batch =  365 stage 1 completed shape= (5, 1024)
# batch 365 time= 2511.2615
# afterbatch 365 length= 366
# (2560, 1920)
# batch =  366 stage 1 completed shape= (5, 1024)
# batch 366 time= 2518.1178
# afterbatch 366 length= 367
# (2560, 1920)
# batch =  367 stage 1 completed shape= (5, 1024)
# batch 367 time= 2524.8842
# afterbatch 367 length= 368
# (2560, 1920)
# batch =  368 stage 1 completed shape= (5, 1024)
# batch 368 time= 2531.744
# afterbatch 368 length= 369
# (2560, 1920)
# batch =  369 stage 1 completed shape= (5, 1024)
# batch 369 time= 2538.5384
# afterbatch 369 length= 370
# (2560, 1920)
# batch =  370 stage 1 completed shape= (5, 1024)
# batch 370 time= 2545.3444
# afterbatch 370 length= 371
# (2560, 1920)
# batch =  371 stage 1 completed shape= (5, 1024)
# batch 371 time= 2552.0771
# afterbatch 371 length= 372
# (2560, 1920)
# batch =  372 stage 1 completed shape= (5, 1024)
# batch 372 time= 2558.8516
# afterbatch 372 length= 373
# (2560, 1920)
# batch =  373 stage 1 completed shape= (5, 1024)
# batch 373 time= 2565.57
# afterbatch 373 length= 374
# (2560, 1920)
# batch =  374 stage 1 completed shape= (5, 1024)
# batch 374 time= 2572.299
# afterbatch 374 length= 375
# (2560, 1920)
# batch =  375 stage 1 completed shape= (5, 1024)
# batch 375 time= 2579.0932
# afterbatch 375 length= 376
# (2560, 1920)
# batch =  376 stage 1 completed shape= (5, 1024)
# batch 376 time= 2585.938
# afterbatch 376 length= 377
# (2560, 1920)
# batch =  377 stage 1 completed shape= (5, 1024)
# batch 377 time= 2592.829
# afterbatch 377 length= 378
# (2560, 1920)
# batch =  378 stage 1 completed shape= (5, 1024)
# batch 378 time= 2599.6383
# afterbatch 378 length= 379
# (2560, 1920)
# batch =  379 stage 1 completed shape= (5, 1024)
# batch 379 time= 2606.4631
# afterbatch 379 length= 380
# (2560, 1920)
# batch =  380 stage 1 completed shape= (5, 1024)
# batch 380 time= 2613.252
# afterbatch 380 length= 381
# (2560, 1920)
# batch =  381 stage 1 completed shape= (5, 1024)
# batch 381 time= 2619.9964
# afterbatch 381 length= 382
# (2560, 1920)
# batch =  382 stage 1 completed shape= (5, 1024)
# batch 382 time= 2626.8183
# afterbatch 382 length= 383
# (2560, 1920)
# batch =  383 stage 1 completed shape= (5, 1024)
# batch 383 time= 2633.6808
# afterbatch 383 length= 384
# (2560, 1920)
# batch =  384 stage 1 completed shape= (5, 1024)
# batch 384 time= 2640.517
# afterbatch 384 length= 385
# (2560, 1920)
# batch =  385 stage 1 completed shape= (5, 1024)
# batch 385 time= 2647.3096
# afterbatch 385 length= 386
# (2560, 1920)
# batch =  386 stage 1 completed shape= (5, 1024)
# batch 386 time= 2654.0817
# afterbatch 386 length= 387
# (2560, 1920)
# batch =  387 stage 1 completed shape= (5, 1024)
# batch 387 time= 2660.8853
# afterbatch 387 length= 388
# (2560, 1920)
# batch =  388 stage 1 completed shape= (5, 1024)
# batch 388 time= 2667.6481
# afterbatch 388 length= 389
# (2560, 1920)
# batch =  389 stage 1 completed shape= (5, 1024)
# batch 389 time= 2674.4595
# afterbatch 389 length= 390
# (2560, 1920)
# batch =  390 stage 1 completed shape= (5, 1024)
# batch 390 time= 2681.312
# afterbatch 390 length= 391
# (2560, 1920)
# batch =  391 stage 1 completed shape= (5, 1024)
# batch 391 time= 2688.0895
# afterbatch 391 length= 392
# (2560, 1920)
# batch =  392 stage 1 completed shape= (5, 1024)
# batch 392 time= 2694.8849
# afterbatch 392 length= 393
# (2560, 1920)
# batch =  393 stage 1 completed shape= (5, 1024)
# batch 393 time= 2701.6834
# afterbatch 393 length= 394
# (2560, 1920)
# batch =  394 stage 1 completed shape= (5, 1024)
# batch 394 time= 2708.5385
# afterbatch 394 length= 395
# (2560, 1920)
# batch =  395 stage 1 completed shape= (5, 1024)
# batch 395 time= 2715.3007
# afterbatch 395 length= 396
# (2560, 1920)
# batch =  396 stage 1 completed shape= (5, 1024)
# batch 396 time= 2722.1116
# afterbatch 396 length= 397
# (2560, 1920)
# batch =  397 stage 1 completed shape= (5, 1024)
# batch 397 time= 2728.9612
# afterbatch 397 length= 398
# (2560, 1920)
# batch =  398 stage 1 completed shape= (5, 1024)
# batch 398 time= 2735.8426
# afterbatch 398 length= 399
# (2560, 1920)
# batch =  399 stage 1 completed shape= (5, 1024)
# batch 399 time= 2742.6817
# afterbatch 399 length= 400
# (2560, 1920)
# batch =  400 stage 1 completed shape= (5, 1024)
# batch 400 time= 2749.5003
# afterbatch 400 length= 401
# (2560, 1920)
# batch =  401 stage 1 completed shape= (5, 1024)
# batch 401 time= 2756.4221
# afterbatch 401 length= 402
# (2560, 1920)
# batch =  402 stage 1 completed shape= (5, 1024)
# batch 402 time= 2763.2241
# afterbatch 402 length= 403
# (2560, 1920)
# batch =  403 stage 1 completed shape= (5, 1024)
# batch 403 time= 2770.0248
# afterbatch 403 length= 404
# (2560, 1920)
# batch =  404 stage 1 completed shape= (5, 1024)
# batch 404 time= 2776.8041
# afterbatch 404 length= 405
# (2560, 1920)
# batch =  405 stage 1 completed shape= (5, 1024)
# batch 405 time= 2783.6268
# afterbatch 405 length= 406
# (2560, 1920)
# batch =  406 stage 1 completed shape= (5, 1024)
# batch 406 time= 2790.414
# afterbatch 406 length= 407
# (2560, 1920)
# batch =  407 stage 1 completed shape= (5, 1024)
# batch 407 time= 2797.2385
# afterbatch 407 length= 408
# (2560, 1920)
# batch =  408 stage 1 completed shape= (5, 1024)
# batch 408 time= 2804.1434
# afterbatch 408 length= 409
# (2560, 1920)
# batch =  409 stage 1 completed shape= (5, 1024)
# batch 409 time= 2810.8815
# afterbatch 409 length= 410
# (2560, 1920)
# batch =  410 stage 1 completed shape= (5, 1024)
# batch 410 time= 2817.6886
# afterbatch 410 length= 411
# (2560, 1920)
# batch =  411 stage 1 completed shape= (5, 1024)
# batch 411 time= 2824.4653
# afterbatch 411 length= 412
# (2560, 1920)
# batch =  412 stage 1 completed shape= (5, 1024)
# batch 412 time= 2831.3066
# afterbatch 412 length= 413
# (2560, 1920)
# batch =  413 stage 1 completed shape= (5, 1024)
# batch 413 time= 2838.1671
# afterbatch 413 length= 414
# (2560, 1920)
# batch =  414 stage 1 completed shape= (5, 1024)
# batch 414 time= 2844.9932
# afterbatch 414 length= 415
# (2560, 1920)
# batch =  415 stage 1 completed shape= (5, 1024)
# batch 415 time= 2851.7504
# afterbatch 415 length= 416
# (2560, 1920)
# batch =  416 stage 1 completed shape= (5, 1024)
# batch 416 time= 2858.5297
# afterbatch 416 length= 417
# (2560, 1920)
# batch =  417 stage 1 completed shape= (5, 1024)
# batch 417 time= 2865.2911
# afterbatch 417 length= 418
# (2560, 1920)
# batch =  418 stage 1 completed shape= (5, 1024)
# batch 418 time= 2872.1097
# afterbatch 418 length= 419
# (2560, 1920)
# batch =  419 stage 1 completed shape= (5, 1024)
# batch 419 time= 2878.9412
# afterbatch 419 length= 420
# (2560, 1920)
# batch =  420 stage 1 completed shape= (5, 1024)
# batch 420 time= 2885.6834
# afterbatch 420 length= 421
# (2560, 1920)
# batch =  421 stage 1 completed shape= (5, 1024)
# batch 421 time= 2892.4634
# afterbatch 421 length= 422
# (2560, 1920)
# batch =  422 stage 1 completed shape= (5, 1024)
# batch 422 time= 2899.2531
# afterbatch 422 length= 423
# (2560, 1920)
# batch =  423 stage 1 completed shape= (5, 1024)
# batch 423 time= 2905.9751
# afterbatch 423 length= 424
# (2560, 1920)
# batch =  424 stage 1 completed shape= (5, 1024)
# batch 424 time= 2912.7001
# afterbatch 424 length= 425
# (2560, 1920)
# batch =  425 stage 1 completed shape= (5, 1024)
# batch 425 time= 2919.4734
# afterbatch 425 length= 426
# (2560, 1920)
# batch =  426 stage 1 completed shape= (5, 1024)
# batch 426 time= 2926.2825
# afterbatch 426 length= 427
# (2560, 1920)
# batch =  427 stage 1 completed shape= (5, 1024)
# batch 427 time= 2933.0884
# afterbatch 427 length= 428
# (2560, 1920)
# batch =  428 stage 1 completed shape= (5, 1024)
# batch 428 time= 2939.8631
# afterbatch 428 length= 429
# (2560, 1920)
# batch =  429 stage 1 completed shape= (5, 1024)
# batch 429 time= 2946.6183
# afterbatch 429 length= 430
# (2560, 1920)
# batch =  430 stage 1 completed shape= (5, 1024)
# batch 430 time= 2953.4027
# afterbatch 430 length= 431
# (2560, 1920)
# batch =  431 stage 1 completed shape= (5, 1024)
# batch 431 time= 2960.1664
# afterbatch 431 length= 432
# (2560, 1920)
# batch =  432 stage 1 completed shape= (5, 1024)
# batch 432 time= 2966.9913
# afterbatch 432 length= 433
# (2560, 1920)
# batch =  433 stage 1 completed shape= (5, 1024)
# batch 433 time= 2973.741
# afterbatch 433 length= 434
# (2560, 1920)
# batch =  434 stage 1 completed shape= (5, 1024)
# batch 434 time= 2980.5633
# afterbatch 434 length= 435
# (2560, 1920)
# batch =  435 stage 1 completed shape= (5, 1024)
# batch 435 time= 2987.4115
# afterbatch 435 length= 436
# (2560, 1920)
# batch =  436 stage 1 completed shape= (5, 1024)
# batch 436 time= 2994.2223
# afterbatch 436 length= 437
# (2560, 1920)
# batch =  437 stage 1 completed shape= (5, 1024)
# batch 437 time= 3001.0472
# afterbatch 437 length= 438
# (2560, 1920)
# batch =  438 stage 1 completed shape= (5, 1024)
# batch 438 time= 3007.9083
# afterbatch 438 length= 439
# (2560, 1920)
# batch =  439 stage 1 completed shape= (5, 1024)
# batch 439 time= 3014.6454
# afterbatch 439 length= 440
# (2560, 1920)
# batch =  440 stage 1 completed shape= (5, 1024)
# batch 440 time= 3021.5362
# afterbatch 440 length= 441
# (2560, 1920)
# batch =  441 stage 1 completed shape= (5, 1024)
# batch 441 time= 3028.355
# afterbatch 441 length= 442
# (2560, 1920)
# batch =  442 stage 1 completed shape= (5, 1024)
# batch 442 time= 3035.2089
# afterbatch 442 length= 443
# (2560, 1920)
# batch =  443 stage 1 completed shape= (5, 1024)
# batch 443 time= 3041.9531
# afterbatch 443 length= 444
# (2560, 1920)
# batch =  444 stage 1 completed shape= (5, 1024)
# batch 444 time= 3048.6924
# afterbatch 444 length= 445
# (2560, 1920)
# batch =  445 stage 1 completed shape= (5, 1024)
# batch 445 time= 3055.4549
# afterbatch 445 length= 446
# (2560, 1920)
# batch =  446 stage 1 completed shape= (5, 1024)
# batch 446 time= 3062.3956
# afterbatch 446 length= 447
# (2560, 1920)
# batch =  447 stage 1 completed shape= (5, 1024)
# batch 447 time= 3069.1762
# afterbatch 447 length= 448
# (2560, 1920)
# batch =  448 stage 1 completed shape= (5, 1024)
# batch 448 time= 3075.9727
# afterbatch 448 length= 449
# (2560, 1920)
# batch =  449 stage 1 completed shape= (5, 1024)
# batch 449 time= 3082.7733
# afterbatch 449 length= 450
# (2560, 1920)
# batch =  450 stage 1 completed shape= (5, 1024)
# batch 450 time= 3089.5236
# afterbatch 450 length= 451
# (2560, 1920)
# batch =  451 stage 1 completed shape= (5, 1024)
# batch 451 time= 3096.2705
# afterbatch 451 length= 452
# (2560, 1920)
# batch =  452 stage 1 completed shape= (5, 1024)
# batch 452 time= 3103.0885
# afterbatch 452 length= 453
# (2560, 1920)
# batch =  453 stage 1 completed shape= (5, 1024)
# batch 453 time= 3109.8934
# afterbatch 453 length= 454
# (2560, 1920)
# batch =  454 stage 1 completed shape= (5, 1024)
# batch 454 time= 3116.6223
# afterbatch 454 length= 455
# (2560, 1920)
# batch =  455 stage 1 completed shape= (5, 1024)
# batch 455 time= 3123.5063
# afterbatch 455 length= 456
# (2560, 1920)
# batch =  456 stage 1 completed shape= (5, 1024)
# batch 456 time= 3130.2655
# afterbatch 456 length= 457
# (2560, 1920)
# batch =  457 stage 1 completed shape= (5, 1024)
# batch 457 time= 3137.1004
# afterbatch 457 length= 458
# (2560, 1920)
# batch =  458 stage 1 completed shape= (5, 1024)
# batch 458 time= 3143.9068
# afterbatch 458 length= 459
# (2560, 1920)
# batch =  459 stage 1 completed shape= (5, 1024)
# batch 459 time= 3150.7584
# afterbatch 459 length= 460
# (2560, 1920)
# batch =  460 stage 1 completed shape= (5, 1024)
# batch 460 time= 3157.5183
# afterbatch 460 length= 461
# (2560, 1920)
# batch =  461 stage 1 completed shape= (5, 1024)
# batch 461 time= 3164.3036
# afterbatch 461 length= 462
# (2560, 1920)
# batch =  462 stage 1 completed shape= (5, 1024)
# batch 462 time= 3171.1158
# afterbatch 462 length= 463
# (2560, 1920)
# batch =  463 stage 1 completed shape= (5, 1024)
# batch 463 time= 3177.9194
# afterbatch 463 length= 464
# (2560, 1920)
# batch =  464 stage 1 completed shape= (5, 1024)
# batch 464 time= 3184.6936
# afterbatch 464 length= 465
# (2560, 1920)
# batch =  465 stage 1 completed shape= (5, 1024)
# batch 465 time= 3191.4802
# afterbatch 465 length= 466
# (2560, 1920)
# batch =  466 stage 1 completed shape= (5, 1024)
# batch 466 time= 3198.2292
# afterbatch 466 length= 467
# (2560, 1920)
# batch =  467 stage 1 completed shape= (5, 1024)
# batch 467 time= 3205.0317
# afterbatch 467 length= 468
# (2560, 1920)
# batch =  468 stage 1 completed shape= (5, 1024)
# batch 468 time= 3211.8935
# afterbatch 468 length= 469
# (2560, 1920)
# batch =  469 stage 1 completed shape= (5, 1024)
# batch 469 time= 3218.7292
# afterbatch 469 length= 470
# (2560, 1920)
# batch =  470 stage 1 completed shape= (5, 1024)
# batch 470 time= 3225.5332
# afterbatch 470 length= 471
# (2560, 1920)
# batch =  471 stage 1 completed shape= (5, 1024)
# batch 471 time= 3232.3675
# afterbatch 471 length= 472
# (2560, 1920)
# batch =  472 stage 1 completed shape= (5, 1024)
# batch 472 time= 3239.1505
# afterbatch 472 length= 473
# (2560, 1920)
# batch =  473 stage 1 completed shape= (5, 1024)
# batch 473 time= 3245.9466
# afterbatch 473 length= 474
# (2560, 1920)
# batch =  474 stage 1 completed shape= (5, 1024)
# batch 474 time= 3252.7912
# afterbatch 474 length= 475
# (2560, 1920)
# batch =  475 stage 1 completed shape= (5, 1024)
# batch 475 time= 3259.6026
# afterbatch 475 length= 476
# (2560, 1920)
# batch =  476 stage 1 completed shape= (5, 1024)
# batch 476 time= 3266.3739
# afterbatch 476 length= 477
# (2560, 1920)
# batch =  477 stage 1 completed shape= (1, 1024)
# batch 477 time= 3268.8266
# afterbatch 477 length= 478
# train_final array_1 (2386, 1024)
# totally done, train_data_DenseNet_1_verification.npy

# %%
test_file_list =  os.listdir(src_3)


if '.DS_Store' in test_file_list:
    test_file_list.remove('.DS_Store')

test_final_array_1 = make_data(test_file_list,model_1,src_3)
print ('test_final array_1', test_final_array_1.shape)
np.save(src_save+'test_data_DenseNet121_1_verification.npy',test_final_array_1)
print ('totally done, test_final_data_DenseNet121_1_verification.npy')
# Out:
# floor= 62
# total size 440 file_list 440 final_list length NOT equal to file_list
# 0
# warning, something wrong
# 63
# (2560, 1920)
# batch =  0 stage 1 completed shape= (7, 1024)
# batch 0 time= 26.7989
# afterbatch 0 length= 1
# (2560, 1920)
# batch =  1 stage 1 completed shape= (7, 1024)
# batch 1 time= 36.1722
# afterbatch 1 length= 2
# (2560, 1920)
# batch =  2 stage 1 completed shape= (7, 1024)
# batch 2 time= 45.4679
# afterbatch 2 length= 3
# (2560, 1920)
# batch =  3 stage 1 completed shape= (7, 1024)
# batch 3 time= 54.7421
# afterbatch 3 length= 4
# (2560, 1920)
# batch =  4 stage 1 completed shape= (7, 1024)
# batch 4 time= 64.197
# afterbatch 4 length= 5
# (2560, 1920)
# batch =  5 stage 1 completed shape= (7, 1024)
# batch 5 time= 73.5009
# afterbatch 5 length= 6
# (2560, 1920)
# batch =  6 stage 1 completed shape= (7, 1024)
# batch 6 time= 82.9802
# afterbatch 6 length= 7
# (2560, 1920)
# batch =  7 stage 1 completed shape= (7, 1024)
# batch 7 time= 92.4764
# afterbatch 7 length= 8
# (2560, 1920)
# batch =  8 stage 1 completed shape= (7, 1024)
# batch 8 time= 101.9551
# afterbatch 8 length= 9
# (2560, 1920)
# batch =  9 stage 1 completed shape= (7, 1024)
# batch 9 time= 111.4339
# afterbatch 9 length= 10
# (2560, 1920)
# batch =  10 stage 1 completed shape= (7, 1024)
# batch 10 time= 120.7496
# afterbatch 10 length= 11
# (2560, 1920)
# batch =  11 stage 1 completed shape= (7, 1024)
# batch 11 time= 130.1482
# afterbatch 11 length= 12
# (2560, 1920)
# batch =  12 stage 1 completed shape= (7, 1024)
# batch 12 time= 139.6486
# afterbatch 12 length= 13
# (2560, 1920)
# batch =  13 stage 1 completed shape= (7, 1024)
# batch 13 time= 148.9422
# afterbatch 13 length= 14
# (2560, 1920)
# batch =  14 stage 1 completed shape= (7, 1024)
# batch 14 time= 158.4599
# afterbatch 14 length= 15
# (2560, 1920)
# batch =  15 stage 1 completed shape= (7, 1024)
# batch 15 time= 167.9517
# afterbatch 15 length= 16
# (2560, 1920)
# batch =  16 stage 1 completed shape= (7, 1024)
# batch 16 time= 177.4567
# afterbatch 16 length= 17
# (2560, 1920)
# batch =  17 stage 1 completed shape= (7, 1024)
# batch 17 time= 186.9426
# afterbatch 17 length= 18
# (2560, 1920)
# batch =  18 stage 1 completed shape= (7, 1024)
# batch 18 time= 196.4034
# afterbatch 18 length= 19
# (2560, 1920)
# batch =  19 stage 1 completed shape= (7, 1024)
# batch 19 time= 205.9073
# afterbatch 19 length= 20
# (2560, 1920)
# batch =  20 stage 1 completed shape= (7, 1024)
# batch 20 time= 215.2874
# afterbatch 20 length= 21
# (2560, 1920)
# batch =  21 stage 1 completed shape= (7, 1024)
# batch 21 time= 224.7947
# afterbatch 21 length= 22
# (2560, 1920)
# batch =  22 stage 1 completed shape= (7, 1024)
# batch 22 time= 234.3415
# afterbatch 22 length= 23
# (2560, 1920)
# batch =  23 stage 1 completed shape= (7, 1024)
# batch 23 time= 243.8595
# afterbatch 23 length= 24
# (2560, 1920)
# batch =  24 stage 1 completed shape= (7, 1024)
# batch 24 time= 253.3954
# afterbatch 24 length= 25
# (2560, 1920)
# batch =  25 stage 1 completed shape= (7, 1024)
# batch 25 time= 262.7611
# afterbatch 25 length= 26
# (2560, 1920)
# batch =  26 stage 1 completed shape= (7, 1024)
# batch 26 time= 272.025
# afterbatch 26 length= 27
# (2560, 1920)
# batch =  27 stage 1 completed shape= (7, 1024)
# batch 27 time= 281.2954
# afterbatch 27 length= 28
# (2560, 1920)
# batch =  28 stage 1 completed shape= (7, 1024)
# batch 28 time= 290.6089
# afterbatch 28 length= 29
# (2560, 1920)
# batch =  29 stage 1 completed shape= (7, 1024)
# batch 29 time= 300.1671
# afterbatch 29 length= 30
# (2560, 1920)
# batch =  30 stage 1 completed shape= (7, 1024)
# batch 30 time= 309.7061
# afterbatch 30 length= 31
# (2560, 1920)
# batch =  31 stage 1 completed shape= (7, 1024)
# batch 31 time= 319.2308
# afterbatch 31 length= 32
# (2560, 1920)
# batch =  32 stage 1 completed shape= (7, 1024)
# batch 32 time= 328.6928
# afterbatch 32 length= 33
# (2560, 1920)
# batch =  33 stage 1 completed shape= (7, 1024)
# batch 33 time= 338.1726
# afterbatch 33 length= 34
# (2560, 1920)
# batch =  34 stage 1 completed shape= (7, 1024)
# batch 34 time= 347.5592
# afterbatch 34 length= 35
# (2560, 1920)
# batch =  35 stage 1 completed shape= (7, 1024)
# batch 35 time= 357.0642
# afterbatch 35 length= 36
# (2560, 1920)
# batch =  36 stage 1 completed shape= (7, 1024)
# batch 36 time= 366.5833
# afterbatch 36 length= 37
# (2560, 1920)
# batch =  37 stage 1 completed shape= (7, 1024)
# batch 37 time= 375.9011
# afterbatch 37 length= 38
# (2560, 1920)
# batch =  38 stage 1 completed shape= (7, 1024)
# batch 38 time= 385.2857
# afterbatch 38 length= 39
# (2560, 1920)
# batch =  39 stage 1 completed shape= (7, 1024)
# batch 39 time= 394.7413
# afterbatch 39 length= 40
# (2560, 1920)
# batch =  40 stage 1 completed shape= (7, 1024)
# batch 40 time= 404.0711
# afterbatch 40 length= 41
# (2560, 1920)
# batch =  41 stage 1 completed shape= (7, 1024)
# batch 41 time= 413.3659
# afterbatch 41 length= 42
# (2560, 1920)
# batch =  42 stage 1 completed shape= (7, 1024)
# batch 42 time= 422.8931
# afterbatch 42 length= 43
# (2560, 1920)
# batch =  43 stage 1 completed shape= (7, 1024)
# batch 43 time= 432.4287
# afterbatch 43 length= 44
# (2560, 1920)
# batch =  44 stage 1 completed shape= (7, 1024)
# batch 44 time= 441.942
# afterbatch 44 length= 45
# (2560, 1920)
# batch =  45 stage 1 completed shape= (7, 1024)
# batch 45 time= 451.4338
# afterbatch 45 length= 46
# (2560, 1920)
# batch =  46 stage 1 completed shape= (7, 1024)
# batch 46 time= 460.9249
# afterbatch 46 length= 47
# (2560, 1920)
# batch =  47 stage 1 completed shape= (7, 1024)
# batch 47 time= 470.3949
# afterbatch 47 length= 48
# (2560, 1920)
# batch =  48 stage 1 completed shape= (7, 1024)
# batch 48 time= 479.8829
# afterbatch 48 length= 49
# (2560, 1920)
# batch =  49 stage 1 completed shape= (7, 1024)
# batch 49 time= 489.3681
# afterbatch 49 length= 50
# (2560, 1920)
# batch =  50 stage 1 completed shape= (7, 1024)
# batch 50 time= 498.8985
# afterbatch 50 length= 51
# (2560, 1920)
# batch =  51 stage 1 completed shape= (7, 1024)
# batch 51 time= 508.4269
# afterbatch 51 length= 52
# (2560, 1920)
# batch =  52 stage 1 completed shape= (7, 1024)
# batch 52 time= 517.7732
# afterbatch 52 length= 53
# (2560, 1920)
# batch =  53 stage 1 completed shape= (7, 1024)
# batch 53 time= 527.0838
# afterbatch 53 length= 54
# (2560, 1920)
# batch =  54 stage 1 completed shape= (7, 1024)
# batch 54 time= 536.4537
# afterbatch 54 length= 55
# (2560, 1920)
# batch =  55 stage 1 completed shape= (7, 1024)
# batch 55 time= 545.9585
# afterbatch 55 length= 56
# (2560, 1920)
# batch =  56 stage 1 completed shape= (7, 1024)
# batch 56 time= 555.2201
# afterbatch 56 length= 57
# (2560, 1920)
# batch =  57 stage 1 completed shape= (7, 1024)
# batch 57 time= 564.5035
# afterbatch 57 length= 58
# (2560, 1920)
# batch =  58 stage 1 completed shape= (7, 1024)
# batch 58 time= 573.829
# afterbatch 58 length= 59
# (2560, 1920)
# batch =  59 stage 1 completed shape= (7, 1024)
# batch 59 time= 583.1163
# afterbatch 59 length= 60
# (2560, 1920)
# batch =  60 stage 1 completed shape= (7, 1024)
# batch 60 time= 592.6275
# afterbatch 60 length= 61
# (2560, 1920)
# batch =  61 stage 1 completed shape= (7, 1024)
# batch 61 time= 602.1454
# afterbatch 61 length= 62
# (2560, 1920)
# batch =  62 stage 1 completed shape= (6, 1024)
# batch 62 time= 615.2028
# afterbatch 62 length= 63
# test_final array_1 (440, 1024)
# totally done, test_final_data_DenseNet121_1_verification.npy

# %%
'''
delet model 1, then start to prepare model_2
'''

del model_1

# %%
def build_model_2():


    inputs_2 = Input(shape=(480,640,3))
    base_model_2 = DenseNet121(weights='imagenet',input_tensor=inputs_2,  include_top=True)
    model_2_out = base_model_2.layers[135].output

    model_2 = Model(inputs=base_model_2.input, outputs=model_2_out)

    model_2.summary()

    return model_2





# In[ ]:


model_2 = build_model_2()






model_2.compile(optimizer='adam', loss='categorical_crossentropy',metrics=['accuracy'])


def make_data(file_list,model,src):

    
    '''
    first make bacth, then make data
    '''
    batch_size = 7
    final_list = make_batch(file_list,batch_size)
    print (len(final_list))




    s= time.time()
    final_array = []
    for j,l in enumerate(final_list):
          img_list=[]
          for i,img in enumerate(l):
              img = load_img(src+img)

              img = img.resize((2560//4,1920//4))

              x = img_to_array(img)
              x = preprocess_input(x)
              if i  == 0 :


                print (x.shape)
              #x = cv2.cvtColor(y, cv2.COLOR_BGR2RGB)
              #x = x/127.5 -1.
              img_list.append(x)
          #print ('img_list=', len(img_list))
          testing_data = np.array(img_list)

          #print ('testing_data_shape', testing_data.shape)
          #train_data =  train_data[:,:,:,np.newaxis]
          #print (testing_data.shape)
          pred_temp = model.predict(testing_data)

          print('batch = ', j, 'stage 1 completed', 'shape=', pred_temp.shape)
          #np.save(src_save+'temp_'+str(j)+'.npy',pred_temp)

          #print ('bacth npy saved', j)
          e = time.time()
          print ('batch',j,'time=', round(e -s ,4))

          final_array.append(pred_temp)
          print ('afterbatch',j,'length=', len(final_array))

    final_array = np.concatenate(final_array)

    return final_array
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_10 (InputLayer)           (None, 480, 640, 3)  0
# __________________________________________________________________________________________________
# zero_padding2d_11 (ZeroPadding2 (None, 486, 646, 3)  0           input_10[0][0]
# __________________________________________________________________________________________________
# conv1/conv (Conv2D)             (None, 240, 320, 64) 9408        zero_padding2d_11[0][0]
# __________________________________________________________________________________________________
# conv1/bn (BatchNormalization)   (None, 240, 320, 64) 256         conv1/conv[0][0]
# __________________________________________________________________________________________________
# conv1/relu (Activation)         (None, 240, 320, 64) 0           conv1/bn[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_12 (ZeroPadding2 (None, 242, 322, 64) 0           conv1/relu[0][0]
# __________________________________________________________________________________________________
# pool1 (MaxPooling2D)            (None, 120, 160, 64) 0           zero_padding2d_12[0][0]
# __________________________________________________________________________________________________
# conv2_block1_0_bn (BatchNormali (None, 120, 160, 64) 256         pool1[0][0]
# __________________________________________________________________________________________________
# conv2_block1_0_relu (Activation (None, 120, 160, 64) 0           conv2_block1_0_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block1_1_conv (Conv2D)    (None, 120, 160, 128 8192        conv2_block1_0_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block1_1_bn (BatchNormali (None, 120, 160, 128 512         conv2_block1_1_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block1_1_relu (Activation (None, 120, 160, 128 0           conv2_block1_1_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block1_2_conv (Conv2D)    (None, 120, 160, 32) 36864       conv2_block1_1_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block1_concat (Concatenat (None, 120, 160, 96) 0           pool1[0][0]
#                                                                  conv2_block1_2_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block2_0_bn (BatchNormali (None, 120, 160, 96) 384         conv2_block1_concat[0][0]
# __________________________________________________________________________________________________
# conv2_block2_0_relu (Activation (None, 120, 160, 96) 0           conv2_block2_0_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block2_1_conv (Conv2D)    (None, 120, 160, 128 12288       conv2_block2_0_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block2_1_bn (BatchNormali (None, 120, 160, 128 512         conv2_block2_1_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block2_1_relu (Activation (None, 120, 160, 128 0           conv2_block2_1_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block2_2_conv (Conv2D)    (None, 120, 160, 32) 36864       conv2_block2_1_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block2_concat (Concatenat (None, 120, 160, 128 0           conv2_block1_concat[0][0]
#                                                                  conv2_block2_2_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block3_0_bn (BatchNormali (None, 120, 160, 128 512         conv2_block2_concat[0][0]
# __________________________________________________________________________________________________
# conv2_block3_0_relu (Activation (None, 120, 160, 128 0           conv2_block3_0_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block3_1_conv (Conv2D)    (None, 120, 160, 128 16384       conv2_block3_0_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block3_1_bn (BatchNormali (None, 120, 160, 128 512         conv2_block3_1_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block3_1_relu (Activation (None, 120, 160, 128 0           conv2_block3_1_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block3_2_conv (Conv2D)    (None, 120, 160, 32) 36864       conv2_block3_1_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block3_concat (Concatenat (None, 120, 160, 160 0           conv2_block2_concat[0][0]
#                                                                  conv2_block3_2_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block4_0_bn (BatchNormali (None, 120, 160, 160 640         conv2_block3_concat[0][0]
# __________________________________________________________________________________________________
# conv2_block4_0_relu (Activation (None, 120, 160, 160 0           conv2_block4_0_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block4_1_conv (Conv2D)    (None, 120, 160, 128 20480       conv2_block4_0_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block4_1_bn (BatchNormali (None, 120, 160, 128 512         conv2_block4_1_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block4_1_relu (Activation (None, 120, 160, 128 0           conv2_block4_1_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block4_2_conv (Conv2D)    (None, 120, 160, 32) 36864       conv2_block4_1_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block4_concat (Concatenat (None, 120, 160, 192 0           conv2_block3_concat[0][0]
#                                                                  conv2_block4_2_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block5_0_bn (BatchNormali (None, 120, 160, 192 768         conv2_block4_concat[0][0]
# __________________________________________________________________________________________________
# conv2_block5_0_relu (Activation (None, 120, 160, 192 0           conv2_block5_0_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block5_1_conv (Conv2D)    (None, 120, 160, 128 24576       conv2_block5_0_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block5_1_bn (BatchNormali (None, 120, 160, 128 512         conv2_block5_1_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block5_1_relu (Activation (None, 120, 160, 128 0           conv2_block5_1_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block5_2_conv (Conv2D)    (None, 120, 160, 32) 36864       conv2_block5_1_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block5_concat (Concatenat (None, 120, 160, 224 0           conv2_block4_concat[0][0]
#                                                                  conv2_block5_2_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block6_0_bn (BatchNormali (None, 120, 160, 224 896         conv2_block5_concat[0][0]
# __________________________________________________________________________________________________
# conv2_block6_0_relu (Activation (None, 120, 160, 224 0           conv2_block6_0_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block6_1_conv (Conv2D)    (None, 120, 160, 128 28672       conv2_block6_0_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block6_1_bn (BatchNormali (None, 120, 160, 128 512         conv2_block6_1_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block6_1_relu (Activation (None, 120, 160, 128 0           conv2_block6_1_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block6_2_conv (Conv2D)    (None, 120, 160, 32) 36864       conv2_block6_1_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block6_concat (Concatenat (None, 120, 160, 256 0           conv2_block5_concat[0][0]
#                                                                  conv2_block6_2_conv[0][0]
# __________________________________________________________________________________________________
# pool2_bn (BatchNormalization)   (None, 120, 160, 256 1024        conv2_block6_concat[0][0]
# __________________________________________________________________________________________________
# pool2_relu (Activation)         (None, 120, 160, 256 0           pool2_bn[0][0]
# __________________________________________________________________________________________________
# pool2_conv (Conv2D)             (None, 120, 160, 128 32768       pool2_relu[0][0]
# __________________________________________________________________________________________________
# pool2_pool (AveragePooling2D)   (None, 60, 80, 128)  0           pool2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block1_0_bn (BatchNormali (None, 60, 80, 128)  512         pool2_pool[0][0]
# __________________________________________________________________________________________________
# conv3_block1_0_relu (Activation (None, 60, 80, 128)  0           conv3_block1_0_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block1_1_conv (Conv2D)    (None, 60, 80, 128)  16384       conv3_block1_0_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block1_1_bn (BatchNormali (None, 60, 80, 128)  512         conv3_block1_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block1_1_relu (Activation (None, 60, 80, 128)  0           conv3_block1_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block1_2_conv (Conv2D)    (None, 60, 80, 32)   36864       conv3_block1_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block1_concat (Concatenat (None, 60, 80, 160)  0           pool2_pool[0][0]
#                                                                  conv3_block1_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block2_0_bn (BatchNormali (None, 60, 80, 160)  640         conv3_block1_concat[0][0]
# __________________________________________________________________________________________________
# conv3_block2_0_relu (Activation (None, 60, 80, 160)  0           conv3_block2_0_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block2_1_conv (Conv2D)    (None, 60, 80, 128)  20480       conv3_block2_0_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block2_1_bn (BatchNormali (None, 60, 80, 128)  512         conv3_block2_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block2_1_relu (Activation (None, 60, 80, 128)  0           conv3_block2_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block2_2_conv (Conv2D)    (None, 60, 80, 32)   36864       conv3_block2_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block2_concat (Concatenat (None, 60, 80, 192)  0           conv3_block1_concat[0][0]
#                                                                  conv3_block2_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block3_0_bn (BatchNormali (None, 60, 80, 192)  768         conv3_block2_concat[0][0]
# __________________________________________________________________________________________________
# conv3_block3_0_relu (Activation (None, 60, 80, 192)  0           conv3_block3_0_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block3_1_conv (Conv2D)    (None, 60, 80, 128)  24576       conv3_block3_0_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block3_1_bn (BatchNormali (None, 60, 80, 128)  512         conv3_block3_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block3_1_relu (Activation (None, 60, 80, 128)  0           conv3_block3_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block3_2_conv (Conv2D)    (None, 60, 80, 32)   36864       conv3_block3_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block3_concat (Concatenat (None, 60, 80, 224)  0           conv3_block2_concat[0][0]
#                                                                  conv3_block3_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block4_0_bn (BatchNormali (None, 60, 80, 224)  896         conv3_block3_concat[0][0]
# __________________________________________________________________________________________________
# conv3_block4_0_relu (Activation (None, 60, 80, 224)  0           conv3_block4_0_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block4_1_conv (Conv2D)    (None, 60, 80, 128)  28672       conv3_block4_0_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block4_1_bn (BatchNormali (None, 60, 80, 128)  512         conv3_block4_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block4_1_relu (Activation (None, 60, 80, 128)  0           conv3_block4_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block4_2_conv (Conv2D)    (None, 60, 80, 32)   36864       conv3_block4_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block4_concat (Concatenat (None, 60, 80, 256)  0           conv3_block3_concat[0][0]
#                                                                  conv3_block4_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block5_0_bn (BatchNormali (None, 60, 80, 256)  1024        conv3_block4_concat[0][0]
# __________________________________________________________________________________________________
# conv3_block5_0_relu (Activation (None, 60, 80, 256)  0           conv3_block5_0_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block5_1_conv (Conv2D)    (None, 60, 80, 128)  32768       conv3_block5_0_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block5_1_bn (BatchNormali (None, 60, 80, 128)  512         conv3_block5_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block5_1_relu (Activation (None, 60, 80, 128)  0           conv3_block5_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block5_2_conv (Conv2D)    (None, 60, 80, 32)   36864       conv3_block5_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block5_concat (Concatenat (None, 60, 80, 288)  0           conv3_block4_concat[0][0]
#                                                                  conv3_block5_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block6_0_bn (BatchNormali (None, 60, 80, 288)  1152        conv3_block5_concat[0][0]
# __________________________________________________________________________________________________
# conv3_block6_0_relu (Activation (None, 60, 80, 288)  0           conv3_block6_0_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block6_1_conv (Conv2D)    (None, 60, 80, 128)  36864       conv3_block6_0_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block6_1_bn (BatchNormali (None, 60, 80, 128)  512         conv3_block6_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block6_1_relu (Activation (None, 60, 80, 128)  0           conv3_block6_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block6_2_conv (Conv2D)    (None, 60, 80, 32)   36864       conv3_block6_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block6_concat (Concatenat (None, 60, 80, 320)  0           conv3_block5_concat[0][0]
#                                                                  conv3_block6_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block7_0_bn (BatchNormali (None, 60, 80, 320)  1280        conv3_block6_concat[0][0]
# __________________________________________________________________________________________________
# conv3_block7_0_relu (Activation (None, 60, 80, 320)  0           conv3_block7_0_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block7_1_conv (Conv2D)    (None, 60, 80, 128)  40960       conv3_block7_0_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block7_1_bn (BatchNormali (None, 60, 80, 128)  512         conv3_block7_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block7_1_relu (Activation (None, 60, 80, 128)  0           conv3_block7_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block7_2_conv (Conv2D)    (None, 60, 80, 32)   36864       conv3_block7_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block7_concat (Concatenat (None, 60, 80, 352)  0           conv3_block6_concat[0][0]
#                                                                  conv3_block7_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block8_0_bn (BatchNormali (None, 60, 80, 352)  1408        conv3_block7_concat[0][0]
# __________________________________________________________________________________________________
# conv3_block8_0_relu (Activation (None, 60, 80, 352)  0           conv3_block8_0_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block8_1_conv (Conv2D)    (None, 60, 80, 128)  45056       conv3_block8_0_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block8_1_bn (BatchNormali (None, 60, 80, 128)  512         conv3_block8_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block8_1_relu (Activation (None, 60, 80, 128)  0           conv3_block8_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block8_2_conv (Conv2D)    (None, 60, 80, 32)   36864       conv3_block8_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block8_concat (Concatenat (None, 60, 80, 384)  0           conv3_block7_concat[0][0]
#                                                                  conv3_block8_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block9_0_bn (BatchNormali (None, 60, 80, 384)  1536        conv3_block8_concat[0][0]
# __________________________________________________________________________________________________
# conv3_block9_0_relu (Activation (None, 60, 80, 384)  0           conv3_block9_0_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block9_1_conv (Conv2D)    (None, 60, 80, 128)  49152       conv3_block9_0_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block9_1_bn (BatchNormali (None, 60, 80, 128)  512         conv3_block9_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block9_1_relu (Activation (None, 60, 80, 128)  0           conv3_block9_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block9_2_conv (Conv2D)    (None, 60, 80, 32)   36864       conv3_block9_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block9_concat (Concatenat (None, 60, 80, 416)  0           conv3_block8_concat[0][0]
#                                                                  conv3_block9_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block10_0_bn (BatchNormal (None, 60, 80, 416)  1664        conv3_block9_concat[0][0]
# __________________________________________________________________________________________________
# conv3_block10_0_relu (Activatio (None, 60, 80, 416)  0           conv3_block10_0_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block10_1_conv (Conv2D)   (None, 60, 80, 128)  53248       conv3_block10_0_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block10_1_bn (BatchNormal (None, 60, 80, 128)  512         conv3_block10_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block10_1_relu (Activatio (None, 60, 80, 128)  0           conv3_block10_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block10_2_conv (Conv2D)   (None, 60, 80, 32)   36864       conv3_block10_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block10_concat (Concatena (None, 60, 80, 448)  0           conv3_block9_concat[0][0]
#                                                                  conv3_block10_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block11_0_bn (BatchNormal (None, 60, 80, 448)  1792        conv3_block10_concat[0][0]
# __________________________________________________________________________________________________
# conv3_block11_0_relu (Activatio (None, 60, 80, 448)  0           conv3_block11_0_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block11_1_conv (Conv2D)   (None, 60, 80, 128)  57344       conv3_block11_0_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block11_1_bn (BatchNormal (None, 60, 80, 128)  512         conv3_block11_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block11_1_relu (Activatio (None, 60, 80, 128)  0           conv3_block11_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block11_2_conv (Conv2D)   (None, 60, 80, 32)   36864       conv3_block11_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block11_concat (Concatena (None, 60, 80, 480)  0           conv3_block10_concat[0][0]
#                                                                  conv3_block11_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block12_0_bn (BatchNormal (None, 60, 80, 480)  1920        conv3_block11_concat[0][0]
# __________________________________________________________________________________________________
# conv3_block12_0_relu (Activatio (None, 60, 80, 480)  0           conv3_block12_0_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block12_1_conv (Conv2D)   (None, 60, 80, 128)  61440       conv3_block12_0_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block12_1_bn (BatchNormal (None, 60, 80, 128)  512         conv3_block12_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block12_1_relu (Activatio (None, 60, 80, 128)  0           conv3_block12_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block12_2_conv (Conv2D)   (None, 60, 80, 32)   36864       conv3_block12_1_relu[0][0]
# ==================================================================================================
# Total params: 1,311,808
# Trainable params: 1,297,536
# Non-trainable params: 14,272
# __________________________________________________________________________________________________

# %%
'''
make stage 2 train data
'''
train_final_array_2 = make_data(train_file_list, model_2,src_2)

print ('train final array_2', train_final_array_2.shape)
np.save(src_save+'train_data_img_preprocess_DenseNet121_2_verification.npy',train_final_array_2)
print ('totally done, train_data_img_preprocess_denseNet121_2_verification.npy.npy')
# Out:
# floor= 340
# total size 2386 file_list 2386 final_list length NOT equal to file_list
# 0
# warning, something wrong
# 341
# (480, 640, 3)
# batch =  0 stage 1 completed shape= (7, 60, 80, 32)
# batch 0 time= 20.9452
# afterbatch 0 length= 1
# (480, 640, 3)
# batch =  1 stage 1 completed shape= (7, 60, 80, 32)
# batch 1 time= 21.918
# afterbatch 1 length= 2
# (480, 640, 3)
# batch =  2 stage 1 completed shape= (7, 60, 80, 32)
# batch 2 time= 22.9138
# afterbatch 2 length= 3
# (480, 640, 3)
# batch =  3 stage 1 completed shape= (7, 60, 80, 32)
# batch 3 time= 23.8874
# afterbatch 3 length= 4
# (480, 640, 3)
# batch =  4 stage 1 completed shape= (7, 60, 80, 32)
# batch 4 time= 24.8339
# afterbatch 4 length= 5
# (480, 640, 3)
# batch =  5 stage 1 completed shape= (7, 60, 80, 32)
# batch 5 time= 25.8109
# afterbatch 5 length= 6
# (480, 640, 3)
# batch =  6 stage 1 completed shape= (7, 60, 80, 32)
# batch 6 time= 26.7821
# afterbatch 6 length= 7
# (480, 640, 3)
# batch =  7 stage 1 completed shape= (7, 60, 80, 32)
# batch 7 time= 27.7835
# afterbatch 7 length= 8
# (480, 640, 3)
# batch =  8 stage 1 completed shape= (7, 60, 80, 32)
# batch 8 time= 28.775
# afterbatch 8 length= 9
# (480, 640, 3)
# batch =  9 stage 1 completed shape= (7, 60, 80, 32)
# batch 9 time= 29.7648
# afterbatch 9 length= 10
# (480, 640, 3)
# batch =  10 stage 1 completed shape= (7, 60, 80, 32)
# batch 10 time= 30.739
# afterbatch 10 length= 11
# (480, 640, 3)
# batch =  11 stage 1 completed shape= (7, 60, 80, 32)
# batch 11 time= 31.7273
# afterbatch 11 length= 12
# (480, 640, 3)
# batch =  12 stage 1 completed shape= (7, 60, 80, 32)
# batch 12 time= 32.7105
# afterbatch 12 length= 13
# (480, 640, 3)
# batch =  13 stage 1 completed shape= (7, 60, 80, 32)
# batch 13 time= 33.7002
# afterbatch 13 length= 14
# (480, 640, 3)
# batch =  14 stage 1 completed shape= (7, 60, 80, 32)
# batch 14 time= 34.6668
# afterbatch 14 length= 15
# (480, 640, 3)
# batch =  15 stage 1 completed shape= (7, 60, 80, 32)
# batch 15 time= 35.6308
# afterbatch 15 length= 16
# (480, 640, 3)
# batch =  16 stage 1 completed shape= (7, 60, 80, 32)
# batch 16 time= 36.635
# afterbatch 16 length= 17
# (480, 640, 3)
# batch =  17 stage 1 completed shape= (7, 60, 80, 32)
# batch 17 time= 37.5999
# afterbatch 17 length= 18
# (480, 640, 3)
# batch =  18 stage 1 completed shape= (7, 60, 80, 32)
# batch 18 time= 38.5667
# afterbatch 18 length= 19
# (480, 640, 3)
# batch =  19 stage 1 completed shape= (7, 60, 80, 32)
# batch 19 time= 39.5104
# afterbatch 19 length= 20
# (480, 640, 3)
# batch =  20 stage 1 completed shape= (7, 60, 80, 32)
# batch 20 time= 40.4614
# afterbatch 20 length= 21
# (480, 640, 3)
# batch =  21 stage 1 completed shape= (7, 60, 80, 32)
# batch 21 time= 41.4262
# afterbatch 21 length= 22
# (480, 640, 3)
# batch =  22 stage 1 completed shape= (7, 60, 80, 32)
# batch 22 time= 42.408
# afterbatch 22 length= 23
# (480, 640, 3)
# batch =  23 stage 1 completed shape= (7, 60, 80, 32)
# batch 23 time= 43.3879
# afterbatch 23 length= 24
# (480, 640, 3)
# batch =  24 stage 1 completed shape= (7, 60, 80, 32)
# batch 24 time= 44.3335
# afterbatch 24 length= 25
# (480, 640, 3)
# batch =  25 stage 1 completed shape= (7, 60, 80, 32)
# batch 25 time= 45.3289
# afterbatch 25 length= 26
# (480, 640, 3)
# batch =  26 stage 1 completed shape= (7, 60, 80, 32)
# batch 26 time= 46.3025
# afterbatch 26 length= 27
# (480, 640, 3)
# batch =  27 stage 1 completed shape= (7, 60, 80, 32)
# batch 27 time= 47.2572
# afterbatch 27 length= 28
# (480, 640, 3)
# batch =  28 stage 1 completed shape= (7, 60, 80, 32)
# batch 28 time= 48.2112
# afterbatch 28 length= 29
# (480, 640, 3)
# batch =  29 stage 1 completed shape= (7, 60, 80, 32)
# batch 29 time= 49.1837
# afterbatch 29 length= 30
# (480, 640, 3)
# batch =  30 stage 1 completed shape= (7, 60, 80, 32)
# batch 30 time= 50.1571
# afterbatch 30 length= 31
# (480, 640, 3)
# batch =  31 stage 1 completed shape= (7, 60, 80, 32)
# batch 31 time= 51.1022
# afterbatch 31 length= 32
# (480, 640, 3)
# batch =  32 stage 1 completed shape= (7, 60, 80, 32)
# batch 32 time= 52.0756
# afterbatch 32 length= 33
# (480, 640, 3)
# batch =  33 stage 1 completed shape= (7, 60, 80, 32)
# batch 33 time= 53.0476
# afterbatch 33 length= 34
# (480, 640, 3)
# batch =  34 stage 1 completed shape= (7, 60, 80, 32)
# batch 34 time= 54.0302
# afterbatch 34 length= 35
# (480, 640, 3)
# batch =  35 stage 1 completed shape= (7, 60, 80, 32)
# batch 35 time= 54.9955
# afterbatch 35 length= 36
# (480, 640, 3)
# batch =  36 stage 1 completed shape= (7, 60, 80, 32)
# batch 36 time= 55.9754
# afterbatch 36 length= 37
# (480, 640, 3)
# batch =  37 stage 1 completed shape= (7, 60, 80, 32)
# batch 37 time= 56.9415
# afterbatch 37 length= 38
# (480, 640, 3)
# batch =  38 stage 1 completed shape= (7, 60, 80, 32)
# batch 38 time= 57.9428
# afterbatch 38 length= 39
# (480, 640, 3)
# batch =  39 stage 1 completed shape= (7, 60, 80, 32)
# batch 39 time= 58.928
# afterbatch 39 length= 40
# (480, 640, 3)
# batch =  40 stage 1 completed shape= (7, 60, 80, 32)
# batch 40 time= 59.9138
# afterbatch 40 length= 41
# (480, 640, 3)
# batch =  41 stage 1 completed shape= (7, 60, 80, 32)
# batch 41 time= 60.8711
# afterbatch 41 length= 42
# (480, 640, 3)
# batch =  42 stage 1 completed shape= (7, 60, 80, 32)
# batch 42 time= 61.847
# afterbatch 42 length= 43
# (480, 640, 3)
# batch =  43 stage 1 completed shape= (7, 60, 80, 32)
# batch 43 time= 62.8425
# afterbatch 43 length= 44
# (480, 640, 3)
# batch =  44 stage 1 completed shape= (7, 60, 80, 32)
# batch 44 time= 63.807
# afterbatch 44 length= 45
# (480, 640, 3)
# batch =  45 stage 1 completed shape= (7, 60, 80, 32)
# batch 45 time= 64.7719
# afterbatch 45 length= 46
# (480, 640, 3)
# batch =  46 stage 1 completed shape= (7, 60, 80, 32)
# batch 46 time= 65.7504
# afterbatch 46 length= 47
# (480, 640, 3)
# batch =  47 stage 1 completed shape= (7, 60, 80, 32)
# batch 47 time= 66.7085
# afterbatch 47 length= 48
# (480, 640, 3)
# batch =  48 stage 1 completed shape= (7, 60, 80, 32)
# batch 48 time= 67.6859
# afterbatch 48 length= 49
# (480, 640, 3)
# batch =  49 stage 1 completed shape= (7, 60, 80, 32)
# batch 49 time= 68.6678
# afterbatch 49 length= 50
# (480, 640, 3)
# batch =  50 stage 1 completed shape= (7, 60, 80, 32)
# batch 50 time= 69.6232
# afterbatch 50 length= 51
# (480, 640, 3)
# batch =  51 stage 1 completed shape= (7, 60, 80, 32)
# batch 51 time= 70.5956
# afterbatch 51 length= 52
# (480, 640, 3)
# batch =  52 stage 1 completed shape= (7, 60, 80, 32)
# batch 52 time= 71.6047
# afterbatch 52 length= 53
# (480, 640, 3)
# batch =  53 stage 1 completed shape= (7, 60, 80, 32)
# batch 53 time= 72.5973
# afterbatch 53 length= 54
# (480, 640, 3)
# batch =  54 stage 1 completed shape= (7, 60, 80, 32)
# batch 54 time= 73.5669
# afterbatch 54 length= 55
# (480, 640, 3)
# batch =  55 stage 1 completed shape= (7, 60, 80, 32)
# batch 55 time= 74.5577
# afterbatch 55 length= 56
# (480, 640, 3)
# batch =  56 stage 1 completed shape= (7, 60, 80, 32)
# batch 56 time= 75.5442
# afterbatch 56 length= 57
# (480, 640, 3)
# batch =  57 stage 1 completed shape= (7, 60, 80, 32)
# batch 57 time= 76.5323
# afterbatch 57 length= 58
# (480, 640, 3)
# batch =  58 stage 1 completed shape= (7, 60, 80, 32)
# batch 58 time= 77.5011
# afterbatch 58 length= 59
# (480, 640, 3)
# batch =  59 stage 1 completed shape= (7, 60, 80, 32)
# batch 59 time= 78.4532
# afterbatch 59 length= 60
# (480, 640, 3)
# batch =  60 stage 1 completed shape= (7, 60, 80, 32)
# batch 60 time= 79.4621
# afterbatch 60 length= 61
# (480, 640, 3)
# batch =  61 stage 1 completed shape= (7, 60, 80, 32)
# batch 61 time= 80.4454
# afterbatch 61 length= 62
# (480, 640, 3)
# batch =  62 stage 1 completed shape= (7, 60, 80, 32)
# batch 62 time= 81.4393
# afterbatch 62 length= 63
# (480, 640, 3)
# batch =  63 stage 1 completed shape= (7, 60, 80, 32)
# batch 63 time= 82.4273
# afterbatch 63 length= 64
# (480, 640, 3)
# batch =  64 stage 1 completed shape= (7, 60, 80, 32)
# batch 64 time= 83.3689
# afterbatch 64 length= 65
# (480, 640, 3)
# batch =  65 stage 1 completed shape= (7, 60, 80, 32)
# batch 65 time= 84.3538
# afterbatch 65 length= 66
# (480, 640, 3)
# batch =  66 stage 1 completed shape= (7, 60, 80, 32)
# batch 66 time= 85.3382
# afterbatch 66 length= 67
# (480, 640, 3)
# batch =  67 stage 1 completed shape= (7, 60, 80, 32)
# batch 67 time= 86.3097
# afterbatch 67 length= 68
# (480, 640, 3)
# batch =  68 stage 1 completed shape= (7, 60, 80, 32)
# batch 68 time= 87.2881
# afterbatch 68 length= 69
# (480, 640, 3)
# batch =  69 stage 1 completed shape= (7, 60, 80, 32)
# batch 69 time= 88.238
# afterbatch 69 length= 70
# (480, 640, 3)
# batch =  70 stage 1 completed shape= (7, 60, 80, 32)
# batch 70 time= 89.2243
# afterbatch 70 length= 71
# (480, 640, 3)
# batch =  71 stage 1 completed shape= (7, 60, 80, 32)
# batch 71 time= 90.2033
# afterbatch 71 length= 72
# (480, 640, 3)
# batch =  72 stage 1 completed shape= (7, 60, 80, 32)
# batch 72 time= 91.1709
# afterbatch 72 length= 73
# (480, 640, 3)
# batch =  73 stage 1 completed shape= (7, 60, 80, 32)
# batch 73 time= 92.1715
# afterbatch 73 length= 74
# (480, 640, 3)
# batch =  74 stage 1 completed shape= (7, 60, 80, 32)
# batch 74 time= 93.1525
# afterbatch 74 length= 75
# (480, 640, 3)
# batch =  75 stage 1 completed shape= (7, 60, 80, 32)
# batch 75 time= 94.1406
# afterbatch 75 length= 76
# (480, 640, 3)
# batch =  76 stage 1 completed shape= (7, 60, 80, 32)
# batch 76 time= 95.1114
# afterbatch 76 length= 77
# (480, 640, 3)
# batch =  77 stage 1 completed shape= (7, 60, 80, 32)
# batch 77 time= 96.0706
# afterbatch 77 length= 78
# (480, 640, 3)
# batch =  78 stage 1 completed shape= (7, 60, 80, 32)
# batch 78 time= 97.0405
# afterbatch 78 length= 79
# (480, 640, 3)
# batch =  79 stage 1 completed shape= (7, 60, 80, 32)
# batch 79 time= 98.0303
# afterbatch 79 length= 80
# (480, 640, 3)
# batch =  80 stage 1 completed shape= (7, 60, 80, 32)
# batch 80 time= 98.9747
# afterbatch 80 length= 81
# (480, 640, 3)
# batch =  81 stage 1 completed shape= (7, 60, 80, 32)
# batch 81 time= 99.959
# afterbatch 81 length= 82
# (480, 640, 3)
# batch =  82 stage 1 completed shape= (7, 60, 80, 32)
# batch 82 time= 100.9412
# afterbatch 82 length= 83
# (480, 640, 3)
# batch =  83 stage 1 completed shape= (7, 60, 80, 32)
# batch 83 time= 101.8965
# afterbatch 83 length= 84
# (480, 640, 3)
# batch =  84 stage 1 completed shape= (7, 60, 80, 32)
# batch 84 time= 102.8702
# afterbatch 84 length= 85
# (480, 640, 3)
# batch =  85 stage 1 completed shape= (7, 60, 80, 32)
# batch 85 time= 103.8446
# afterbatch 85 length= 86
# (480, 640, 3)
# batch =  86 stage 1 completed shape= (7, 60, 80, 32)
# batch 86 time= 104.8078
# afterbatch 86 length= 87
# (480, 640, 3)
# batch =  87 stage 1 completed shape= (7, 60, 80, 32)
# batch 87 time= 105.7973
# afterbatch 87 length= 88
# (480, 640, 3)
# batch =  88 stage 1 completed shape= (7, 60, 80, 32)
# batch 88 time= 106.7947
# afterbatch 88 length= 89
# (480, 640, 3)
# batch =  89 stage 1 completed shape= (7, 60, 80, 32)
# batch 89 time= 107.7929
# afterbatch 89 length= 90
# (480, 640, 3)
# batch =  90 stage 1 completed shape= (7, 60, 80, 32)
# batch 90 time= 108.774
# afterbatch 90 length= 91
# (480, 640, 3)
# batch =  91 stage 1 completed shape= (7, 60, 80, 32)
# batch 91 time= 109.7477
# afterbatch 91 length= 92
# (480, 640, 3)
# batch =  92 stage 1 completed shape= (7, 60, 80, 32)
# batch 92 time= 110.7245
# afterbatch 92 length= 93
# (480, 640, 3)
# batch =  93 stage 1 completed shape= (7, 60, 80, 32)
# batch 93 time= 111.7215
# afterbatch 93 length= 94
# (480, 640, 3)
# batch =  94 stage 1 completed shape= (7, 60, 80, 32)
# batch 94 time= 112.7133
# afterbatch 94 length= 95
# (480, 640, 3)
# batch =  95 stage 1 completed shape= (7, 60, 80, 32)
# batch 95 time= 113.7024
# afterbatch 95 length= 96
# (480, 640, 3)
# batch =  96 stage 1 completed shape= (7, 60, 80, 32)
# batch 96 time= 114.688
# afterbatch 96 length= 97
# (480, 640, 3)
# batch =  97 stage 1 completed shape= (7, 60, 80, 32)
# batch 97 time= 115.6414
# afterbatch 97 length= 98
# (480, 640, 3)
# batch =  98 stage 1 completed shape= (7, 60, 80, 32)
# batch 98 time= 116.6402
# afterbatch 98 length= 99
# (480, 640, 3)
# batch =  99 stage 1 completed shape= (7, 60, 80, 32)
# batch 99 time= 117.6335
# afterbatch 99 length= 100
# (480, 640, 3)
# batch =  100 stage 1 completed shape= (7, 60, 80, 32)
# batch 100 time= 118.6152
# afterbatch 100 length= 101
# (480, 640, 3)
# batch =  101 stage 1 completed shape= (7, 60, 80, 32)
# batch 101 time= 119.6023
# afterbatch 101 length= 102
# (480, 640, 3)
# batch =  102 stage 1 completed shape= (7, 60, 80, 32)
# batch 102 time= 120.5712
# afterbatch 102 length= 103
# (480, 640, 3)
# batch =  103 stage 1 completed shape= (7, 60, 80, 32)
# batch 103 time= 121.5649
# afterbatch 103 length= 104
# (480, 640, 3)
# batch =  104 stage 1 completed shape= (7, 60, 80, 32)
# batch 104 time= 122.5337
# afterbatch 104 length= 105
# (480, 640, 3)
# batch =  105 stage 1 completed shape= (7, 60, 80, 32)
# batch 105 time= 123.4971
# afterbatch 105 length= 106
# (480, 640, 3)
# batch =  106 stage 1 completed shape= (7, 60, 80, 32)
# batch 106 time= 124.467
# afterbatch 106 length= 107
# (480, 640, 3)
# batch =  107 stage 1 completed shape= (7, 60, 80, 32)
# batch 107 time= 125.4519
# afterbatch 107 length= 108
# (480, 640, 3)
# batch =  108 stage 1 completed shape= (7, 60, 80, 32)
# batch 108 time= 126.4321
# afterbatch 108 length= 109
# (480, 640, 3)
# batch =  109 stage 1 completed shape= (7, 60, 80, 32)
# batch 109 time= 127.3979
# afterbatch 109 length= 110
# (480, 640, 3)
# batch =  110 stage 1 completed shape= (7, 60, 80, 32)
# batch 110 time= 128.3761
# afterbatch 110 length= 111
# (480, 640, 3)
# batch =  111 stage 1 completed shape= (7, 60, 80, 32)
# batch 111 time= 129.3548
# afterbatch 111 length= 112
# (480, 640, 3)
# batch =  112 stage 1 completed shape= (7, 60, 80, 32)
# batch 112 time= 130.339
# afterbatch 112 length= 113
# (480, 640, 3)
# batch =  113 stage 1 completed shape= (7, 60, 80, 32)
# batch 113 time= 131.3293
# afterbatch 113 length= 114
# (480, 640, 3)
# batch =  114 stage 1 completed shape= (7, 60, 80, 32)
# batch 114 time= 132.2753
# afterbatch 114 length= 115
# (480, 640, 3)
# batch =  115 stage 1 completed shape= (7, 60, 80, 32)
# batch 115 time= 133.2097
# afterbatch 115 length= 116
# (480, 640, 3)
# batch =  116 stage 1 completed shape= (7, 60, 80, 32)
# batch 116 time= 134.1725
# afterbatch 116 length= 117
# (480, 640, 3)
# batch =  117 stage 1 completed shape= (7, 60, 80, 32)
# batch 117 time= 135.1188
# afterbatch 117 length= 118
# (480, 640, 3)
# batch =  118 stage 1 completed shape= (7, 60, 80, 32)
# batch 118 time= 136.086
# afterbatch 118 length= 119
# (480, 640, 3)
# batch =  119 stage 1 completed shape= (7, 60, 80, 32)
# batch 119 time= 137.0843
# afterbatch 119 length= 120
# (480, 640, 3)
# batch =  120 stage 1 completed shape= (7, 60, 80, 32)
# batch 120 time= 138.0621
# afterbatch 120 length= 121
# (480, 640, 3)
# batch =  121 stage 1 completed shape= (7, 60, 80, 32)
# batch 121 time= 139.0454
# afterbatch 121 length= 122
# (480, 640, 3)
# batch =  122 stage 1 completed shape= (7, 60, 80, 32)
# batch 122 time= 140.0134
# afterbatch 122 length= 123
# (480, 640, 3)
# batch =  123 stage 1 completed shape= (7, 60, 80, 32)
# batch 123 time= 140.9941
# afterbatch 123 length= 124
# (480, 640, 3)
# batch =  124 stage 1 completed shape= (7, 60, 80, 32)
# batch 124 time= 141.9534
# afterbatch 124 length= 125
# (480, 640, 3)
# batch =  125 stage 1 completed shape= (7, 60, 80, 32)
# batch 125 time= 142.9328
# afterbatch 125 length= 126
# (480, 640, 3)
# batch =  126 stage 1 completed shape= (7, 60, 80, 32)
# batch 126 time= 143.8922
# afterbatch 126 length= 127
# (480, 640, 3)
# batch =  127 stage 1 completed shape= (7, 60, 80, 32)
# batch 127 time= 144.8622
# afterbatch 127 length= 128
# (480, 640, 3)
# batch =  128 stage 1 completed shape= (7, 60, 80, 32)
# batch 128 time= 145.8597
# afterbatch 128 length= 129
# (480, 640, 3)
# batch =  129 stage 1 completed shape= (7, 60, 80, 32)
# batch 129 time= 146.8275
# afterbatch 129 length= 130
# (480, 640, 3)
# batch =  130 stage 1 completed shape= (7, 60, 80, 32)
# batch 130 time= 147.8183
# afterbatch 130 length= 131
# (480, 640, 3)
# batch =  131 stage 1 completed shape= (7, 60, 80, 32)
# batch 131 time= 148.7924
# afterbatch 131 length= 132
# (480, 640, 3)
# batch =  132 stage 1 completed shape= (7, 60, 80, 32)
# batch 132 time= 149.7737
# afterbatch 132 length= 133
# (480, 640, 3)
# batch =  133 stage 1 completed shape= (7, 60, 80, 32)
# batch 133 time= 150.7835
# afterbatch 133 length= 134
# (480, 640, 3)
# batch =  134 stage 1 completed shape= (7, 60, 80, 32)
# batch 134 time= 151.783
# afterbatch 134 length= 135
# (480, 640, 3)
# batch =  135 stage 1 completed shape= (7, 60, 80, 32)
# batch 135 time= 152.8026
# afterbatch 135 length= 136
# (480, 640, 3)
# batch =  136 stage 1 completed shape= (7, 60, 80, 32)
# batch 136 time= 153.8058
# afterbatch 136 length= 137
# (480, 640, 3)
# batch =  137 stage 1 completed shape= (7, 60, 80, 32)
# batch 137 time= 154.8127
# afterbatch 137 length= 138
# (480, 640, 3)
# batch =  138 stage 1 completed shape= (7, 60, 80, 32)
# batch 138 time= 155.7933
# afterbatch 138 length= 139
# (480, 640, 3)
# batch =  139 stage 1 completed shape= (7, 60, 80, 32)
# batch 139 time= 156.7591
# afterbatch 139 length= 140
# (480, 640, 3)
# batch =  140 stage 1 completed shape= (7, 60, 80, 32)
# batch 140 time= 157.7445
# afterbatch 140 length= 141
# (480, 640, 3)
# batch =  141 stage 1 completed shape= (7, 60, 80, 32)
# batch 141 time= 158.7152
# afterbatch 141 length= 142
# (480, 640, 3)
# batch =  142 stage 1 completed shape= (7, 60, 80, 32)
# batch 142 time= 159.6803
# afterbatch 142 length= 143
# (480, 640, 3)
# batch =  143 stage 1 completed shape= (7, 60, 80, 32)
# batch 143 time= 160.6401
# afterbatch 143 length= 144
# (480, 640, 3)
# batch =  144 stage 1 completed shape= (7, 60, 80, 32)
# batch 144 time= 161.6471
# afterbatch 144 length= 145
# (480, 640, 3)
# batch =  145 stage 1 completed shape= (7, 60, 80, 32)
# batch 145 time= 162.6207
# afterbatch 145 length= 146
# (480, 640, 3)
# batch =  146 stage 1 completed shape= (7, 60, 80, 32)
# batch 146 time= 163.589
# afterbatch 146 length= 147
# (480, 640, 3)
# batch =  147 stage 1 completed shape= (7, 60, 80, 32)
# batch 147 time= 164.5861
# afterbatch 147 length= 148
# (480, 640, 3)
# batch =  148 stage 1 completed shape= (7, 60, 80, 32)
# batch 148 time= 165.5714
# afterbatch 148 length= 149
# (480, 640, 3)
# batch =  149 stage 1 completed shape= (7, 60, 80, 32)
# batch 149 time= 166.5536
# afterbatch 149 length= 150
# (480, 640, 3)
# batch =  150 stage 1 completed shape= (7, 60, 80, 32)
# batch 150 time= 167.5309
# afterbatch 150 length= 151
# (480, 640, 3)
# batch =  151 stage 1 completed shape= (7, 60, 80, 32)
# batch 151 time= 168.5075
# afterbatch 151 length= 152
# (480, 640, 3)
# batch =  152 stage 1 completed shape= (7, 60, 80, 32)
# batch 152 time= 169.4682
# afterbatch 152 length= 153
# (480, 640, 3)
# batch =  153 stage 1 completed shape= (7, 60, 80, 32)
# batch 153 time= 170.4531
# afterbatch 153 length= 154
# (480, 640, 3)
# batch =  154 stage 1 completed shape= (7, 60, 80, 32)
# batch 154 time= 171.4378
# afterbatch 154 length= 155
# (480, 640, 3)
# batch =  155 stage 1 completed shape= (7, 60, 80, 32)
# batch 155 time= 172.3607
# afterbatch 155 length= 156
# (480, 640, 3)
# batch =  156 stage 1 completed shape= (7, 60, 80, 32)
# batch 156 time= 173.3398
# afterbatch 156 length= 157
# (480, 640, 3)
# batch =  157 stage 1 completed shape= (7, 60, 80, 32)
# batch 157 time= 174.2807
# afterbatch 157 length= 158
# (480, 640, 3)
# batch =  158 stage 1 completed shape= (7, 60, 80, 32)
# batch 158 time= 175.2577
# afterbatch 158 length= 159
# (480, 640, 3)
# batch =  159 stage 1 completed shape= (7, 60, 80, 32)
# batch 159 time= 176.2693
# afterbatch 159 length= 160
# (480, 640, 3)
# batch =  160 stage 1 completed shape= (7, 60, 80, 32)
# batch 160 time= 177.23
# afterbatch 160 length= 161
# (480, 640, 3)
# batch =  161 stage 1 completed shape= (7, 60, 80, 32)
# batch 161 time= 178.1714
# afterbatch 161 length= 162
# (480, 640, 3)
# batch =  162 stage 1 completed shape= (7, 60, 80, 32)
# batch 162 time= 179.1518
# afterbatch 162 length= 163
# (480, 640, 3)
# batch =  163 stage 1 completed shape= (7, 60, 80, 32)
# batch 163 time= 180.1493
# afterbatch 163 length= 164
# (480, 640, 3)
# batch =  164 stage 1 completed shape= (7, 60, 80, 32)
# batch 164 time= 181.1331
# afterbatch 164 length= 165
# (480, 640, 3)
# batch =  165 stage 1 completed shape= (7, 60, 80, 32)
# batch 165 time= 182.0909
# afterbatch 165 length= 166
# (480, 640, 3)
# batch =  166 stage 1 completed shape= (7, 60, 80, 32)
# batch 166 time= 183.0671
# afterbatch 166 length= 167
# (480, 640, 3)
# batch =  167 stage 1 completed shape= (7, 60, 80, 32)
# batch 167 time= 184.0352
# afterbatch 167 length= 168
# (480, 640, 3)
# batch =  168 stage 1 completed shape= (7, 60, 80, 32)
# batch 168 time= 185.0226
# afterbatch 168 length= 169
# (480, 640, 3)
# batch =  169 stage 1 completed shape= (7, 60, 80, 32)
# batch 169 time= 185.9933
# afterbatch 169 length= 170
# (480, 640, 3)
# batch =  170 stage 1 completed shape= (7, 60, 80, 32)
# batch 170 time= 186.9747
# afterbatch 170 length= 171
# (480, 640, 3)
# batch =  171 stage 1 completed shape= (7, 60, 80, 32)
# batch 171 time= 187.9986
# afterbatch 171 length= 172
# (480, 640, 3)
# batch =  172 stage 1 completed shape= (7, 60, 80, 32)
# batch 172 time= 188.9642
# afterbatch 172 length= 173
# (480, 640, 3)
# batch =  173 stage 1 completed shape= (7, 60, 80, 32)
# batch 173 time= 189.9105
# afterbatch 173 length= 174
# (480, 640, 3)
# batch =  174 stage 1 completed shape= (7, 60, 80, 32)
# batch 174 time= 190.8892
# afterbatch 174 length= 175
# (480, 640, 3)
# batch =  175 stage 1 completed shape= (7, 60, 80, 32)
# batch 175 time= 191.8721
# afterbatch 175 length= 176
# (480, 640, 3)
# batch =  176 stage 1 completed shape= (7, 60, 80, 32)
# batch 176 time= 192.8523
# afterbatch 176 length= 177
# (480, 640, 3)
# batch =  177 stage 1 completed shape= (7, 60, 80, 32)
# batch 177 time= 193.8563
# afterbatch 177 length= 178
# (480, 640, 3)
# batch =  178 stage 1 completed shape= (7, 60, 80, 32)
# batch 178 time= 194.8176
# afterbatch 178 length= 179
# (480, 640, 3)
# batch =  179 stage 1 completed shape= (7, 60, 80, 32)
# batch 179 time= 195.7785
# afterbatch 179 length= 180
# (480, 640, 3)
# batch =  180 stage 1 completed shape= (7, 60, 80, 32)
# batch 180 time= 196.7706
# afterbatch 180 length= 181
# (480, 640, 3)
# batch =  181 stage 1 completed shape= (7, 60, 80, 32)
# batch 181 time= 197.7692
# afterbatch 181 length= 182
# (480, 640, 3)
# batch =  182 stage 1 completed shape= (7, 60, 80, 32)
# batch 182 time= 198.741
# afterbatch 182 length= 183
# (480, 640, 3)
# batch =  183 stage 1 completed shape= (7, 60, 80, 32)
# batch 183 time= 199.7228
# afterbatch 183 length= 184
# (480, 640, 3)
# batch =  184 stage 1 completed shape= (7, 60, 80, 32)
# batch 184 time= 200.6893
# afterbatch 184 length= 185
# (480, 640, 3)
# batch =  185 stage 1 completed shape= (7, 60, 80, 32)
# batch 185 time= 201.6641
# afterbatch 185 length= 186
# (480, 640, 3)
# batch =  186 stage 1 completed shape= (7, 60, 80, 32)
# batch 186 time= 202.6566
# afterbatch 186 length= 187
# (480, 640, 3)
# batch =  187 stage 1 completed shape= (7, 60, 80, 32)
# batch 187 time= 203.6157
# afterbatch 187 length= 188
# (480, 640, 3)
# batch =  188 stage 1 completed shape= (7, 60, 80, 32)
# batch 188 time= 204.5726
# afterbatch 188 length= 189
# (480, 640, 3)
# batch =  189 stage 1 completed shape= (7, 60, 80, 32)
# batch 189 time= 205.5213
# afterbatch 189 length= 190
# (480, 640, 3)
# batch =  190 stage 1 completed shape= (7, 60, 80, 32)
# batch 190 time= 206.4919
# afterbatch 190 length= 191
# (480, 640, 3)
# batch =  191 stage 1 completed shape= (7, 60, 80, 32)
# batch 191 time= 207.4736
# afterbatch 191 length= 192
# (480, 640, 3)
# batch =  192 stage 1 completed shape= (7, 60, 80, 32)
# batch 192 time= 208.4336
# afterbatch 192 length= 193
# (480, 640, 3)
# batch =  193 stage 1 completed shape= (7, 60, 80, 32)
# batch 193 time= 209.3777
# afterbatch 193 length= 194
# (480, 640, 3)
# batch =  194 stage 1 completed shape= (7, 60, 80, 32)
# batch 194 time= 210.337
# afterbatch 194 length= 195
# (480, 640, 3)
# batch =  195 stage 1 completed shape= (7, 60, 80, 32)
# batch 195 time= 211.3191
# afterbatch 195 length= 196
# (480, 640, 3)
# batch =  196 stage 1 completed shape= (7, 60, 80, 32)
# batch 196 time= 212.2876
# afterbatch 196 length= 197
# (480, 640, 3)
# batch =  197 stage 1 completed shape= (7, 60, 80, 32)
# batch 197 time= 213.2459
# afterbatch 197 length= 198
# (480, 640, 3)
# batch =  198 stage 1 completed shape= (7, 60, 80, 32)
# batch 198 time= 214.2423
# afterbatch 198 length= 199
# (480, 640, 3)
# batch =  199 stage 1 completed shape= (7, 60, 80, 32)
# batch 199 time= 215.2168
# afterbatch 199 length= 200
# (480, 640, 3)
# batch =  200 stage 1 completed shape= (7, 60, 80, 32)
# batch 200 time= 216.1906
# afterbatch 200 length= 201
# (480, 640, 3)
# batch =  201 stage 1 completed shape= (7, 60, 80, 32)
# batch 201 time= 217.1711
# afterbatch 201 length= 202
# (480, 640, 3)
# batch =  202 stage 1 completed shape= (7, 60, 80, 32)
# batch 202 time= 218.1359
# afterbatch 202 length= 203
# (480, 640, 3)
# batch =  203 stage 1 completed shape= (7, 60, 80, 32)
# batch 203 time= 219.1206
# afterbatch 203 length= 204
# (480, 640, 3)
# batch =  204 stage 1 completed shape= (7, 60, 80, 32)
# batch 204 time= 220.0855
# afterbatch 204 length= 205
# (480, 640, 3)
# batch =  205 stage 1 completed shape= (7, 60, 80, 32)
# batch 205 time= 221.0708
# afterbatch 205 length= 206
# (480, 640, 3)
# batch =  206 stage 1 completed shape= (7, 60, 80, 32)
# batch 206 time= 222.0485
# afterbatch 206 length= 207
# (480, 640, 3)
# batch =  207 stage 1 completed shape= (7, 60, 80, 32)
# batch 207 time= 223.0162
# afterbatch 207 length= 208
# (480, 640, 3)
# batch =  208 stage 1 completed shape= (7, 60, 80, 32)
# batch 208 time= 223.9858
# afterbatch 208 length= 209
# (480, 640, 3)
# batch =  209 stage 1 completed shape= (7, 60, 80, 32)
# batch 209 time= 224.9769
# afterbatch 209 length= 210
# (480, 640, 3)
# batch =  210 stage 1 completed shape= (7, 60, 80, 32)
# batch 210 time= 225.9568
# afterbatch 210 length= 211
# (480, 640, 3)
# batch =  211 stage 1 completed shape= (7, 60, 80, 32)
# batch 211 time= 226.9371
# afterbatch 211 length= 212
# (480, 640, 3)
# batch =  212 stage 1 completed shape= (7, 60, 80, 32)
# batch 212 time= 227.8963
# afterbatch 212 length= 213
# (480, 640, 3)
# batch =  213 stage 1 completed shape= (7, 60, 80, 32)
# batch 213 time= 228.8714
# afterbatch 213 length= 214
# (480, 640, 3)
# batch =  214 stage 1 completed shape= (7, 60, 80, 32)
# batch 214 time= 229.8482
# afterbatch 214 length= 215
# (480, 640, 3)
# batch =  215 stage 1 completed shape= (7, 60, 80, 32)
# batch 215 time= 230.8244
# afterbatch 215 length= 216
# (480, 640, 3)
# batch =  216 stage 1 completed shape= (7, 60, 80, 32)
# batch 216 time= 231.7901
# afterbatch 216 length= 217
# (480, 640, 3)
# batch =  217 stage 1 completed shape= (7, 60, 80, 32)
# batch 217 time= 232.7805
# afterbatch 217 length= 218
# (480, 640, 3)
# batch =  218 stage 1 completed shape= (7, 60, 80, 32)
# batch 218 time= 233.777
# afterbatch 218 length= 219
# (480, 640, 3)
# batch =  219 stage 1 completed shape= (7, 60, 80, 32)
# batch 219 time= 234.7503
# afterbatch 219 length= 220
# (480, 640, 3)
# batch =  220 stage 1 completed shape= (7, 60, 80, 32)
# batch 220 time= 235.7181
# afterbatch 220 length= 221
# (480, 640, 3)
# batch =  221 stage 1 completed shape= (7, 60, 80, 32)
# batch 221 time= 236.6812
# afterbatch 221 length= 222
# (480, 640, 3)
# batch =  222 stage 1 completed shape= (7, 60, 80, 32)
# batch 222 time= 237.6789
# afterbatch 222 length= 223
# (480, 640, 3)
# batch =  223 stage 1 completed shape= (7, 60, 80, 32)
# batch 223 time= 238.6201
# afterbatch 223 length= 224
# (480, 640, 3)
# batch =  224 stage 1 completed shape= (7, 60, 80, 32)
# batch 224 time= 239.5937
# afterbatch 224 length= 225
# (480, 640, 3)
# batch =  225 stage 1 completed shape= (7, 60, 80, 32)
# batch 225 time= 240.5504
# afterbatch 225 length= 226
# (480, 640, 3)
# batch =  226 stage 1 completed shape= (7, 60, 80, 32)
# batch 226 time= 241.5439
# afterbatch 226 length= 227
# (480, 640, 3)
# batch =  227 stage 1 completed shape= (7, 60, 80, 32)
# batch 227 time= 242.5324
# afterbatch 227 length= 228
# (480, 640, 3)
# batch =  228 stage 1 completed shape= (7, 60, 80, 32)
# batch 228 time= 243.5182
# afterbatch 228 length= 229
# (480, 640, 3)
# batch =  229 stage 1 completed shape= (7, 60, 80, 32)
# batch 229 time= 244.4882
# afterbatch 229 length= 230
# (480, 640, 3)
# batch =  230 stage 1 completed shape= (7, 60, 80, 32)
# batch 230 time= 245.4583
# afterbatch 230 length= 231
# (480, 640, 3)
# batch =  231 stage 1 completed shape= (7, 60, 80, 32)
# batch 231 time= 246.4061
# afterbatch 231 length= 232
# (480, 640, 3)
# batch =  232 stage 1 completed shape= (7, 60, 80, 32)
# batch 232 time= 247.3776
# afterbatch 232 length= 233
# (480, 640, 3)
# batch =  233 stage 1 completed shape= (7, 60, 80, 32)
# batch 233 time= 248.3285
# afterbatch 233 length= 234
# (480, 640, 3)
# batch =  234 stage 1 completed shape= (7, 60, 80, 32)
# batch 234 time= 249.3052
# afterbatch 234 length= 235
# (480, 640, 3)
# batch =  235 stage 1 completed shape= (7, 60, 80, 32)
# batch 235 time= 250.2589
# afterbatch 235 length= 236
# (480, 640, 3)
# batch =  236 stage 1 completed shape= (7, 60, 80, 32)
# batch 236 time= 251.2266
# afterbatch 236 length= 237
# (480, 640, 3)
# batch =  237 stage 1 completed shape= (7, 60, 80, 32)
# batch 237 time= 252.1814
# afterbatch 237 length= 238
# (480, 640, 3)
# batch =  238 stage 1 completed shape= (7, 60, 80, 32)
# batch 238 time= 253.1592
# afterbatch 238 length= 239
# (480, 640, 3)
# batch =  239 stage 1 completed shape= (7, 60, 80, 32)
# batch 239 time= 254.147
# afterbatch 239 length= 240
# (480, 640, 3)
# batch =  240 stage 1 completed shape= (7, 60, 80, 32)
# batch 240 time= 255.1145
# afterbatch 240 length= 241
# (480, 640, 3)
# batch =  241 stage 1 completed shape= (7, 60, 80, 32)
# batch 241 time= 256.0507
# afterbatch 241 length= 242
# (480, 640, 3)
# batch =  242 stage 1 completed shape= (7, 60, 80, 32)
# batch 242 time= 257.0145
# afterbatch 242 length= 243
# (480, 640, 3)
# batch =  243 stage 1 completed shape= (7, 60, 80, 32)
# batch 243 time= 257.9943
# afterbatch 243 length= 244
# (480, 640, 3)
# batch =  244 stage 1 completed shape= (7, 60, 80, 32)
# batch 244 time= 258.9618
# afterbatch 244 length= 245
# (480, 640, 3)
# batch =  245 stage 1 completed shape= (7, 60, 80, 32)
# batch 245 time= 259.9208
# afterbatch 245 length= 246
# (480, 640, 3)
# batch =  246 stage 1 completed shape= (7, 60, 80, 32)
# batch 246 time= 260.8725
# afterbatch 246 length= 247
# (480, 640, 3)
# batch =  247 stage 1 completed shape= (7, 60, 80, 32)
# batch 247 time= 261.8395
# afterbatch 247 length= 248
# (480, 640, 3)
# batch =  248 stage 1 completed shape= (7, 60, 80, 32)
# batch 248 time= 262.8155
# afterbatch 248 length= 249
# (480, 640, 3)
# batch =  249 stage 1 completed shape= (7, 60, 80, 32)
# batch 249 time= 263.7892
# afterbatch 249 length= 250
# (480, 640, 3)
# batch =  250 stage 1 completed shape= (7, 60, 80, 32)
# batch 250 time= 264.7583
# afterbatch 250 length= 251
# (480, 640, 3)
# batch =  251 stage 1 completed shape= (7, 60, 80, 32)
# batch 251 time= 265.7255
# afterbatch 251 length= 252
# (480, 640, 3)
# batch =  252 stage 1 completed shape= (7, 60, 80, 32)
# batch 252 time= 266.7014
# afterbatch 252 length= 253
# (480, 640, 3)
# batch =  253 stage 1 completed shape= (7, 60, 80, 32)
# batch 253 time= 267.6858
# afterbatch 253 length= 254
# (480, 640, 3)
# batch =  254 stage 1 completed shape= (7, 60, 80, 32)
# batch 254 time= 268.6601
# afterbatch 254 length= 255
# (480, 640, 3)
# batch =  255 stage 1 completed shape= (7, 60, 80, 32)
# batch 255 time= 269.6285
# afterbatch 255 length= 256
# (480, 640, 3)
# batch =  256 stage 1 completed shape= (7, 60, 80, 32)
# batch 256 time= 270.6134
# afterbatch 256 length= 257
# (480, 640, 3)
# batch =  257 stage 1 completed shape= (7, 60, 80, 32)
# batch 257 time= 271.5715
# afterbatch 257 length= 258
# (480, 640, 3)
# batch =  258 stage 1 completed shape= (7, 60, 80, 32)
# batch 258 time= 272.5541
# afterbatch 258 length= 259
# (480, 640, 3)
# batch =  259 stage 1 completed shape= (7, 60, 80, 32)
# batch 259 time= 273.501
# afterbatch 259 length= 260
# (480, 640, 3)
# batch =  260 stage 1 completed shape= (7, 60, 80, 32)
# batch 260 time= 274.4686
# afterbatch 260 length= 261
# (480, 640, 3)
# batch =  261 stage 1 completed shape= (7, 60, 80, 32)
# batch 261 time= 275.4577
# afterbatch 261 length= 262
# (480, 640, 3)
# batch =  262 stage 1 completed shape= (7, 60, 80, 32)
# batch 262 time= 276.4499
# afterbatch 262 length= 263
# (480, 640, 3)
# batch =  263 stage 1 completed shape= (7, 60, 80, 32)
# batch 263 time= 277.4497
# afterbatch 263 length= 264
# (480, 640, 3)
# batch =  264 stage 1 completed shape= (7, 60, 80, 32)
# batch 264 time= 278.4074
# afterbatch 264 length= 265
# (480, 640, 3)
# batch =  265 stage 1 completed shape= (7, 60, 80, 32)
# batch 265 time= 279.3833
# afterbatch 265 length= 266
# (480, 640, 3)
# batch =  266 stage 1 completed shape= (7, 60, 80, 32)
# batch 266 time= 280.3646
# afterbatch 266 length= 267
# (480, 640, 3)
# batch =  267 stage 1 completed shape= (7, 60, 80, 32)
# batch 267 time= 281.3637
# afterbatch 267 length= 268
# (480, 640, 3)
# batch =  268 stage 1 completed shape= (7, 60, 80, 32)
# batch 268 time= 282.3367
# afterbatch 268 length= 269
# (480, 640, 3)
# batch =  269 stage 1 completed shape= (7, 60, 80, 32)
# batch 269 time= 283.3307
# afterbatch 269 length= 270
# (480, 640, 3)
# batch =  270 stage 1 completed shape= (7, 60, 80, 32)
# batch 270 time= 284.3001
# afterbatch 270 length= 271
# (480, 640, 3)
# batch =  271 stage 1 completed shape= (7, 60, 80, 32)
# batch 271 time= 285.2731
# afterbatch 271 length= 272
# (480, 640, 3)
# batch =  272 stage 1 completed shape= (7, 60, 80, 32)
# batch 272 time= 286.2605
# afterbatch 272 length= 273
# (480, 640, 3)
# batch =  273 stage 1 completed shape= (7, 60, 80, 32)
# batch 273 time= 287.2517
# afterbatch 273 length= 274
# (480, 640, 3)
# batch =  274 stage 1 completed shape= (7, 60, 80, 32)
# batch 274 time= 288.2511
# afterbatch 274 length= 275
# (480, 640, 3)
# batch =  275 stage 1 completed shape= (7, 60, 80, 32)
# batch 275 time= 289.2563
# afterbatch 275 length= 276
# (480, 640, 3)
# batch =  276 stage 1 completed shape= (7, 60, 80, 32)
# batch 276 time= 290.2318
# afterbatch 276 length= 277
# (480, 640, 3)
# batch =  277 stage 1 completed shape= (7, 60, 80, 32)
# batch 277 time= 291.2205
# afterbatch 277 length= 278
# (480, 640, 3)
# batch =  278 stage 1 completed shape= (7, 60, 80, 32)
# batch 278 time= 292.1997
# afterbatch 278 length= 279
# (480, 640, 3)
# batch =  279 stage 1 completed shape= (7, 60, 80, 32)
# batch 279 time= 293.1689
# afterbatch 279 length= 280
# (480, 640, 3)
# batch =  280 stage 1 completed shape= (7, 60, 80, 32)
# batch 280 time= 294.1493
# afterbatch 280 length= 281
# (480, 640, 3)
# batch =  281 stage 1 completed shape= (7, 60, 80, 32)
# batch 281 time= 295.1347
# afterbatch 281 length= 282
# (480, 640, 3)
# batch =  282 stage 1 completed shape= (7, 60, 80, 32)
# batch 282 time= 296.0762
# afterbatch 282 length= 283
# (480, 640, 3)
# batch =  283 stage 1 completed shape= (7, 60, 80, 32)
# batch 283 time= 297.0514
# afterbatch 283 length= 284
# (480, 640, 3)
# batch =  284 stage 1 completed shape= (7, 60, 80, 32)
# batch 284 time= 298.0133
# afterbatch 284 length= 285
# (480, 640, 3)
# batch =  285 stage 1 completed shape= (7, 60, 80, 32)
# batch 285 time= 299.007
# afterbatch 285 length= 286
# (480, 640, 3)
# batch =  286 stage 1 completed shape= (7, 60, 80, 32)
# batch 286 time= 300.0156
# afterbatch 286 length= 287
# (480, 640, 3)
# batch =  287 stage 1 completed shape= (7, 60, 80, 32)
# batch 287 time= 300.9954
# afterbatch 287 length= 288
# (480, 640, 3)
# batch =  288 stage 1 completed shape= (7, 60, 80, 32)
# batch 288 time= 301.9521
# afterbatch 288 length= 289
# (480, 640, 3)
# batch =  289 stage 1 completed shape= (7, 60, 80, 32)
# batch 289 time= 302.9206
# afterbatch 289 length= 290
# (480, 640, 3)
# batch =  290 stage 1 completed shape= (7, 60, 80, 32)
# batch 290 time= 303.8824
# afterbatch 290 length= 291
# (480, 640, 3)
# batch =  291 stage 1 completed shape= (7, 60, 80, 32)
# batch 291 time= 304.8495
# afterbatch 291 length= 292
# (480, 640, 3)
# batch =  292 stage 1 completed shape= (7, 60, 80, 32)
# batch 292 time= 305.8289
# afterbatch 292 length= 293
# (480, 640, 3)
# batch =  293 stage 1 completed shape= (7, 60, 80, 32)
# batch 293 time= 306.8166
# afterbatch 293 length= 294
# (480, 640, 3)
# batch =  294 stage 1 completed shape= (7, 60, 80, 32)
# batch 294 time= 307.809
# afterbatch 294 length= 295
# (480, 640, 3)
# batch =  295 stage 1 completed shape= (7, 60, 80, 32)
# batch 295 time= 308.7947
# afterbatch 295 length= 296
# (480, 640, 3)
# batch =  296 stage 1 completed shape= (7, 60, 80, 32)
# batch 296 time= 309.7952
# afterbatch 296 length= 297
# (480, 640, 3)
# batch =  297 stage 1 completed shape= (7, 60, 80, 32)
# batch 297 time= 310.7547
# afterbatch 297 length= 298
# (480, 640, 3)
# batch =  298 stage 1 completed shape= (7, 60, 80, 32)
# batch 298 time= 311.7366
# afterbatch 298 length= 299
# (480, 640, 3)
# batch =  299 stage 1 completed shape= (7, 60, 80, 32)
# batch 299 time= 312.7354
# afterbatch 299 length= 300
# (480, 640, 3)
# batch =  300 stage 1 completed shape= (7, 60, 80, 32)
# batch 300 time= 313.7235
# afterbatch 300 length= 301
# (480, 640, 3)
# batch =  301 stage 1 completed shape= (7, 60, 80, 32)
# batch 301 time= 314.7327
# afterbatch 301 length= 302
# (480, 640, 3)
# batch =  302 stage 1 completed shape= (7, 60, 80, 32)
# batch 302 time= 315.7077
# afterbatch 302 length= 303
# (480, 640, 3)
# batch =  303 stage 1 completed shape= (7, 60, 80, 32)
# batch 303 time= 316.7038
# afterbatch 303 length= 304
# (480, 640, 3)
# batch =  304 stage 1 completed shape= (7, 60, 80, 32)
# batch 304 time= 317.6813
# afterbatch 304 length= 305
# (480, 640, 3)
# batch =  305 stage 1 completed shape= (7, 60, 80, 32)
# batch 305 time= 318.6608
# afterbatch 305 length= 306
# (480, 640, 3)
# batch =  306 stage 1 completed shape= (7, 60, 80, 32)
# batch 306 time= 319.6316
# afterbatch 306 length= 307
# (480, 640, 3)
# batch =  307 stage 1 completed shape= (7, 60, 80, 32)
# batch 307 time= 320.5942
# afterbatch 307 length= 308
# (480, 640, 3)
# batch =  308 stage 1 completed shape= (7, 60, 80, 32)
# batch 308 time= 321.5684
# afterbatch 308 length= 309
# (480, 640, 3)
# batch =  309 stage 1 completed shape= (7, 60, 80, 32)
# batch 309 time= 322.5486
# afterbatch 309 length= 310
# (480, 640, 3)
# batch =  310 stage 1 completed shape= (7, 60, 80, 32)
# batch 310 time= 323.5333
# afterbatch 310 length= 311
# (480, 640, 3)
# batch =  311 stage 1 completed shape= (7, 60, 80, 32)
# batch 311 time= 324.5114
# afterbatch 311 length= 312
# (480, 640, 3)
# batch =  312 stage 1 completed shape= (7, 60, 80, 32)
# batch 312 time= 325.4961
# afterbatch 312 length= 313
# (480, 640, 3)
# batch =  313 stage 1 completed shape= (7, 60, 80, 32)
# batch 313 time= 326.4838
# afterbatch 313 length= 314
# (480, 640, 3)
# batch =  314 stage 1 completed shape= (7, 60, 80, 32)
# batch 314 time= 327.445
# afterbatch 314 length= 315
# (480, 640, 3)
# batch =  315 stage 1 completed shape= (7, 60, 80, 32)
# batch 315 time= 328.4215
# afterbatch 315 length= 316
# (480, 640, 3)
# batch =  316 stage 1 completed shape= (7, 60, 80, 32)
# batch 316 time= 329.3774
# afterbatch 316 length= 317
# (480, 640, 3)
# batch =  317 stage 1 completed shape= (7, 60, 80, 32)
# batch 317 time= 330.35
# afterbatch 317 length= 318
# (480, 640, 3)
# batch =  318 stage 1 completed shape= (7, 60, 80, 32)
# batch 318 time= 331.3629
# afterbatch 318 length= 319
# (480, 640, 3)
# batch =  319 stage 1 completed shape= (7, 60, 80, 32)
# batch 319 time= 332.3434
# afterbatch 319 length= 320
# (480, 640, 3)
# batch =  320 stage 1 completed shape= (7, 60, 80, 32)
# batch 320 time= 333.3111
# afterbatch 320 length= 321
# (480, 640, 3)
# batch =  321 stage 1 completed shape= (7, 60, 80, 32)
# batch 321 time= 334.3058
# afterbatch 321 length= 322
# (480, 640, 3)
# batch =  322 stage 1 completed shape= (7, 60, 80, 32)
# batch 322 time= 335.3005
# afterbatch 322 length= 323
# (480, 640, 3)
# batch =  323 stage 1 completed shape= (7, 60, 80, 32)
# batch 323 time= 336.3119
# afterbatch 323 length= 324
# (480, 640, 3)
# batch =  324 stage 1 completed shape= (7, 60, 80, 32)
# batch 324 time= 337.2985
# afterbatch 324 length= 325
# (480, 640, 3)
# batch =  325 stage 1 completed shape= (7, 60, 80, 32)
# batch 325 time= 338.2764
# afterbatch 325 length= 326
# (480, 640, 3)
# batch =  326 stage 1 completed shape= (7, 60, 80, 32)
# batch 326 time= 339.2606
# afterbatch 326 length= 327
# (480, 640, 3)
# batch =  327 stage 1 completed shape= (7, 60, 80, 32)
# batch 327 time= 340.2332
# afterbatch 327 length= 328
# (480, 640, 3)
# batch =  328 stage 1 completed shape= (7, 60, 80, 32)
# batch 328 time= 341.2237
# afterbatch 328 length= 329
# (480, 640, 3)
# batch =  329 stage 1 completed shape= (7, 60, 80, 32)
# batch 329 time= 342.2105
# afterbatch 329 length= 330
# (480, 640, 3)
# batch =  330 stage 1 completed shape= (7, 60, 80, 32)
# batch 330 time= 343.1881
# afterbatch 330 length= 331
# (480, 640, 3)
# batch =  331 stage 1 completed shape= (7, 60, 80, 32)
# batch 331 time= 344.1805
# afterbatch 331 length= 332
# (480, 640, 3)
# batch =  332 stage 1 completed shape= (7, 60, 80, 32)
# batch 332 time= 345.1772
# afterbatch 332 length= 333
# (480, 640, 3)
# batch =  333 stage 1 completed shape= (7, 60, 80, 32)
# batch 333 time= 346.1273
# afterbatch 333 length= 334
# (480, 640, 3)
# batch =  334 stage 1 completed shape= (7, 60, 80, 32)
# batch 334 time= 347.0875
# afterbatch 334 length= 335
# (480, 640, 3)
# batch =  335 stage 1 completed shape= (7, 60, 80, 32)
# batch 335 time= 348.0497
# afterbatch 335 length= 336
# (480, 640, 3)
# batch =  336 stage 1 completed shape= (7, 60, 80, 32)
# batch 336 time= 349.0282
# afterbatch 336 length= 337
# (480, 640, 3)
# batch =  337 stage 1 completed shape= (7, 60, 80, 32)
# batch 337 time= 350.0063
# afterbatch 337 length= 338
# (480, 640, 3)
# batch =  338 stage 1 completed shape= (7, 60, 80, 32)
# batch 338 time= 350.9908
# afterbatch 338 length= 339
# (480, 640, 3)
# batch =  339 stage 1 completed shape= (7, 60, 80, 32)
# batch 339 time= 351.9698
# afterbatch 339 length= 340
# (480, 640, 3)
# batch =  340 stage 1 completed shape= (6, 60, 80, 32)
# batch 340 time= 353.4081
# afterbatch 340 length= 341
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-31-c9d3532895e7> in <module>()
#       5 train_final_array_2 = make_data(train_file_list, model_2,src_2)
#       6
# ----> 7 print ('train final array_2', final_array_2.shape)
#       8 np.save(src_save+'train_data_img_preprocess_DenseNet121_2_verification.npy',train_final_array_2)
#       9 print ('totally done, train_data_img_preprocess_denseNet121_2_verification.npy.npy')
#
# NameError: name 'final_array_2' is not defined

# %%
'''
print ('train final array_2', train_final_array_2.shape)
np.save(src_save+'train_data_img_preprocess_DenseNet121_2_verification.npy',train_final_array_2)
print ('totally done, train_data_img_preprocess_denseNet121_2_verification.npy.npy')
'''
# Out:
# "\nprint ('train final array_2', train_final_array_2.shape)\nnp.save(src_save+'train_data_img_preprocess_DenseNet121_2_verification.npy',train_final_array_2)\nprint ('totally done, train_data_img_preprocess_denseNet121_2_verification.npy.npy')\n"

# %%
test_file_list =  os.listdir(src_3)


test_final_array_2 = make_data(test_file_list,model_2,src_3)
print ('test_final array_2', test_final_array_2.shape)
np.save(src_save+'test_data_img_preprocess_MobileNetV2_2_verification.npy',test_final_array_2)
print ('totally done, test_final_data_img_preprocess_MobileNetV2_2_verification.npy')
# Out:
# floor= 62
# total size 440 file_list 440 final_list length NOT equal to file_list
# 0
# warning, something wrong
# 63
# (480, 640, 3)
# batch =  0 stage 1 completed shape= (7, 60, 80, 32)
# batch 0 time= 1.1581
# afterbatch 0 length= 1
# (480, 640, 3)
# batch =  1 stage 1 completed shape= (7, 60, 80, 32)
# batch 1 time= 2.199
# afterbatch 1 length= 2
# (480, 640, 3)
# batch =  2 stage 1 completed shape= (7, 60, 80, 32)
# batch 2 time= 3.1667
# afterbatch 2 length= 3
# (480, 640, 3)
# batch =  3 stage 1 completed shape= (7, 60, 80, 32)
# batch 3 time= 4.1613
# afterbatch 3 length= 4
# (480, 640, 3)
# batch =  4 stage 1 completed shape= (7, 60, 80, 32)
# batch 4 time= 5.1495
# afterbatch 4 length= 5
# (480, 640, 3)
# batch =  5 stage 1 completed shape= (7, 60, 80, 32)
# batch 5 time= 6.1196
# afterbatch 5 length= 6
# (480, 640, 3)
# batch =  6 stage 1 completed shape= (7, 60, 80, 32)
# batch 6 time= 7.0755
# afterbatch 6 length= 7
# (480, 640, 3)
# batch =  7 stage 1 completed shape= (7, 60, 80, 32)
# batch 7 time= 8.0399
# afterbatch 7 length= 8
# (480, 640, 3)
# batch =  8 stage 1 completed shape= (7, 60, 80, 32)
# batch 8 time= 9.0205
# afterbatch 8 length= 9
# (480, 640, 3)
# batch =  9 stage 1 completed shape= (7, 60, 80, 32)
# batch 9 time= 9.991
# afterbatch 9 length= 10
# (480, 640, 3)
# batch =  10 stage 1 completed shape= (7, 60, 80, 32)
# batch 10 time= 10.9267
# afterbatch 10 length= 11
# (480, 640, 3)
# batch =  11 stage 1 completed shape= (7, 60, 80, 32)
# batch 11 time= 11.9118
# afterbatch 11 length= 12
# (480, 640, 3)
# batch =  12 stage 1 completed shape= (7, 60, 80, 32)
# batch 12 time= 12.8925
# afterbatch 12 length= 13
# (480, 640, 3)
# batch =  13 stage 1 completed shape= (7, 60, 80, 32)
# batch 13 time= 13.8588
# afterbatch 13 length= 14
# (480, 640, 3)
# batch =  14 stage 1 completed shape= (7, 60, 80, 32)
# batch 14 time= 14.8308
# afterbatch 14 length= 15
# (480, 640, 3)
# batch =  15 stage 1 completed shape= (7, 60, 80, 32)
# batch 15 time= 15.7939
# afterbatch 15 length= 16
# (480, 640, 3)
# batch =  16 stage 1 completed shape= (7, 60, 80, 32)
# batch 16 time= 16.7434
# afterbatch 16 length= 17
# (480, 640, 3)
# batch =  17 stage 1 completed shape= (7, 60, 80, 32)
# batch 17 time= 17.7265
# afterbatch 17 length= 18
# (480, 640, 3)
# batch =  18 stage 1 completed shape= (7, 60, 80, 32)
# batch 18 time= 18.7006
# afterbatch 18 length= 19
# (480, 640, 3)
# batch =  19 stage 1 completed shape= (7, 60, 80, 32)
# batch 19 time= 19.6666
# afterbatch 19 length= 20
# (480, 640, 3)
# batch =  20 stage 1 completed shape= (7, 60, 80, 32)
# batch 20 time= 20.6293
# afterbatch 20 length= 21
# (480, 640, 3)
# batch =  21 stage 1 completed shape= (7, 60, 80, 32)
# batch 21 time= 21.5948
# afterbatch 21 length= 22
# (480, 640, 3)
# batch =  22 stage 1 completed shape= (7, 60, 80, 32)
# batch 22 time= 22.5894
# afterbatch 22 length= 23
# (480, 640, 3)
# batch =  23 stage 1 completed shape= (7, 60, 80, 32)
# batch 23 time= 23.5586
# afterbatch 23 length= 24
# (480, 640, 3)
# batch =  24 stage 1 completed shape= (7, 60, 80, 32)
# batch 24 time= 24.5308
# afterbatch 24 length= 25
# (480, 640, 3)
# batch =  25 stage 1 completed shape= (7, 60, 80, 32)
# batch 25 time= 25.4877
# afterbatch 25 length= 26
# (480, 640, 3)
# batch =  26 stage 1 completed shape= (7, 60, 80, 32)
# batch 26 time= 26.4366
# afterbatch 26 length= 27
# (480, 640, 3)
# batch =  27 stage 1 completed shape= (7, 60, 80, 32)
# batch 27 time= 27.406
# afterbatch 27 length= 28
# (480, 640, 3)
# batch =  28 stage 1 completed shape= (7, 60, 80, 32)
# batch 28 time= 28.3572
# afterbatch 28 length= 29
# (480, 640, 3)
# batch =  29 stage 1 completed shape= (7, 60, 80, 32)
# batch 29 time= 29.3534
# afterbatch 29 length= 30
# (480, 640, 3)
# batch =  30 stage 1 completed shape= (7, 60, 80, 32)
# batch 30 time= 30.3632
# afterbatch 30 length= 31
# (480, 640, 3)
# batch =  31 stage 1 completed shape= (7, 60, 80, 32)
# batch 31 time= 31.3735
# afterbatch 31 length= 32
# (480, 640, 3)
# batch =  32 stage 1 completed shape= (7, 60, 80, 32)
# batch 32 time= 32.3412
# afterbatch 32 length= 33
# (480, 640, 3)
# batch =  33 stage 1 completed shape= (7, 60, 80, 32)
# batch 33 time= 33.3159
# afterbatch 33 length= 34
# (480, 640, 3)
# batch =  34 stage 1 completed shape= (7, 60, 80, 32)
# batch 34 time= 34.3128
# afterbatch 34 length= 35
# (480, 640, 3)
# batch =  35 stage 1 completed shape= (7, 60, 80, 32)
# batch 35 time= 35.3237
# afterbatch 35 length= 36
# (480, 640, 3)
# batch =  36 stage 1 completed shape= (7, 60, 80, 32)
# batch 36 time= 36.3052
# afterbatch 36 length= 37
# (480, 640, 3)
# batch =  37 stage 1 completed shape= (7, 60, 80, 32)
# batch 37 time= 37.2757
# afterbatch 37 length= 38
# (480, 640, 3)
# batch =  38 stage 1 completed shape= (7, 60, 80, 32)
# batch 38 time= 38.2691
# afterbatch 38 length= 39
# (480, 640, 3)
# batch =  39 stage 1 completed shape= (7, 60, 80, 32)
# batch 39 time= 39.2725
# afterbatch 39 length= 40
# (480, 640, 3)
# batch =  40 stage 1 completed shape= (7, 60, 80, 32)
# batch 40 time= 40.2431
# afterbatch 40 length= 41
# (480, 640, 3)
# batch =  41 stage 1 completed shape= (7, 60, 80, 32)
# batch 41 time= 41.267
# afterbatch 41 length= 42
# (480, 640, 3)
# batch =  42 stage 1 completed shape= (7, 60, 80, 32)
# batch 42 time= 42.2436
# afterbatch 42 length= 43
# (480, 640, 3)
# batch =  43 stage 1 completed shape= (7, 60, 80, 32)
# batch 43 time= 43.2514
# afterbatch 43 length= 44
# (480, 640, 3)
# batch =  44 stage 1 completed shape= (7, 60, 80, 32)
# batch 44 time= 44.2471
# afterbatch 44 length= 45
# (480, 640, 3)
# batch =  45 stage 1 completed shape= (7, 60, 80, 32)
# batch 45 time= 45.2318
# afterbatch 45 length= 46
# (480, 640, 3)
# batch =  46 stage 1 completed shape= (7, 60, 80, 32)
# batch 46 time= 46.2052
# afterbatch 46 length= 47
# (480, 640, 3)
# batch =  47 stage 1 completed shape= (7, 60, 80, 32)
# batch 47 time= 47.1505
# afterbatch 47 length= 48
# (480, 640, 3)
# batch =  48 stage 1 completed shape= (7, 60, 80, 32)
# batch 48 time= 48.1305
# afterbatch 48 length= 49
# (480, 640, 3)
# batch =  49 stage 1 completed shape= (7, 60, 80, 32)
# batch 49 time= 49.1076
# afterbatch 49 length= 50
# (480, 640, 3)
# batch =  50 stage 1 completed shape= (7, 60, 80, 32)
# batch 50 time= 50.0857
# afterbatch 50 length= 51
# (480, 640, 3)
# batch =  51 stage 1 completed shape= (7, 60, 80, 32)
# batch 51 time= 51.0914
# afterbatch 51 length= 52
# (480, 640, 3)
# batch =  52 stage 1 completed shape= (7, 60, 80, 32)
# batch 52 time= 52.0531
# afterbatch 52 length= 53
# (480, 640, 3)
# batch =  53 stage 1 completed shape= (7, 60, 80, 32)
# batch 53 time= 53.0263
# afterbatch 53 length= 54
# (480, 640, 3)
# batch =  54 stage 1 completed shape= (7, 60, 80, 32)
# batch 54 time= 54.0394
# afterbatch 54 length= 55
# (480, 640, 3)
# batch =  55 stage 1 completed shape= (7, 60, 80, 32)
# batch 55 time= 55.0236
# afterbatch 55 length= 56
# (480, 640, 3)
# batch =  56 stage 1 completed shape= (7, 60, 80, 32)
# batch 56 time= 55.947
# afterbatch 56 length= 57
# (480, 640, 3)
# batch =  57 stage 1 completed shape= (7, 60, 80, 32)
# batch 57 time= 56.9104
# afterbatch 57 length= 58
# (480, 640, 3)
# batch =  58 stage 1 completed shape= (7, 60, 80, 32)
# batch 58 time= 57.9063
# afterbatch 58 length= 59
# (480, 640, 3)
# batch =  59 stage 1 completed shape= (7, 60, 80, 32)
# batch 59 time= 58.8932
# afterbatch 59 length= 60
# (480, 640, 3)
# batch =  60 stage 1 completed shape= (7, 60, 80, 32)
# batch 60 time= 59.8718
# afterbatch 60 length= 61
# (480, 640, 3)
# batch =  61 stage 1 completed shape= (7, 60, 80, 32)
# batch 61 time= 60.8376
# afterbatch 61 length= 62
# (480, 640, 3)
# batch =  62 stage 1 completed shape= (6, 60, 80, 32)
# batch 62 time= 61.7068
# afterbatch 62 length= 63
# test_final array_2 (440, 60, 80, 32)
# totally done, test_final_data_img_preprocess_MobileNetV2_2_verification.npy
